# %%
import re

txt = "Heavy rain in TN"
x = re.split("\s",txt)
print(x)

txt = " ".join(x)
print(txt)
# Out:
# ['Heavy', 'rain', 'in', 'TN']
# Heavy rain in TN

# %%
import re
txt = "the world is most beautiful"
# string starts with hello
x= re.findall("^she" , txt)
print(x)
if x:
  print("yes there is a match")
else:
  print("No match")
# Out:
# []
# No match

# %%
import re
text = " i am using oneplus mobile"
x = re.findall("oneplus$", text)
print(x)
if x:
  print("there is a match")
else :
  print("No match")
# Out:
# []
# No match

# %%
import re#multi word

txt = "The rain in Spain falls mainly in the plain!"

#Check if the string contains either "falls" or "stays":

x = re.findall("falls|stays", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['falls']
# Yes, there is at least one match!

# %%
import re#multi word

txt = "The rain in Spain falls mainly in the plain!"

#Check if the string contains either "falls" or "stays":

x = re.findall("falls|Spain|sta", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['Spain', 'falls']
# Yes, there is at least one match!

# %%
import re
with open("Hints for remembering RI syntax.txt", "r") as file :
    file_contents = file.read()
    x=  re.split("\s" , file_contents)


a=x
print(a)
# Out:
# ['Convert', 'the', 'single', 'sentence', 'in', 'to', 'string', 'array:', '-----------------------------------------------------------', '', 'import', 're', '', 'txt', '=', '"Heavy', 'rain', 'in', 'TN"', 'x', '=', 're.split("\\s",', 'txt)', 'print(x)', '', 'text', '=', '"', '".join(x)', 'print(text)', '', '', 'Check', 'is', 'the', 'string', 'starts', 'and', 'ends', 'with', 'particular', 'string:', '-----------------------------------------------------------', 'import', 're', '', 'txt', '=', '"hi', 'planet', 'hello', 'bala"', '', '#', 'Check', 'if', 'the', 'string', 'starts', 'with', "'hello'", 'x', '=', 're.findall("^hello",', 'txt)', 'print(x)', 'if', 'x:', '', '', '', '', 'print("Yes,', 'the', 'string', 'starts', 'with', '\'hello\'")', 'else:', '', '', '', '', 'print("No', 'match")', '', '#', 'Check', 'if', 'the', 'string', 'ends', 'with', "'bala'", 'y', '=', 're.findall("bala$",', 'txt)', 'print(y)', 'if', 'y:', '', '', '', '', 'print("Yes,', 'the', 'string', 'ends', 'with', '\'bal
# ...
