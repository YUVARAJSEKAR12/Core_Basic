# %%
pip install fuzzywuzzy

# %%
pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.7 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=d9ec94148b14d1e22cf9752ad43fb3825db05497c91692ecb883620b2c6ec344
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
# ...

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from googletrans import Translator
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

def electromag():
  data="Electromagnetism is a fundamental physical phenomenon that describes the interaction between electrically charged particles and the electromagnetic force, one of the four fundamental forces of nature."
  print(data)
  print("Data is in Language English, If you want to convert to any language please enter it")
  languagespecified=input("Enter a string = ")
  llanguagespecified=languagespecified.lower()
  print("Language specified is: ",llanguagespecified)
  languageconversion(data,llanguagespecified)
def electrochar():
  data="An electric charge is a fundamental property of matter that causes it to experience an electromagnetic force. There are two types: positive and negative."
  print(data)
  print("Data is in Language English, If you want to convert to any language please enter it")
  languagespecified=input("Enter a string = ")
  llanguagespecified=languagespecified.lower()
  print("Language specified is: ",llanguagespecified)
  languageconversion(data,llanguagespecified)
def electricfield():
  data="An electric field is a region around a charged particle or object where the electromagnetic force can be detected. It's measured in volts per meter (V/m)."
  print(data)
  print("Data is in Language English, If you want to convert to any language please enter it")
  languagespecified=input("Enter a string = ")
  llanguagespecified=languagespecified.lower()
  print("Language specified is: ",llanguagespecified)
  languageconversion(data,llanguagespecified)
def magneticfield():
  data="A magnetic field is a region around a magnet or current-carrying wire where magnetic forces can be detected. It's measured in teslas (T)."
  print(data)
  print("Data is in Language English, If you want to convert to any language please enter it")
  languagespecified=input("Enter a string = ")
  llanguagespecified=languagespecified.lower()
  print("Language specified is: ",llanguagespecified)
  languageconversion(data,llanguagespecified)
def electroinduction():
  data="Electromagnetic induction is the process by which a changing magnetic field induces an electric current in a conductor."
  print(data)
  print("Data is in Language English, If you want to convert to any language please enter it")
  languagespecified=input("Enter a string = ")
  llanguagespecified=languagespecified.lower()
  print("Language specified is: ",llanguagespecified)
  languageconversion(data,llanguagespecified)
def differenceACandDC():
  data="AC (Alternating Current) changes direction periodically, while DC (Direct Current) flows in one direction only."
  print(data)
  print("Data is in Language English, If you want to convert to any language please enter it")
  languagespecified=input("Enter a string = ")
  llanguagespecified=languagespecified.lower()
  print("Language specified is: ",llanguagespecified)
  languageconversion(data,llanguagespecified)
def electrospecturm():
  data="The electromagnetic spectrum describes the range of electromagnetic waves, from low-frequency radio waves to high-frequency gamma rays."
  print(data)
  print("Data is in Language English, If you want to convert to any language please enter it")
  languagespecified=input("Enter a string = ")
  llanguagespecified=languagespecified.lower()
  print("Language specified is: ",llanguagespecified)
  languageconversion(data,llanguagespecified)
def electricandmagneticrelationship():
  data="Electric and magnetic fields are interconnected; a changing electric field produces a magnetic field, and vice versa."
  print(data)
  print("Data is in Language English, If you want to convert to any language please enter it")
  languagespecified=input("Enter a string = ")
  llanguagespecified=languagespecified.lower()
  print("Language specified is: ",llanguagespecified)
  languageconversion(data,llanguagespecified)
def maxwellequation():
  data="Maxwell's Equations unify the previously separate theories of electricity and magnetism into a single, coherent theory of electromagnetism."
  print(data)
  print("Data is in Language English, If you want to convert to any language please enter it")
  languagespecified=input("Enter a string = ")
  llanguagespecified=languagespecified.lower()
  print("Language specified is: ",llanguagespecified)
  languageconversion(data,llanguagespecified)
def application_electromagnetism():
  data = """Electromagnetism has numerous applications, including:
    - Electricity generation and distribution
    - Electronic devices (smartphones, computers)
    - Medical imaging (MRI, CT scans)
    - Communication systems (radio, microwave)
    - Particle accelerators"""
  print(data)
  print("Data is in Language English, If you want to convert to any language please enter it")
  languagespecified=input("Enter a string = ")
  llanguagespecified=languagespecified.lower()
  print("Language specified is: ",llanguagespecified)
  languageconversion(data,llanguagespecified)
def languageconversion(data,llanguagespecified):
  if llanguagespecified == "hindi":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='hi')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "spanish":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='es')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "french":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='fr')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "german":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='de')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "italian":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='it')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "portuguese":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='pt')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "japanese":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='ja')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "korean":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='ko')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "chinese":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='zh-cn')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "russian":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='ru')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "arabic":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='ar')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "tamil":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='ta')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "telugu":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='te')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "bengali":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='bn')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "urdu":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='ur')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "gujarati":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='gu')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "marathi":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='mr')
    b=translated_text.text
    print(b)
  elif llanguagespecified == "kannada":
    t = Translator()
    translated_text = t.translate(data, src='en', dest='kn')
    b=translated_text.text
    print(b)
  else:
    print("Language not supported")



wordstobefiltered=["who", "what", "when", "where", "why", "how", "is", "in", "on", "at", "by", "with", "from", "to", "of", "for", "your", "their", "my", "his", "her", "its", "our", "which", "whom", "whose","explain","and","was","define","brief","are","me","us","to","/","//","the"]
ip=input("Please input your area of interest")
l=ip.lower()
print("\ninput in lower case =",l)
b = l.split()
print("\ninput in list Format=",b)
filter = [word for word in b if word.lower() not in wordstobefiltered]
print("\nfiltered words=",filter)
result1 = " ".join(filter)
result=result1.replace(" ", "")
tokens = word_tokenize(result)
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
filtered_sentence = " ".join(filtered_tokens)
print("Original Sentence:")
print(result)
print("\nFiltered Sentence:")
print(filtered_sentence)
if 'electromagnetism' in result.lower() or 'electromagnetism' in filtered_sentence.lower():
    electromag()

elif 'electriccharge' in result.lower() or 'electriccharge' in filtered_sentence.lower():
    electrochar()

elif 'electricfield' in result.lower() or 'electricfield' in filtered_sentence.lower():
    electricfield()

elif 'electromagneticinduction' in result.lower() or 'electromagneticinduction' in filtered_sentence.lower():
    electroinduction()

elif 'differencebetweenacdccurrent' in result.lower() or 'differencebetweenacdccurrent' in filtered_sentence.lower() :
    differenceACandDC()

elif 'electromagneticspectrum' in result.lower() or 'electromagneticspectrum' in filtered_sentence.lower():
    electrospecturm()

elif 'relationshipbetweenelectricmagneticfields' in result.lower():
    electricandmagneticrelationship()

elif "maxwell'sequations" in result.lower():
    maxwellequation()

elif "magneticfield" in result.lower():
    magneticfield()

elif result =='Electromagnetism' or result == 'Electro magnetism' or result == 'electro magnetism' or result == 'Electro Magnetism':
  electromag()

elif result == 'Electric Charge' or result == 'Electric charge' or result == 'electric charge' or result == 'ElectricCharge':
  electrochar()

elif result == 'Electric Field' or result == 'Electric field' or result == 'electric field' or result == 'ElectricField':
  electricfield()

elif result == 'Magnetic Field' or result == 'Magnetic field' or result == 'magnetic field' or result == 'MagneticField':
  magneticfield()

elif result == 'Electromagnetic Induction' or result == 'Electromagnetic induction' or result == 'electromagnetic induction' or result == 'ElectromagneticInduction':
  electromag()

elif result == 'Difference between AC and DC Current' or result == 'Difference Between AC and DC Current' or result == 'difference between ac and dc current' or result == 'DifferenceBetweenACandDCCurrent':
  differenceACandDC()

elif result == 'Electromagnetic Spectrum' or result == 'Electromagnetic spectrum' or result == 'electromagnetic spectrum' or result == 'ElectromagneticSpectrum':
  electromag()

elif result == 'Relationship between Electric and Magnetic Fields' or result == 'Relationship Between Electric and Magnetic Fields' or result == 'relationship between electric and magnetic fields' or result == 'RelationshipBetweenElectricAndMagneticFields':
  electricandmagneticrelationship()

elif result == "Maxwell\'s Equations" or result == "Maxwell's Equations" or result == "maxwell\'s equations" or result == "Maxwell\'sEquations" or result == "Maxwell's Equations" or result == "maxwell's equations":
  maxwellequation()

else:
    Z = result
    Z1 = "electromagnetism"
    Z2 = "electriccharge"
    Z3 = "electricfield"
    Z4 = "magneticfield"
    Z5 = "electromagneticinduction"
    Z6 = "DifferencebetweenACandDCCurrent"
    Z7 = "ElectromagneticSpectrum"
    Z8 = "RelationshipbetweenElectricandMagneticFields"
    Z9 = "theSignificanceofMaxwellsEquations"

    Y1 = fuzz.WRatio(Z, Z1)
    print("Electromagnetism =", Y1)
    Y2 = fuzz.WRatio(Z, Z2)
    print("Electric Charge =", Y2)
    Y3 = fuzz.WRatio(Z, Z3)
    print("Electric Field =", Y3)
    Y4 = fuzz.WRatio(Z, Z4)
    print("Magnetic Field =", Y4)
    Y5 = fuzz.WRatio(Z, Z5)
    print("Electromagnetic Induction =", Y5)
    Y6 = fuzz.WRatio(Z, Z6)
    print("Difference between AC and DC =", Y6)
    Y7 = fuzz.WRatio(Z, Z7)
    print("Electromagnetic Spectrum =", Y7)
    Y8 = fuzz.WRatio(Z, Z8)
    print("Relationship between Electric and Magnetic Fields =", Y8)
    Y9 = fuzz.WRatio(Z, Z9)
    print("The Significance of Maxwell's Equations =", Y9)

    if Y1 > 80:
        print(electromag())
    elif Y2 > 80:
        print(electrochar())
    elif Y3 > 80:
        print(electricfield())
    elif Y4 > 80:
        print(magneticfield())
    elif Y5 > 80:
        print(electroinduction())
    elif Y6 > 80:
        print(differenceACandDC())
    elif Y7 > 80:
        print(electrospecturm())
    elif Y8 > 80:
        print(electricandmagneticrelationship())
    elif Y9 > 80:
        print(maxwellequation())
    else:
        print("Invalid input")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Please input your area of interestelectro
#
# input in lower case = electro
#
# input in list Format= ['electro']
#
# filtered words= ['electro']
# Original Sentence:
# electro
#
# Filtered Sentence:
# electro
# Electromagnetism = 90
# Electric Charge = 77
# Electric Field = 77
# Magnetic Field = 36
# Electromagnetic Induction = 90
# Difference between AC and DC = 39
# Electromagnetic Spectrum = 90
# Relationship between Electric and Magnetic Fields = 77
# The Significance of Maxwell's Equations = 39
# ...
