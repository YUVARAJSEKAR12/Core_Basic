# %%
import re
with open("test.txt", "r") as file :
    file_contents = file.read()
    x=  re.split("\s" , file_contents)


a=x
print(a)
# Out:
# ['Company', 'site,', 'all', 'line', 'of', 'business,', 'company', 'presence', '']

# %%
import re

txt = "Heavy rain in TN"
x = re.split("\s", txt)
print(x)

text = " ".join(x)
print(text)
# Out:
# ['Heavy', 'rain', 'in', 'TN']
# Heavy rain in TN

# %%
import re

txt = "Heavy rain in TN"
x = re.split("\s", txt)
print(x)

import re
with open("test.txt", "r") as file :
    file_contents = file.read()
    x=  re.split("\s" , file_contents)


a=x
print(a)
# Out:
# ['Heavy', 'rain', 'in', 'TN']
# ['Company', 'site,', 'all', 'line', 'of', 'business,', 'company', 'presence', '']

# %%
#Lower
b=input("Enter a text ")
x1=b.lower()
print(x1)
# Out:
# Enter a textHELLO
# hello

# %%
#upper
b1=input("Enter a text")
x2=b1.upper()
print(x2)
# Out:
# Enter a texthdwndone
# HDWNDONE

# %%
#title
b2=input("Enter a text")
x3=b2.title()
print(x3)
# Out:
# Enter a textsrefgg
# Srefgg

# %%
#puntuation
import re
x11=input("Enter a text=")
# Use regular expression to remove punctuation
a1 = re.sub(r'[^\w\s]', '', x11)
# Out:
# Enter a text=ent'a'est

# %%
import re # remove numbers
text = input("Input = ")
a=re.sub(r'\d+', '', text)
print(a)
# Out:
# Input = wewr24343
# wewr

# %%
#Special cha
import re
text = input("Input =")
a12=re.sub(r'[^A-Za-z0-9\s]+', '', text)
print(a12)
# Out:
# Input =Weiedf@$5513224
# Weiedf5513224

# %%
#Remove Extra Whitespaces
import re
text = input("Input =")
a12=re.sub(r'\s+', ' ', text).strip()
print(a12)
# Out:
# Input =Wekcome   yuvaraj
# Wekcome yuvaraj

# %%
import re #task
text = input("Input = ")
x1=text.lower()
a=re.sub(r'\d+', '', x1)
print(a)
a1=re.sub(r'\s+', ' ', a).strip()
print(a1)
a2=re.sub(r'[^A-Za-z0-9\s]+', '', a1)
print(a2)
# Out:
# Input =  Hello, World! Welcome to Python3. Regex is #1 @ cleaning: spaces, 123 numbers, & *special* characters!!!
#  hello, world! welcome to python. regex is # @ cleaning: spaces,  numbers, & *special* characters!!!
# hello, world! welcome to python. regex is # @ cleaning: spaces, numbers, & *special* characters!!!
# hello world welcome to python regex is   cleaning spaces numbers  special characters
