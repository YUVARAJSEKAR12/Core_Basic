# %%
import pandas as pd
import sqlite3 as db
import re
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk
import nltk

#fuzzy with GA
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

a = input("kindly provide me your name=")
print("welcome mr",a)
con = db.connect('seat1.sqlite')

def filter():
      Z = input("Hello! Welcome to Air Canada. How may I assist you today? ")
      Y = Z.lower()
      a1 =re.sub(r'[^A-Za-z0-9\s]+', '', Y)
      a2=re.sub(r'\d+', '', a1)

      a3=re.sub(r'\s+', ' ', a2).strip()
      T = ['don','were','why','havent','hasnt','didnt','didn','don','dont','werent','whats','which','arent','let','wasnt','dont','doesnt','appreciate','kindly','update','yet','isnt','youd','im','ive','youve','youll','hasnt','werent','wasnt','thats','lets','also','heres','ill','id','look','looking','from','more','who','a','it','any','if','being','an','im','make','get','my','that','spent','observed','?','hi','what','are','could','they','access','would','this','from','like','will','have','and','not','need','we','could','utilized','as','utilize','clear','share','on','or','provide','hello','are','unclear','forward','give','pass','through','want','encountering','encounter','revoke','seeking','i','experiencing','requires','help','initiate','passenger','traveler','intends','customer','my','to','oh','i','go','at','am','fresh','purchase','alright','may','having','needs','struggling','struggle','into','does','customers','client','clients','user','unable','okay','while','secure','asking','on','do','confirm','support','wish','wishes','arrange','arranging','requesting','is','was','the','assistance','trying','an','planning','a','many','looking','ways','has','by','a','his','wants','makes','so','should','about','during','for','with','can','using','on','be','guide','how','or','in','explain','whle','new','there','based','show','at','end','of','all','some','used','not','their','provides','his','has','who','explains','mention','due','know','to','yes','can','you','tell','me','use','them']

      X = a3.split()
      filter = [word for word in X if word.lower() not in T]

      key = " ".join(filter)

      return key
def filter1(Z):

      Y = Z.lower()
      a1 =re.sub(r'[^A-Za-z0-9\s]+', '', Y)
      a2=re.sub(r'\d+', '', a1)

      a3=re.sub(r'\s+', ' ', a2).strip()
      T = ['don','were','why','havent','its','hasnt','didnt','didn','don','dont','werent','whats','which','arent','let','wasnt','dont','doesnt','appreciate','kindly','update','yet','isnt','youd','im','ive','youve','youll','hasnt','werent','wasnt','thats','lets','also','heres','ill','id','look','looking','from','more','who','a','it','any','if','being','an','im','make','get','my','that','spent','observed','?','hi','what','are','could','they','access','would','this','from','like','will','have','and','not','need','we','could','utilized','as','utilize','clear','share','on','or','provide','hello','are','unclear','forward','give','pass','through','want','encountering','encounter','revoke','seeking','i','experiencing','requires','help','initiate','passenger','traveler','intends','customer','my','to','oh','i','go','at','am','fresh','purchase','alright','may','having','needs','struggling','struggle','into','does','customers','client','clients','user','unable','okay','while','secure','asking','on','do','confirm','support','wish','wishes','arrange','arranging','requesting','is','was','the','assistance','trying','an','planning','a','many','looking','ways','has','by','a','his','wants','makes','so','should','about','during','for','with','can','using','on','be','guide','how','or','in','explain','whle','new','there','based','show','at','end','of','all','some','used','not','their','provides','his','has','who','explains','mention','due','know','to','yes','can','you','tell','me','use','them']

      X = a3.split()
      filter = [word for word in X if word.lower() not in T]

      key = " ".join(filter)

      return key
def filter2(Z2):

      Y2 = Z2.lower()

      a21=re.sub(r'\d+', '', Y2)

      a31=re.sub(r'\s+', ' ', a21).strip()
      T2 = ['were','why','havent','hasnt','which','arent','let','wasnt','dont','doesnt','appreciate','kindly','update','yet','isnt','youd','im','ive','youve','youll','hasnt','werent','wasnt','thats','lets','also','heres','ill','id','look','looking','from','more','who','a','it','any','if','being','an','im','make','get','my','that','spent','observed','?','hi','what','are','could','they','access','would','this','from','like','will','have','and','not','need','we','could','utilized','as','utilize','clear','share','on','or','provide','hello','are','unclear','forward','give','pass','through','want','encountering','encounter','revoke','seeking','i','experiencing','requires','help','initiate','passenger','traveler','intends','customer','my','to','oh','i','go','at','am','fresh','purchase','alright','may','having','needs','struggling','struggle','into','does','customers','client','clients','user','unable','okay','while','secure','asking','on','do','confirm','support','wish','wishes','arrange','arranging','requesting','is','was','the','assistance','trying','an','planning','a','many','looking','ways','has','by','a','his','wants','makes','so','should','about','during','for','with','can','using','on','be','guide','how','or','in','explain','whle','new','there','based','show','at','end','of','all','some','used','not','their','provides','his','has','who','explains','mention','due','know','to','yes','can','you','tell','me','use','them']

      X2 = a31.split()
      filter = [word for word in X2 if word.lower() not in T2]

      key2 = " ".join(filter)

      return key2

def A():
  with open("A1.txt", "r") as file:
    A = file.read()
    print(A)
    return(A)
def cancelresponse():
  with open("cancel.txt", "r") as file:
    cancelresponse = file.read()
    print(cancelresponse)

    return(cancelresponse)
def cancelresponse1():
  with open("cancel2.txt", "r") as file:
    cancelresponse1 = file.read()
    print(cancelresponse1)
    return(cancelresponse1)
def cancelresponse2():
  with open("cancel3.txt", "r") as file:
    cancelresponse2 = file.read()
    print(cancelresponse2)
    return(cancelresponse2)
def cancelresponse3():
  with open("cancel4.txt", "r") as file:
    cancelresponse3 = file.read()
    print(cancelresponse3)
    return(cancelresponse3)
def cancelresponse4():
  with open("cancel5.txt", "r") as file:
    cancelresponse4 = file.read()
    print(cancelresponse4)
    return(cancelresponse4)
def cancelresponse5():
  with open("cancel6.txt", "r") as file:
    cancelresponse5 = file.read()
    print(cancelresponse5)
    return(cancelresponse5)
def lockedacc():
  with open("locked.txt", "r") as file:
    lockedacc = file.read()
    print(lockedacc)
    return(lockedacc)
def lockedresponse():
  with open("locked1.txt", "r") as file:
    lockedresponse = file.read()
    print(lockedresponse)
    return(lockedresponse)
def lockedresponse1():
  with open("locked2.txt", "r") as file:
    lockedresponse1 = file.read()
    print(lockedresponse1)
    return(lockedresponse1)
def lockedresponse2():
  with open("locked3.txt", "r") as file:
    lockedresponse2 = file.read()
    print(lockedresponse2)
    return(lockedresponse2)
def lockedresponse3():
  with open("locked5.txt", "r") as file:
    lockedresponse3 = file.read()
    print(lockedresponse3)
    return(lockedresponse3)
def lockedresponse4():
  with open("locked6.txt", "r") as file:
    lockedresponse4 = file.read()
    print(lockedresponse4)
    return(lockedresponse4)
def lockedresponse5():
  with open("locked7.txt", "r") as file:
    lockedresponse5 = file.read()
    print(lockedresponse5)
    return(lockedresponse5)
def lockedresponse6():
  with open("locked8.txt", "r") as file:
    lockedresponse6 = file.read()
    print(lockedresponse6)
    return(lockedresponse6)
def rewardpt():
  with open("reward.txt", "r") as file:
    reward = file.read()
    print(reward)
    return(reward)
def rewardpt1():
  with open("reward1.txt", "r") as file:
    rewardres = file.read()
    print(rewardres)
    return(rewardres)
def rewardpt2():
  with open("reward2.txt", "r") as file:
    rewardres1 = file.read()
    print(rewardres1)
    return(rewardres1)
def rewardpt3():
  with open("reward3.txt", "r") as file:
    rewardres2 = file.read()
    print(rewardres2)
    return(rewardres2)
def rewardpt4():
  with open("reward4.txt", "r") as file:
    rewardres3 = file.read()
    print(rewardres3)
    return(rewardres3)
def seat1():
  with open("seat1.txt", "r") as file:
    s1 = file.read()
    print(s1)
    return(s1)

def seatoptionbasedonflightnumber():
    df = pd.read_sql_query("select FlightNumber,DepartureTime,SeatingOption from Users order by DepartureTime asc", con)
    print(df.head)
    con.commit()


def n1():
    df = pd.read_sql_query("select FlightNumber from Users", con)
    print(df.head)
    con.commit()

def economyoptions():
    seating_option = 'economy'
    df = pd.read_sql_query("select * from Users where SeatingOption = 'Economy'", con)
    print(df.head)
    con.commit()



def pr():
    seating_option = 'premium economy'
    df = pd.read_sql_query("select * from Users where SeatingOption = 'Premium Economy'", con)
    print(df.head)
    con.commit()

def seatnumber():
  with open("seat.txt", "r") as file:
    s = file.read()
    print(s)
    return(s)

def s2():
  with open("seat2.txt", "r") as file:
    s2 = file.read()
    print(s2)
    return(s2)

def seat3():
  with open("seat3.txt", "r") as file:
    s3 = file.read()
    print(s3)
    return(s3)

def seat4():
  with open("seat4.txt", "r") as file:
    s4 = file.read()
    print(s4)
    return(s4)

def new():
  with open("new.txt", "r") as file:
    n21 = file.read()
    print(n21)
    return(n21)

def new1():
  with open("new1.txt", "r") as file:
    n2 = file.read()
    print(n2)
    return(n2)

def new3():
  with open("new3.txt", "r") as file:
    n3 = file.read()
    print(n3)
    return(n3)

def new4():
  with open("new4.txt", "r") as file:
    n4 = file.read()
    print(n4)
    return(n4)


def new5():
    con = db.connect('new.sqlite')
    df = pd.read_sql_query("select PreferredDate1,PreferredDate2,PreferredDate3,Departure,Destination from Users order by NumberOfTravelers = 1", con)
    print(df.head)
    con.commit()

def new6():
    con = db.connect('new.sqlite')
    df = pd.read_sql_query("select PriceOption1,PriceOption2,PriceOption3 From Users", con)
    print(df.head)
    con.commit()

def new7():
  with open("new5.txt", "r") as file:
    n5 = file.read()
    print(n5)
    return(n5)

def new8():
  with open("new6.txt", "r") as file:
    n8 = file.read()
    print(n8)
    return(n8)

def new9():
  with open("new7.txt", "r") as file:
    n9 = file.read()
    print(n9)
    return(n9)

def new10():
  with open("new8.txt", "r") as file:
    n9 = file.read()
    print(n9)
    return(n9)

def new11():
  with open("new9.txt", "r") as file:
    n9 = file.read()
    print(n9)
    return(n9)

def schedule():
  with open("schedule.txt", "r") as file:
    sc = file.read()
    print(sc)
    return(sc)

def schedule1():
  with open("schedule1.txt", "r") as file:
    sc1 = file.read()
    print(sc1)
    return(sc1)


def schedule2():
  with open("schedule2.txt", "r") as file:
    sc2 = file.read()
    print(sc2)
    return(sc2)


def schedule3():
  with open("schedule3.txt", "r") as file:
    sc3 = file.read()
    print(sc3)
    return(sc3)

def schedule4():
  with open("schedule4.txt", "r") as file:
    sc4 = file.read()
    print(sc4)
    return(sc4)

def schedule5():
  with open("schedule5.txt", "r") as file:
    sc5 = file.read()
    print(sc5)
    return(sc5)

def schedule6():
  with open("schedule6.txt", "r") as file:
    sc6 = file.read()
    print(sc6)
    return(sc6)


def schedule7():
  with open("schedule7.txt", "r") as file:
    sc7 = file.read()
    print(sc7)
    return(sc7)

def forgot():
  with open("forgot.txt", "r") as file:
    f = file.read()
    print(f)
    return(f)

def forgot1():
  with open("forgot1.txt", "r") as file:
    f1 = file.read()
    print(f1)
    return(f1)


def forgot2():
  with open("forgot2.txt", "r") as file:
    f2 = file.read()
    print(f2)
    return(f2)


def forgot3():
  with open("forgot3.txt", "r") as file:
    f3 = file.read()
    print(f3)
    return(f3)

def forgot4():
  with open("forgot4.txt", "r") as file:
    f4 = file.read()
    print(f4)
    return(f4)

def elite():
  with open("elite.txt", "r") as file:
    e = file.read()
    print(e)
    return(e)

def elite1():
  with open("elite1.txt", "r") as file:
    e1 = file.read()
    print(e1)
    return(e1)


def elite2():
  with open("elite2.txt", "r") as file:
    e2 = file.read()
    print(e2)
    return(e2)


def elite3():
  with open("elite3.txt", "r") as file:
    e3 = file.read()
    print(e3)
    return(e3)

def missing():
  with open("missing.txt", "r") as file:
    m = file.read()
    print(m)
    return(m)

def missing1():
  with open("missing1.txt", "r") as file:
    m1 = file.read()
    print(m1)
    return(m1)

def missing2():
  with open("missing2.txt", "r") as file:
    m2 = file.read()
    print(m2)
    return(m2)

def missing3():
  with open("missing3.txt", "r") as file:
    m3 = file.read()
    print(m3)
    return(m3)


def missing4():
  with open("missing4.txt", "r") as file:
    m4 = file.read()
    print(m4)
    return(m4)

def missing5():
  with open("missing5.txt", "r") as file:
    m5 = file.read()
    print(m5)
    return(m5)

def child():
  with open("meal.txt", "r") as file:
    ch = file.read()
    print(ch)
    return(ch)

def child1():
  with open("meal1.txt", "r") as file:
    ch1 = file.read()
    print(ch1)
    return(ch1)

def child2():
  with open("meal2.txt", "r") as file:
    ch2 = file.read()
    print(ch2)
    return(ch2)


def child3():
  with open("meal3.txt", "r") as file:
    ch3 = file.read()
    print(ch3)
    return(ch3)

def child4():
  with open("meal4.txt", "r") as file:
    ch4 = file.read()
    print(ch4)
    return(ch4)

def child5():
  with open("meal5.txt", "r") as file:
    ch5 = file.read()
    print(ch5)
    return(ch5)

def dam():
  with open("damage.txt", "r") as mile:
    d = mile.read()
    print(d)
    return(d)

def dam1():
  with open("damage1.txt", "r") as mile:
    d1 = mile.read()
    print(d1)
    return(d1)

def dam2():
    con = db.connect('damage.sqlite')
    df = pd.read_sql_query("select PassengerName,ContactInfo,FlightNumber,DateOfIncident,AirportName,ReportedAtAirport,BaggageDescription from Users WHERE ClaimID= '001' ", con)
    print(df.head)
    con.commit()

def dam3():
  with open("damage2.txt", "r") as mile:
    d2 = mile.read()
    print(d2)
    return(d2)


def dam4():
  with open("damage3.txt", "r") as mile:
    d3 = mile.read()
    print(d3)
    return(d3)



def special():
  with open("special.txt", "r") as file:
    sp = file.read()
    print(sp)
    return(sp)


def special2():
  with open("special2.txt", "r") as file:
    sp2 = file.read()
    print(sp2)
    return(sp2)
def special3():
  with open("special3.txt", "r") as file:
    sp3 = file.read()
    print(sp3)
    return(sp3)
def special4():
  with open("special4.txt", "r") as file:
    sp4 = file.read()
    print(sp4)
    return(sp4)
def special5():
  with open("special5.txt", "r") as file:
    sp5 = file.read()
    print(sp5)
    return(sp5)
def special6():
  with open("special6.txt", "r") as file:
    sp6 = file.read()
    print(sp6)
    return(sp6)
def special7():
  with open("special7.txt", "r") as file:
    sp7 = file.read()
    print(sp7)
    return(sp7)
def special8():
  with open("special8.txt", "r") as file:
    sp8 = file.read()
    print(sp8)
    return(sp8)
def natural():
    with open("natural.txt", "r") as file:
      na = file.read()
      print(na)
      return(na)
def natural1():
    with open("natural1.txt", "r") as file:
      na1 = file.read()
      print(na1)
      return(na1)
def natural2():
    with open("natural2.txt", "r") as file:
      na2 = file.read()
      print(na2)
      return(na2)
def natural3():
    with open("natural3.txt", "r") as file:
      na3 = file.read()
      print(na3)
      return(na3)
def natural4():
    with open("natural4.txt", "r") as file:
      na4 = file.read()
      print(na4)
      return(na4)
def natural5():
    with open("natural5.txt", "r") as file:
      na5 = file.read()
      print(na5)
      return(na5)
def doc():
    with open("doc.txt", "r") as file:
      dc = file.read()
      print(dc)
      return(dc)
def doc1():
    with open("doc1.txt", "r") as file:
      dc1 = file.read()
      print(dc1)
      return(dc1)
def doc2():
    with open("doc2.txt", "r") as file:
      dc2 = file.read()
      print(dc2)
      return(dc2)

def doc3():
      con = db.connect('docu.sqlite')
      df = pd.read_sql_query("select NecessaryDocuments from Users WHERE TravelerType = 'Minor' AND TravelType = 'International'", con)
      print(df.head)
      con.commit()
def doc4():
    with open("doc3.txt", "r") as file:
      dc3 = file.read()
      print(dc3)
      return(dc3)
def doc5():
      con = db.connect('docu.sqlite')
      df = pd.read_sql_query("select NecessaryDocuments from Users WHERE TravelerType = 'Adult' AND TravelType = 'International'", con)
      print(df.head)
      con.commit()
def doc6():
    with open("doc4.txt", "r") as file:
      dc4 = file.read()
      print(dc4)
      return(dc4)
def doc7():
      con = db.connect('docu.sqlite')
      df = pd.read_sql_query("select NecessaryDocuments from Users WHERE TravelerType = 'Student' AND TravelType = 'International'", con)
      print(df.head)
      con.commit()
def doc8():
    with open("doc5.txt", "r") as file:
      dc5 = file.read()
      print(dc5)
      return(dc5)
def doc9():
      con = db.connect('docu.sqlite')
      df = pd.read_sql_query("select NecessaryDocuments from Users WHERE TravelType = 'Domestic'", con)
      print(df.head)
      con.commit()
def doc10():
    with open("doc6.txt", "r") as file:
      dc6 = file.read()
      print(dc6)
      return(dc6)
def doc11():
    with open("doc7.txt", "r") as file:
      dc7 = file.read()
      print(dc7)
      return(dc7)
def doc12():
    with open("doc8.txt", "r") as file:
      dc8 = file.read()
      print(dc8)
      return(dc8)
def doc13():
    with open("doc9.txt", "r") as file:
      dc9 = file.read()
      print(dc9)
      return(dc9)
def connect():
    with open("connect.txt", "r") as file:
      ct = file.read()
      print(ct)
      return(ct)
def connect1():
    with open("connect1.txt", "r") as file:
      ct1 = file.read()
      print(ct1)
      return(ct1)
def connect2():
    with open("connect2.txt", "r") as file:
      ct2 = file.read()
      print(ct2)
      return(ct2)
def connect3():
    with open("connect3.txt", "r") as file:
      ct3 = file.read()
      print(ct3)
      return(ct3)
def connect4():
    with open("connect4.txt", "r") as file:
      ct4 = file.read()
      print(ct4)
      return(ct4)
def resi():
    with open("restricted.txt", "r") as file:
      res = file.read()
      print(res)
      return(res)
def resi1():
    with open("restricted1.txt", "r") as file:
      res1 = file.read()
      print(res1)
      return(res1)
def resi2():
    with open("restricted2.txt", "r") as file:
      res2 = file.read()
      print(res2)
      return(res2)
def resi3():
    with open("restricted3.txt", "r") as file:
      res3 = file.read()
      print(res3)
      return(res3)
def resi4():
    with open("restricted4.txt", "r") as file:
      res4 = file.read()
      print(res4)
      return(res4)
def resi5():
    with open("restricted5.txt", "r") as file:
      res5 = file.read()
      print(res5)
      return(res5)
def resi6():
    with open("restricted6.txt", "r") as file:
      res6 = file.read()
      print(res6)
      return(res6)
def lead():
    with open("lead.txt", "r") as file:
      le = file.read()
      print(le)
      return(le)
def lead1():
    with open("lead1.txt", "r") as file:
      le1 = file.read()
      print(le1)
      return(le1)
def lead2():
    with open("lead2.txt", "r") as file:
      le2 = file.read()
      print(le2)
      return(le2)
def lead3():
    with open("lead3.txt", "r") as file:
      le3 = file.read()
      print(le3)
      return(le3)
def lead4():
    with open("lead4.txt", "r") as file:
      le4 = file.read()
      print(le4)
      return(le4)
def lead5():
    with open("lead5.txt", "r") as file:
      le5 = file.read()
      print(le5)
      return(le5)
def lead6():
    with open("lead6.txt", "r") as file:
      le6 = file.read()
      print(le6)
      return(le6)
def lead7():
    with open("lead7.txt", "r") as file:
      le7 = file.read()
      print(le7)
      return(le7)
def lead8():
    with open("lead8.txt", "r") as file:
      le8 = file.read()
      print(le8)
      return(le8)
def lead9():
    with open("lead9.txt", "r") as file:
      le9 = file.read()
      print(le9)
      return(le9)
def bistro():
    with open("bistro.txt", "r") as file:
      bs = file.read()
      print(bs)
      return(bs)
def bistro1():
    with open("bistro1.txt", "r") as file:
      bs1 = file.read()
      print(bs1)
      return(bs1)
def bistro2():
    with open("bistro2.txt", "r") as file:
      bs2 = file.read()
      print(bs2)
      return(bs2)
def bistro3():
    with open("bistro3.txt", "r") as file:
      bs3 = file.read()
      print(bs3)
      return(bs3)
def voucher():
    with open("voucher.txt", "r") as file:
      vc = file.read()
      print(vc)
      return(vc)
def voucher1():
    with open("voucher1.txt", "r") as file:
      vc1 = file.read()
      print(vc1)
      return(vc1)
def voucher2():
    with open("voucher2.txt", "r") as file:
      vc2 = file.read()
      print(vc2)
      return(vc2)
def voucher3():
    with open("voucher3.txt", "r") as file:
      vc3 = file.read()
      print(vc3)
      return(vc3)
def festive():
    with open("festive.txt", "r") as file:
      fe = file.read()
      print(fe)
      return(fe)
def festive1():
    with open("festive1.txt", "r") as file:
      fe1 = file.read()
      print(fe1)
      return(fe1)
def festive2():
    with open("festive2.txt", "r") as file:
      fe2 = file.read()
      print(fe2)
      return(fe2)
def festive3():
    with open("festive3.txt", "r") as file:
      fe3 = file.read()
      print(fe3)
      return(fe3)
def festive4():
    with open("festive4.txt", "r") as file:
      fe4 = file.read()
      print(fe4)
      return(fe4)
def festive5():
    with open("festive5.txt", "r") as file:
      fe5 = file.read()
      print(fe5)
      return(fe5)
def festive6():
    with open("festive6.txt", "r") as file:
      fe6 = file.read()
      print(fe6)
      return(fe6)
def festive7():
    with open("festive7.txt", "r") as file:
      fe7 = file.read()
      print(fe7)
      return(fe7)
def promo():
    with open("promotion.txt", "r") as file:
      pr = file.read()
      print(pr)
      return(pr)
def promo1():
    with open("promotion1.txt", "r") as file:
      pr1 = file.read()
      print(pr1)
      return(pr1)
def promo2():
    with open("promotion2.txt", "r") as file:
      pr2 = file.read()
      print(pr2)
      return(pr2)
def promo3():
    with open("promotion3.txt", "r") as file:
      pr3 = file.read()
      print(pr3)
      return(pr3)
def promo4():
    with open("promotion4.txt", "r") as file:
      pr4 = file.read()
      print(pr4)
      return(pr4)
def promo5():
    with open("promotion5.txt", "r") as file:
      pr5 = file.read()
      print(pr5)
      return(pr5)
def promo6():
    with open("promotion6.txt", "r") as file:
      pr6 = file.read()
      print(pr6)
      return(pr6)
def promo7():
    with open("promotion7.txt", "r") as file:
      pr7 = file.read()
      print(pr7)
      return(pr7)
def wifi():
    with open("wifi.txt", "r") as file:
      wf = file.read()
      print(wf)
      return(wf)
def wifi1():
    with open("wifi1.txt", "r") as file:
      wf1 = file.read()
      print(wf1)
      return(wf1)
def wifi2():
    with open("wifi2.txt", "r") as file:
      wf2 = file.read()
      print(wf2)
      return(wf2)
def wifi3():
    with open("wifi3.txt", "r") as file:
      wf3 = file.read()
      print(wf3)
      return(wf3)
def wifi4():
    with open("wifi4.txt", "r") as file:
      wf4 = file.read()
      print(wf4)
      return(wf4)
def wifi5():
    with open("wifi5.txt", "r") as file:
      wf5 = file.read()
      print(wf5)
      return(wf5)
def wifi6():
    with open("wifi6.txt", "r") as file:
      wf6 = file.read()
      print(wf6)
      return(wf6)
def family():
    with open("family.txt", "r") as file:
      fa = file.read()
      print(fa)
      return(fa)
def family1():
    with open("family1.txt", "r") as file:
      fa1 = file.read()
      print(fa1)
      return(fa1)
def family2():
    with open("family2.txt", "r") as file:
      fa2 = file.read()
      print(fa2)
      return(fa2)
def family3():
    with open("family3.txt", "r") as file:
      fa3 = file.read()
      print(fa3)
      return(fa3)
def family4():
    with open("family4.txt", "r") as file:
      fa4 = file.read()
      print(fa4)
      return(fa4)
def check():
    with open("checkin.txt", "r") as file:
      ch = file.read()
      print(ch)
      return(ch)
def check1():
    with open("checkin1.txt", "r") as file:
      ch1 = file.read()
      print(ch1)
      return(ch1)
def check2():
    with open("checkin2.txt", "r") as file:
      ch2 = file.read()
      print(ch2)
      return(ch2)
def check3():
    with open("checkin3.txt", "r") as file:
      ch3 = file.read()
      print(ch3)
      return(ch3)
def check4():
    with open("checkin4.txt", "r") as file:
      ch4 = file.read()
      print(ch4)
      return(ch4)
def check5():
    with open("checkin5.txt", "r") as file:
      ch5 = file.read()
      print(ch5)
      return(ch5)
def hotel():
    with open("hotel.txt", "r") as file:
      hl = file.read()
      print(hl)
      return(hl)
def hotel1():
    with open("hotel1.txt", "r") as file:
      hl1 = file.read()
      print(hl1)
      return(hl1)
def hotel2():
    with open("hotel2.txt", "r") as file:
      hl2 = file.read()
      print(hl2)
      return(hl2)
def hotel3():
    with open("hotel3.txt", "r") as file:
      hl3 = file.read()
      print(hl3)
      return(hl3)
def hotel4():
    with open("hotel4.txt", "r") as file:
      hl4 = file.read()
      print(hl4)
      return(hl4)
def hotel5():
    with open("hotel5.txt", "r") as file:
      hl5 = file.read()
      print(hl5)
      return(hl5)
def hotel6():
    with open("hotel6.txt", "r") as file:
      hl6 = file.read()
      print(hl6)
      return(hl6)
def hotel7():
    with open("hotel7.txt", "r") as file:
      hl7 = file.read()
      print(hl7)
      return(hl7)
def hotel8():
    with open("hotel8.txt", "r") as file:
      hl8 = file.read()
      print(hl8)
      return(hl8)
def reco():
    with open("recommend.txt", "r") as file:
      rec = file.read()
      print(rec)
      return(rec)
def reco1():
    with open("recommend1.txt", "r") as file:
      rec1 = file.read()
      print(rec1)
      return(rec1)
def reco2():
    with open("recommend2.txt", "r") as file:
      rec2 = file.read()
      print(rec2)
      return(rec2)
def reco3():
    with open("recommend3.txt", "r") as file:
      rec3 = file.read()
      print(rec3)
      return(rec3)
def reco4():
    with open("recommend4.txt", "r") as file:
      rec4 = file.read()
      print(rec4)
      return(rec4)
def reco5():
    with open("recommend5.txt", "r") as file:
      rec5 = file.read()
      print(rec5)
      return(rec5)
def cart():
    with open("cart.txt", "r") as file:
      cr = file.read()
      print(cr)
      return(cr)
def cart1():
    with open("cart1.txt", "r") as file:
      cr1 = file.read()
      print(cr1)
      return(cr1)
def cart2():
    with open("cart2.txt", "r") as file:
      cr2 = file.read()
      print(cr2)
      return(cr2)
def cart3():
    with open("cart3.txt", "r") as file:
      cr3 = file.read()
      print(cr3)
      return(cr3)
def cart4():
    with open("cart4.txt", "r") as file:
      cr4 = file.read()
      print(cr4)
      return(cr4)
def cart5():
    with open("cart5.txt", "r") as file:
      cr5 = file.read()
      print(cr5)
      return(cr5)
def cart6():
    with open("cart6.txt", "r") as file:
      cr6 = file.read()
      print(cr6)
      return(cr6)
def cart7():
    with open("cart7.txt", "r") as file:
      cr7 = file.read()
      print(cr7)
      return(cr7)
def addb():
    with open("add.txt", "r") as file:
      ad = file.read()
      print(ad)
      return(ad)
def addb1():
    with open("add1.txt", "r") as file:
      ad1 = file.read()
      print(ad1)
      return(ad1)
def addb2():
    with open("add2.txt", "r") as file:
      ad2 = file.read()
      print(ad2)
      return(ad2)
def addb3():
    with open("add3.txt", "r") as file:
      ad3 = file.read()
      print(ad3)
      return(ad3)
def addb4():
    with open("add4.txt", "r") as file:
      ad4 = file.read()
      print(ad4)
      return(ad4)
def addb5():
    with open("add5.txt", "r") as file:
      ad5 = file.read()
      print(ad5)
      return(ad5)
def upgrade():
    with open("upgrade.txt", "r") as file:
      up = file.read()
      print(up)
      return(up)
def upgrade1():
    with open("upgrade1.txt", "r") as file:
      up1 = file.read()
      print(up1)
      return(up1)
def upgrade5():
    with open("upgrade5.txt", "r") as file:
      up5 = file.read()
      print(up5)
      return(up5)
def upgrade2():
    with open("upgrade2.txt", "r") as file:
      up2 = file.read()
      print(up2)
      return(up2)
def upgrade3():
    with open("upgrade3.txt", "r") as file:
      up3 = file.read()
      print(up3)
      return(up3)
def upgrade4():
    with open("upgrade4.txt", "r") as file:
      up4 = file.read()
      print(up4)
      return(up4)
def transfer():
    with open("transfer.txt", "r") as file:
      tr = file.read()
      print(tr)
      return(tr)
def transfer1():
    with open("transfer1.txt", "r") as file:
      tr1 = file.read()
      print(tr1)
      return(tr1)
def transfer2():
    with open("transfer2.txt", "r") as file:
      tr2 = file.read()
      print(tr2)
      return(tr2)
def transfer3():
    with open("transfer3.txt", "r") as file:
      tr3 = file.read()
      print(tr3)
      return(tr3)
def transfer4():
    with open("transfer4.txt", "r") as file:
      tr4 = file.read()
      print(tr4)
      return(tr4)
def transfer5():
    with open("transfer5.txt", "r") as file:
      tr5 = file.read()
      print(tr5)
      return(tr5)
def follow():
    with open("followup.txt", "r") as file:
      fp = file.read()
      print(fp)
      return(fp)
def follow1():
    with open("followup1.txt", "r") as file:
      fp1 = file.read()
      print(fp1)
      return(fp1)
def follow2():
    with open("followup2.txt", "r") as file:
      fp2 = file.read()
      print(fp2)
      return(fp2)
def follow3():
    with open("followup3.txt", "r") as file:
      fp3 = file.read()
      print(fp3)
      return(fp3)
def follow4():
    with open("followup4.txt", "r") as file:
      fp4 = file.read()
      print(fp4)
      return(fp4)
def follow5():
    with open("followup5.txt", "r") as file:
      fp5 = file.read()
      print(fp5)
      return(fp5)
def existing():
    with open("existing.txt", "r") as file:
      ex = file.read()
      print(ex)
      return(ex)
def existing1():
    with open("existing1.txt", "r") as file:
      ex1 = file.read()
      print(ex1)
      return(ex1)
def existing2():
    with open("existing2.txt", "r") as file:
      ex2 = file.read()
      print(ex2)
      return(ex2)
def existing3():
    with open("existing3.txt", "r") as file:
      ex3 = file.read()
      print(ex3)
      return(ex3)
def existing4():
    with open("existing4.txt", "r") as file:
      ex4 = file.read()
      print(ex4)
      return(ex4)
def existing5():
    with open("existing5.txt", "r") as file:
      ex5 = file.read()
      print(ex5)
      return(ex5)
def flightpass():
    with open("pass.txt", "r") as file:
      ps = file.read()
      print(ps)
      return(ps)
def flightpass1():
    with open("pass1.txt", "r") as file:
      ps1 = file.read()
      print(ps1)
      return(ps1)
def flightpass2():
    with open("pass2.txt", "r") as file:
      ps2 = file.read()
      print(ps2)
      return(ps2)
def flightpass3():
    with open("pass3.txt", "r") as file:
      ps3 = file.read()
      print(ps3)
      return(ps3)
def flightpass4():
    with open("pass4.txt", "r") as file:
      ps4 = file.read()
      print(ps4)
      return(ps4)
def flightpass5():
    with open("pass5.txt", "r") as file:
      ps5 = file.read()
      print(ps5)
      return(ps5)
def flightpass6():
    with open("pass6.txt", "r") as file:
      ps6 = file.read()
      print(ps6)
      return(ps6)
def ref():
      con = db.connect('refund_123.sqlite')
      df = pd.read_sql_query("select FlightDetails,ReasonforRefund,RefundAmountRequested,RefundEligibility,RequestDate,AdditionalNotes from Users where TicketNumber = 'AC123456'", con)
      print(df.head)
      con.commit()
def ref1():
    with open("refund.txt", "r") as file:
      r = file.read()
      print(r)
      return(r)
def ref2():
      con = db.connect('refund_123.sqlite')
      df = pd.read_sql_query("SELECT FlightDetails,ReasonforRefund,RefundAmountRequested,RequestDate,AdditionalNotes,AdditionalNotes,TicketNumber from Users where RefundEligibility = 'No'", con)
      print(df.head)
      con.commit()
def ref3():
    with open("refund1.txt", "r") as file:
      r1 = file.read()
      print(r1)
      return(r1)
def ref4():
      con = db.connect('refund_123.sqlite')
      df = pd.read_sql_query("select ReasonforRefund from Users ", con)
      print(df.head)
      con.commit()
def ref5():
      con = db.connect('refund_123.sqlite')
      df = pd.read_sql_query("select AdditionalNotes,TicketNumber,FlightDetails,ReasonforRefund,RefundAmountRequested,RequestDate from Users where RefundAmountRequested = '1200'", con)
      print(df.head)
      con.commit()
def ref6():
      con = db.connect('refund_123.sqlite')
      df = pd.read_sql_query("select ContactInformation from Users", con)
      print(df.head)
      con.commit()
def ref7():
    with open("refund2.txt", "r") as file:
      r2 = file.read()
      print(r2)
      return(r2)
def ref8():
    with open("refund4.txt", "r") as file:
      r3 = file.read()
      print(r3)
      return(r3)
def ref9():
    with open("refund3.txt", "r") as file:
      r4 = file.read()
      print(r4)
      return(r4)
def pet():
    with open("pet.txt", "r") as file:
      p = file.read()
      print(p)
      return(p)
def pet1():
    with open("pet1.txt", "r") as file:
      p1 = file.read()
      print(p1)
      return(p1)
def pet2():
    with open("pet2.txt", "r") as file:
      p2 = file.read()
      print(p2)
      return(p2)
def pet3():
    with open("pet3.txt", "r") as file:
      p3 = file.read()
      print(p3)
      return(p3)
def pet4():
    with open("pet4.txt", "r") as file:
      p4 = file.read()
      print(p4)
      return(p4)
def pet5():
    with open("pet5.txt", "r") as file:
      p5 = file.read()
      print(p5)
      return(p5)
def pet6():
    with open("pet6.txt", "r") as file:
      p6 = file.read()
      print(p6)
      return(p6)
def carry():
    with open("carry.txt", "r") as file:
      cr = file.read()
      print(cr)
      return(cr)
def carry1():
    with open("carry1.txt", "r") as file:
      cr1 = file.read()
      print(cr1)
      return(cr1)
def carry2():
    with open("carry2.txt", "r") as file:
      cr2 = file.read()
      print(cr2)
      return(cr2)
def carry3():
    with open("carry3.txt", "r") as file:
      cr3 = file.read()
      print(cr3)
      return(cr3)
def carry4():
    with open("carry4.txt", "r") as file:
      cr4 = file.read()
      print(cr4)
      return(cr4)
def carry5():
    with open("carry5.txt", "r") as file:
      cr5 = file.read()
      print(cr5)
      return(cr5)
def suggest():
    with open("sug.txt", "r") as file:
      su = file.read()
      print(su)
      return(su)
def suggest1():
    with open("sug1.txt", "r") as file:
      su1 = file.read()
      print(su1)
      return(su1)
def suggest2():
    with open("sug2.txt", "r") as file:
      su2 = file.read()
      print(su2)
      return(su2)
def suggest3():
    with open("sug3.txt", "r") as file:
      su3 = file.read()
      print(su3)
      return(su3)
def suggest4():
    with open("sug4.txt", "r") as file:
      su4 = file.read()
      print(su4)
      return(su4)
def suggest5():
    with open("sug5.txt", "r") as file:
      su5 = file.read()
      print(su5)
      return(su5)
def suggest6():
    with open("sug6.txt", "r") as file:
      su6 = file.read()
      print(su6)
      return(su6)
def suggest7():
    with open("sug7.txt", "r") as file:
      su7 = file.read()
      print(su7)
      return(su7)
def suggest8():
    with open("sug8.txt", "r") as file:
      su8 = file.read()
      print(su8)
      return(su8)
def access():
    with open("acc.txt", "r") as file:
      ac = file.read()
      print(ac)
      return(ac)
def access1():
    with open("acc1.txt", "r") as file:
      ac1 = file.read()
      print(ac1)
      return(ac1)
def access2():
    with open("acc2.txt", "r") as file:
      ac2 = file.read()
      print(ac2)
      return(ac2)
def access3():
    with open("acc3.txt", "r") as file:
      ac3 = file.read()
      print(ac3)
      return(ac3)
def access4():
    with open("acc4.txt", "r") as file:
      ac4 = file.read()
      print(ac4)
      return(ac4)
def access5():
    with open("acc5.txt", "r") as file:
      ac5 = file.read()
      print(ac5)
      return(ac5)
def maple():
    with open("maple.txt", "r") as file:
      ml = file.read()
      print(ml)
      return(ml)
def maple1():
    with open("maple1.txt", "r") as file:
      ml1 = file.read()
      print(ml1)
      return(ml1)
def maple2():
    with open("maple2.txt", "r") as file:
      ml2 = file.read()
      print(ml2)
      return(ml2)
def maple3():
    with open("maple3.txt", "r") as file:
      ml3 = file.read()
      print(ml3)
      return(ml3)







for i in range(5):

    key = filter()


    if key =='cancel flight ticket' or key == 'canceling their flight ticket' or key =='cancel flight reservation airline' or key =='cancellation flight ticket' or key == 'cancel airline ticket' or key == 'process cancellation flight ticket' or key == 'cancel flight ticket airline' or key == 'cancel' or key =='flight ticket' or key == 'cancel flight ticket' or key == 'canceling a booking' or key == 'cancel booking' or key == 'don’t want fly' or key == 'cancel reservation' or key == 'cancel booking' or key == 'cancel PNR' or key == 'cancel ticket' or key == ' cancel reservation' or key == 'cancel flights' :
      a = A()
      Z2 = input(" Any more questions ")
      a1 = filter2(Z2)
      print(a1)
      if a1 == 'abc123' or a1 == 'booking reference number' :
       b = cancelresponse()
       Z2 = input(" Any more questions ")
       a2 = filter2(Z2)
       print(a2)
       if a2 == 'correct' or a2 == 'carry' or a2 == 'affirmative' or a2 == 'certainly' or a2 == 'absolutely' or a2 == 'ofcourse' :
        c = cancelresponse1()
        Z1 = input(" Any more questions ")
        a3 = filter1(Z1)

        if  a3 == 'please proceed' or a3 == 'sure go ahead' or a3 == 'please continue' or a3 == 'continue' or a3 == 'feel free go':
          d =cancelresponse2()
          Z1 = input(" Any more questions ")
          a4 = filter1(Z1)

          if a4 == 'alright thank' or a4 == 'thanks':
              e = cancelresponse3()
              Z1 = input(" Any more questions ")
              a5 = filter1(Z1)

              if a5 == 'no all thanks again' or a5 == 'no questions':
               f = cancelresponse4()
               Z1 = input(" Any more questions ")
               a6 = filter1(Z1)

               if a6 == 'bye':
                cancelresponse5()

    elif key == 'locked' or key == 'problems logging app account' or  key == 'signing app' or key == 'log app account' or key == 'verification code' or key == 'login' or key == 'logging in' or key =='login issues' or key == 'trouble loggin in' or key =='issues logging app account' or key == 'issues logging app account' or key == 'struggling access app account login issues' or key == 'difficulties signing account app' or key == 'login problems app account' or key == 'unable sign app account successfully' or key == 'experiencing login troubles app' or key == 'issue accessing app account' or key == 'facing problems logging app' or key == 'unable access account via app' or key == 'login issues app account' or key == 'struggling log account app' or key =='issues logging app account' or key == 'trouble signing app' or key =='log app account' or key =='experiencing problems logging app account' or key == 'locked account' or key == 'account locked' or key == 'locked account' or key == 'verification code' or key == 'verification code' or key == 'verification code' or key == 'login' or key == 'logging'  or key == 'login' or key == 'logging account' or key == 'logging account' or key == 'login problem' or key == 'problem logging' or key == 'login problem' or key == 'trouble loggin' or key == 'trouble loggin' or key == 'trouble loggin' or key == 'trouble login' or key == 'trouble loggin account' or key == 'book new flight ticket' or key == 'new flight reservation' or key == 'requesting book new airline ticket' or key == 'reserve new flight ticket':

         a = lockedacc()
         Z1 = input(" Any more questions ")
         key1 = filter1(Z1)
         if  key1 == 'abcc' :
          b = lockedresponse()
          Z1 = input(" Any more questions ")
          l2 = filter1(Z1)
          if l2 == 'sure wait' or l2 == 'certainly wait' or l2 == 'sure thing wait.' or l2 == 'no worries wait':
            c =lockedresponse1()
            Z1 = input(" Any more questions ")
            l3 = filter1(Z1)

            if l3 == 'code' or l3 == 'please otp code' or l3 == 'one time password' or l3 == 'send otp code' or l3 == 'kindly otp code' or l3 == 'otp code':
              d = lockedresponse2()
              Z1 = input(" Any more questions ")
              l4 = filter1(Z1)
              if l4 == 'received code 123456' :
                e = lockedresponse3()
                Z1 = input(" Any more questions ")
                l5 = filter1(Z1)

                if l5 == 'sure' or l5 == 'certain' or l5 == 'confident' or l5 == 'assured' or l5 == 'convinced':
                  f = lockedresponse4()
                  Z1 = input(" Any more questions ")
                  l6 = filter1(Z1)
                  if l6 == 'reset password' or l6 == 'generate new password' or l6 == 'reset login credentials' or l6 == 'refresh password' or l6 == 'retrieve password' or l6 == 'modify password' or l6 == 'set new password' or l6 == 'create new password' :
                    g = lockedresponse5()
                    Z1 = input(" Any more questions ")
                    l7 = filter1(Z1)

                    if l7 == 'set' or l7 =='preset' or l7 == 'settled' or l7 == 'resolute' or l7 == 'firm':
                      h = lockedresponse6()
                      Z1 = input(" Any more questions ")
                      l8 = filter1(Z1)

                      if l8 == 'thanks bye':
                            lockedresponse6()

    elif key =='reward points exact' or key == 'reward points points available' or key == 'accessed reward points exact number points' or key == 'availed reward points sure precise count' or key == 'redeemed reward points unsure total balance' or key == 'reward points uncertain exact value' or key == 'reward points exact points' or key =='accessed reward points unsure exact figure' or key =='redeemed reward points unsure precise number' or key == 'reward points aware exact total' or key == 'availed reward points certain exact balance' or key == 'reward points precise amount' or key == '' or key == '' or key == 'reward points' or key =='redeemed reward points unsure exact balance' or key == 'reward points total points available' or key == 'reward points total points available' or key == 'reward points uncertain exact number' or key == '' :
        a = rewardpt()
        Z1 = input(" Any more questions ")
        r1 = filter1(Z1)

        if r1 == 'Sure membership number' or r1 == 'membership number 123456789' or r1 == 'membership number 123345556':
            b = rewardpt1()
            Z1 = input(" Any more questions ")
            r2 = filter1(Z1)

            if r2 == 'sure hold' or r2 == 'secure grip' or r2 == 'firm hold' or r2 == 'tight grasp' or r2 == 'strong clutch' or r2 == 'steady hold' or r2 == 'reliable hold' :
              c = rewardpt2()
              Z1 = input(" Any more questions ")
              r3 = filter1(Z1)

              if r3 == 'great' or r3 == 'excellent' or r3 == 'outstanding' or r3 =='exceptional' or r3 == 'remarkable' or r3 == 'superb' or r3 == 'brilliant' :
                d = rewardpt3()
                Z1 = input(" Any more questions ")
                r4 = filter1(Z1)

                if r4 == 'right now thanks info' or r4 == 'informations' or r4 == 'right now thanks information':
                     rewardpt4()



    elif key=='planning book flight' or key == 'please seat assignment air canada trip' or key == 'appreciate booking reserving seat upcoming air canada journey' or key == 'reaching out book seat upcoming air canada flight' or key == 'request selecting seat travel air canada' or key == 'seat reservation flight' or  key == 'seat flight canada' or key == 'process booking seat upcoming trip' or key == 'please seat upcoming travel' or key == 'assist booking seat scheduled flight' or key=='seat' or key =='seat selection' or key == 'reserve seat upcoming journey' :
        a = seat1()
        Z1 = input(" Any more questions ")
        z1 = filter1(Z1)

        if z1=='seating options benefits' or z1 == 'upsides seat configurations' or z1 == 'merits seat availability' or z1 == 'positive aspects seating options' or z1 == 'features available seating choices' or z1 == 'rewards seating preferences' or z1 == 'advantages seating options' or z1 == 'perks seat selections' or z1 == 'benefits seat arrangements' or z1 == 'seat options' or z1 == 'seat choices' or z1 == 'seating availability' or z1 == 'seating availability' or z1 == 'seat alternatives' or z1 == 'seating varieties' or z1 == 'seat configurations' or z1 == 'seating preferences' or z1 == 'seating choices' or z1 == 'seating arrangements' or z1 == 'seat selections' or z1=='seating options benefits based flight number' :
            b = seatoptionbasedonflightnumber()
            Z1 = input(" Any more questions ")
            a1 = filter1(Z1)

            if a1 == 'flight alternatives day' or a1 == 'available flight options day' or a1 == 'available flight selections today' or a1 == 'different flight options today' or a1 == 'flight choices available day' or a1 == 'various flight options available day' or a1=='seating options travel newyork california' :
              c = n1()
              Z1 = input(" Any more questions ")
              b1 = filter1(Z1)

              if b1=='economy' or b1 == 'available economy ticket options' or b1 == 'economy pricing options available' or b1 == 'different economy plans available' or b1 == 'available economy categorie' or b1 == 'economy class options available' or b1 == 'various economy class choices available here' or b1  == 'available economy fare options' or b1=='economyoption' or b1 == 'available economy selections' or b1 == 'economy seating options available' or b1 == 'various economy options available' or b1 == 'different economy choices available':
                d =economyoptions()
                Z1 = input(" Any more questions ")
                c1 = filter1(Z1)

                if c1=='premium' or c1 == '' or c1 == 'various premium economy seating choices available here' or c1 == 'premium economy class options available' or c1 == 'premium economy fare options available' or c1 == 'available premium economy selections' or c1=='premium economy' or c1 == 'premium economy choices available' or c1 == 'different premium economy options offered here' :
                  e=pr()
                  Z1 = input(" Any more questions ")
                  d1 = filter1(Z1)

                  if d1 == 'check availability' or d1 == 'checking availability' :
                    f = seatnumber()
                    Z1 = input(" Any more questions ")
                    e1 = filter1(Z1)

                    if e1 == 'yz123' or e1 == 'reference' :
                      g = s2()
                      Z1 = input(" Any more questions ")
                      f1 = filter1(Z1)

                      if f1 == 'please' or f1 == 'definitely' :
                        h = seat3()
                        Z1 = input(" Any more questions ")
                        g1 = filter1(Z1)

                        if g1 == 'perfect thanks':
                          seat4()



    elif key=='book flight' or key == 'new' or key == 'new booking' or key== 'new reservation' or key == 'new ticket' or key == 'booking' or key == 'book travel' or key == 'book' or key == 'buy ticket' or key == 'purchase ticket' or key == 'purchase new ticket' or key == 'make reservation' or key == 'book flight' or key == 'book flights' or key == 'flight reservation' or key == 'booking flight' or key == 'flight ticket' or key == 'interested scheduling flight' or key == 'assist reserving flight' or key == 'flight booking' or key == 'book flight assistance' or key == 'organize flight reservation' or key == 'flight booking' :
        a = new()
        Z1 = input(" Any more questions ")
        d1 = filter1(Z1)

        if d1=='sure flying newyork los angeles' or d1=='certainly traveling york los angeles' or d1 == 'sure departure city newyork destination los angeles' or d1 == 'travel newyork los angeles' or d1 == 'flying out newyork los angeles destination' or d1 == 'book trip departing newyork arriving los angeles' or d1 =='of course flight newyork los angeles' or d1 == 'journey newyork los angeles' or d1 == 'travel route newyork los angeles' or d1 == 'desired travel plan newyork los angeles' or d1 == 'flight newyork los angeles' :
            b = new1()
            Z1 = input(" Any more questions ")
            d2 = filter1(Z1)

            if d2 == 'return journey' or d2 == 'round journey' or d2 == 'return trip' or d2 == 'two way trip' or d2 == 'circular trip' or d2 == 'out back journey' or d2 == 'complete journey' or d2 == 'two way travel' or d2 == 'return travel' or d2 == 'back forth trip':
                    c = new3()
                    Z1 = input(" Any more questions ")
                    d3 = filter1(Z1)
                    print(d3)
                    if d3 == 'departure dates december return dates december january' or d3 == 'travel dates include december departure december january return' or d3 == 'leaving december returns december january ' or d3 == 'outbound dates december inbound dates december january' or d3 == 'proposed travel schedule depart december return december january' or d3 == 'preferred departure days december return options december january' or d3 == 'traveling outbound december back december january' or d3 == 'dates interest departing december returns december january' or d3 == 'flight dates include departures december returns december january ' or d3 == 'scheduled travel dates december departure december january return' :
                      d = new4()
                      Z1 = input(" Any more questions ")
                      d4 = filter1(Z1)
                      print(d4)
                      if d4 == 'only myself' or d4 == 'sole traveler' or d4 == 'traveling alone' or d4 == 'only one myself' or d4== 'traveling individually' :
                        e = new5()
                        Z1 = input(" Any more questions ")
                        d5 = filter1(Z1)

                        if d5 == 'pricing options include economy business first class' or d5 == 'prices vary based preferred dates return travel available' or d5 == 'multiple options suitable needs different preferences available premium options' or d5 == 'assist selection offer best suitable rates match requirements detailed options based schedule' :
                          f = new6()
                          g = new7()
                          Z1 = input(" Any more questions ")
                          d6 = filter1(Z1)

                          if d6 == 'book economy class ticket december departure december' or d6 == 'economy class booking confirmed december 20 departure december 27 return' or d6 == 'december 20 december 27 economy class ticket confirmed' or d6 == 'booking economy class ticket december 20 december 27 preferred dates' or d6 == 'choosing economy class ticket december 20 departure december 27 return' or d6 == 'economy class option selected december 20 december 27 departure return' or d6 == 'booking economy class december 20 departure december 27 return completed' or d6 == 'economy class flight booked december 20 december 27 departure return' or d6 == 'confirming booking economy class december 20 departure december 27 return' or d6 == 'selecting economy class december 20 december 27 departure return ' or d6 == 'economy class ticket december 20 departure december 27 return selected ':
                             h = new8()
                             i = new9()
                             Z1 = input(" Any more questions ")
                             d7 = filter1(Z1)

                             if d7 == 'perfect':
                                j = new10()
                                Z1 = input(" Any more questions ")
                                d8 = filter1(Z1)

                                if d8 == 'no thank you':
                                 new11()
    elif key == 'check details upcoming travel' or key == 'time change' or key == 'flight cancellation' or key == 'flight cancelled' or key == 'email notification' or key == 'rebooked' or key == 'rebook' or key == 'alternate options' or key == 'schedule change policy' or key == 'flight disruptions' or key == 'schedule changes' or key == 'flight changed' or key == 'review details upcoming trip' or key == 'reaching out details scheduled travel' or key == 'assist verifying information upcoming journey' or key == 'check specifics travel itinerary' or key == 'schedule upcoming flight' or key == 'verify details booked trip' or key == 'review itinerary upcoming travel' or key == 'checking details planned journey' or key == 'ensure that details travel accurate' or key == 'reaching out review schedule upcoming travel' :


            a = schedule()
            Z1 = input(" Any more questions ")
            fd = filter1(Z1)


            if fd == 'abc' or fd == 'booking reference number' :
              b = schedule1()
              c = schedule2()
              Z1 = input(" Any more questions ")
              fd1 = filter1(Z1)
              print(fd1)
              if fd1 == 'schedule change timing' or fd1 == 'been change schedule updated timing' or fd1 == 'noticed schedule change departure time' or fd1 == 'departure time' or fd1 == 'revised timing updated schedule' or fd1 == 'details updated schedule timings' or fd1 == 'understand schedule changed' or fd1 == 'updated timing' or fd1 == 'departure time schedule change' or fd1 == 'inform revised timing adjusted schedule' or fd1 == 'updated timing following schedule adjustment' or fd1 == 'departure arrival timings after change' or fd1 == 'clarify timing after schedule modification':
                d = schedule3()
                Z1 = input(" Any more questions ")
                fd2 = filter1(Z1)

                if fd2 == 'see arrival time affected' or fd2 == 'understood arrival time been adjusted well' or fd2 == 'see arrival time affected' or fd2 == ' arrival time changed' or fd2 == 'acknowledged update arrival time too' or fd2 == 'schedule change impacted arrival time' or fd2== 'thank you arrival time been modified' or fd2 == 'noted arrival time following adjustment' or fd2 == 'understand arrival time rescheduled' or fd2 == 'arrival time updated' or fd2 == 'thanks information' or fd2 == 'arrival timing different' or fd2 == 'clarify arrival time affected' or fd2 == 'understood arrival time adjusted well' :
                 e = schedule4()
                 Z1 = input(" Any more questions ")
                 fd3 = filter1(Z1)

                 if fd3 == 'fine anything schedule' or fd3 == 'understand if arrival time changed' or fd3 == 'see arrival time changed' or fd3 == 'noted update arrival time' or fd3 == 'understood schedule adjustment impacted arrival time' or fd3 == 'clarify arrival time revised' or fd3 == 'thank update arrival time different' or fd3 == 'acknowledged. arrival time rescheduled' or fd3 == 'see schedule affects arrival time' or fd3 == 'revised timing applicable arrival well' or fd3 == 'thank you arrival time updated' or fd3=='' == 'understand. arrival time adjusted well' or fd3 == 'see arrival time affected':
                   f = schedule5()
                   Z1 = input(" Any more questions ")
                   fd4 = filter1(Z1)

                   if fd4 == 'perfect thank letting':
                      g = schedule6()
                      Z1 = input(" Any more questions ")
                      fd5 = filter1(Z1)

                      if fd5 == 'bye no questions' :
                          schedule7()

    elif key == 'hello account as forgotten password assist' or key == 'account forgotten password assist' or key == 'trouble accessing account forgotten password' or key == 'log account forgot password' or key == 'account forgotten password appreciated' or key == 'logging account misplaced password support' or key == 'seem forgotten account password login assistance' or key == 'account forgotten password resolve' or key == 'lost account forgot password resetting' or key == 'log account remember password' or key ==  'facing issue account forgotten password' or key == 'forgot account password login assist resetting' :
            a = forgot()
            b = forgot1()
            Z1 = input(" Any more questions ")
            fp = filter1(Z1)

            if fp == 'please send link' or fp == 'please link' or fp == 'certainly expecting link please send' or fp == 'sending link greatly appreciated' or fp == 'absolutely please link' or fp == 'ready receive link kindly send over' or fp == 'please ahead send link' or fp == 'grateful link' or fp == 'thanks appreciate send link' or fp == 'certainly please send link your earliest convenience' or fp == 'kindly proceed sending link' or fp == 'booking reference number' :
              c = forgot2()
              Z1 = input(" Any more questions ")
              fp1 = filter1(Z1)

              if fp1 == 'got next' or fp1 == 'next' or fp1 == 'understood next steps' or fp1 == 'thank next step take' or fp1 == 'acknowledged' or fp1 == 'noted please advise next course action' or fp1 == 'understand clarify comes next thank information actions take next' or fp1 == 'guidance next steps' or fp1 == 'understood recommend here' or fp1 == 'noted proceed' or fp1 == 'thank next action' :
                d = forgot3()
                Z1 = input(" Any more questions ")
                fp2 = filter1(Z1)

                if fp2 == 'sincerely appreciate' or fp2 == 'thank your' or fp2 == 'thanks your' :
                 e = forgot4()

    elif key == 'loyal appreciate detail benefits expect next journey' or key == 'frequent understand benefits entitled next journey' or key == 'shed light exclusive services qualify ready upcoming travels' or key == 'preparing another trip information benefits available elite member' or key == 'finalize plans next journey elaborate advantages offered frequent travelers' or key == 'comprehensive summary elite privileges enjoy next trip' or key == 'frequent understand benefits entitled next journey' or key == 'ready upcoming trip clarify exclusive services take advantage' or key == 'detail perks eligible prepare next travel experience' or key == 'frequent flyer appreciate it if outline benefits available next journey' or key == 'frequent prepare next journey elaborate benefits entitled' or key == 'plan upcoming trip detailed overview privileges qualify':
                a = elite()
                Z1 = input(" Any more questions ")
                e1 = filter1(Z1)

                if e1 == 'great further expect lounge' or e1 == 'amazing depth description lounge privileges' or e1 == 'fantastic love features lounge' or e1 == 'impressive clarify perks included lounge' or e1 == 'sounds wonderful detailed overview lounge services' or e1 == 'impressed additional insights lounge facilities' or e1 == 'intrigued lounge works' or e1 == 'excellent details amenities offered lounge' or e1 == 'fascinating elaborate lounge includes' or e1 == 'impressive details lounge' or e1 == 'sounds amazing information lounge benefits' :
                    b = elite1()
                    Z1 = input(" Any more questions ")
                    e2 = filter1(Z1)

                    if e2 == 'grateful information usually travel multiple bags baggage privileges' or e2 == 'thank perfect travel multiple bags frequently elaborate baggage allowance benefits' or e2 == 'very reassuring sure these privileges thank comprehensive information' or e2 == 'thankful often multiple bags traveling specifics baggage allowance eligible' or e2 == 'thank much someone often travels additional luggage clarify baggage allowance entitlements' or e2 == 'much appreciated detailed overview baggage allowance benefits frequent flyers' or e2 == 'thanks lot understand extra baggage allowances available' or e2 == 'grateful information usually travel multiple bags baggage privileges' or e2 == 'thank very helpful insights baggage policies frequent travelers' or e2 == 'appreciate frequently carry extra luggage baggage allowance benefits detail' or e2 == 'thanks great hear elaborate further benefits related additional baggage allowance' or e2 == 'thank wonderful often travel multiple bags details baggage allowance perks' or e2 == 'thank perfect travel multiple bags frequently elaborate baggage allowance benefits' :
                        c = elite2()
                        Z = input(" Any more questions ")
                        e3 = filter1(Z)

                        if e3 == 'very reassuring sure these privileges thank comprehensive information' or e3 == 'excellent news ensure most these perks thank providing such comprehensive overview' or e3 == 'find very reassuring point these benefits thank detailed insight' or e3 == 'incredibly helpful sure take full advantage these benefits thank detailed explanation' or e3 == 'very comforting definitely these privileges thanks thorough information' :
                            elite3()
    elif key == 'missing points' or key == 'missing miles' or key == 'missing transaction' or key == 'claim missing points' or key == 'claim missing flights' or key == 'credit flights' or key == 'credit account' or key == 'noticed discrepancy reward points balance request resolve' or key == 'believe reward points unaccounted clarify' or key == 'identified issue missing reward points account assistance' or key == 'seem missing reward points addressing issue' or key == 'discovered few reward points reflecting account resolve' or key ==  'reaching out noticed missing reward points account assist' or key == 'seems reward points missing account rectify' or key == 'realized reward points absent guidance' or key == 'contacting regarding missing reward points assist resolving issue' or key == 'noticed reward points missing issue' or key == 'portion reward points appears missing. assist matter' :
            a = missing()
            b = missing1()
            Z1 = input(" Any more questions ")
            fp = filter1(Z1)

            if fp == 'please send link' or fp == 'please link' or fp == 'certainly expecting link please send' or fp == 'sending link greatly appreciated' or fp == 'absolutely please link' or fp == 'ready receive link kindly send over' or fp == 'please ahead send link' or fp == 'grateful link' or fp == 'thanks appreciate send link' or fp == 'certainly please send link your earliest convenience' or fp == 'kindly proceed sending link' or fp == 'booking reference number' :
              c = missing2()
              Z1 = input(" Any more questions ")
              fp6 = filter1(Z1)

              if fp6 == '600112544':
                d = missing3()
                Z1 = input(" Any more questions ")
                fp1 = filter1(Z1)

                if fp1 == 'next' or fp1 == 'understood next steps' or fp1 == 'thank next step take' or fp1 == 'acknowledged' or fp1 == 'noted please advise next course action' or fp1 == 'understand clarify comes next thank information actions take next' or fp1 == 'guidance next steps' or fp1 == 'understood recommend here' or fp1 == 'noted proceed' or fp1 == 'thank next action' :
                 e = missing4()
                 Z1 = input(" Any more questions ")
                 fp2 = filter1(Z1)

                 if fp2 == 'sincerely appreciate' or fp2 == 'thanks your' :
                   f = missing4()

    elif key == 'Child traveling alone' or key == 'unaccompanied' or key == 'unaccompanied minor' or key == 'unaccompanied child' or key == 'unaccompanied minor fee' or key == 'unaccompanied minor service' or key == 'teenager traveling alone' or key == 'unaccompanied teenager' or key == 'unaccompanied traveller service' == 'special amenities discounts available children traveling' or key == 'traveling little one soon services offers tailored children' or key == 'traveling child wanted ask kid friendly facilities discounts' or key == 'let special arrangements benefits families children' or key == 'travel little one curious discounts child specific services' or key == 'special perks discounted rates traveling children' or key == 'flying child offer perks benefits kid' or key == 'special facilities discounts families traveling children' or key == 'traveling little one wondering child specific services offers available' or key == 'traveling child wanted special provisions discounts kids' or key == 'traveling little one wanted check special facilities discounts available children' :

                a = child()
                Z1 = input(" Any more questions ")
                cl = filter1(Z1)

                if cl == 'incredible describe options available keep children entertained traveling' or cl == 'delightful love learn entertainment facilities offered children' or cl == 'amazing further details kids entertained trip' or cl == 'excellent curious entertainment arrangements children' or cl == 'sounds perfect games activities available kids' or cl == 'wonderful information entertainment options kids journey' or cl == 'fantastic entertainment facilities designed children' or cl == 'sounds great details activities entertainment kids' or cl == 'sounds wonderful entertainment facilities kids' or cl == 'amazing elaborate entertainment options available children' or cl == 'sounds great details activities entertainment kids' or cl == 'fantastic entertainment facilities designed children' or cl == 'wonderful information entertainment options kids journey' or cl == 'great hear kind entertainment provided children' or cl == 'sounds perfect games activities available kids' or cl == 'excellent curious entertainment arrangements children' or cl == 'amazing further details kids entertained trip' or key == 'delightful love learn entertainment facilities offered children' or cl == 'incredible describe options available keep children entertained traveling' :
                  b = child1()
                  Z1 = input(" Any more questions ")
                  cl1 = filter1(Z1)

                  if cl1 == 'really nice meals kids child very particular palate' or cl1 == 'awesome childrens meal options little one bit fussy meals' or cl1 == 'sounds great meal arrangements kids child quite choosy food' or cl1 == 'amazing meal options children child often specific food preferences' or cl1 == 'sounds good details children meals little one picky eater' or cl1 == 'sounds good details childrens meals little one picky eater' or cl1 == 'excellent meal choices kids child quite selective eat' or cl1 == 'wonderful elaborate food options children child tends fussy eater' or cl1 == 'great hear kind meals available kids little one quite particular food' or cl1 == 'fantastic meal options children child specific preferences' or cl1 == 'great meals child picky eater' :
                    c = child2()
                    Z1 = input(" Any more questions ")
                    cl2 = filter1(Z1)

                    if cl2 == 'love clarify take advantage priority boarding' or cl2 == 'very useful steps priority boarding' or cl2 == 'helpful benefit priority boarding service' or cl2 == 'additionally priority boarding option' or cl2 == 'perfect avail priority boarding facility' or cl2 == 'helpful avail priority boarding' or cl2 == 'great priority boarding service' :
                        d = child3()
                        Z1 = input(" Any more questions ")
                        cl3 = filter1(Z1)

                        if cl3 == 'abcde' or cl3 == 'booking reference number' :
                              e = child4()
                              Z1 = input(" Any more questions ")
                              cl4 = filter1(Z1)

                              if cl4 == 'thank much' :
                                f = child5()



    elif key == 'luggage damaged supposed' or key == 'shocked bag bad condition process' or key == 'ridiculous suitcase destroyed resolve issue' or key == 'suitcase completely ruined unacceptable now' or key == '' or key == 'outrageous suitcase wrecked next' or key == 'believe luggage been ruined options' or key == 'believe badly suitcase damaged handle' or key == 'bag terrible shape expected now' or key =='upset luggage completely damaged next step' or key == 'totally destroyed' or key == 'believe suitcase completely ruined supposed now':
            a = dam()
            Z1 = input(" Any more questions ")
            da1 = filter1(Z1)

            if da1 == 'airport' or da1 == 'incident airport itself' or da1 == 'occurred airport' or da1 == 'airport grounds' or da1 == 'damage occurred airport' or da1 == 'took place airport' or da1 == 'issue right airport' or da1 == 'damage occurred right airport' or da1 == 'took place airport':
                b = dam1()

                Z1 = input(" Any more questions ")
                da2 = filter1(Z1)

                if da2 == 'flight number ac additional specifics' or da2 == 'flight ac other details please' or da2 == 'flight ac mine other specifics' or da2 == 'flight ac supply remaining information' or da2 == 'traveling ac other details' or da2 == 'flight number ac related information' or da2 == 'flying ac details' or da2 == 'flight number ac other details' or da2 == 'flight ac further details' or da2 == 'flight ac additional details' or da2 == 'flight ac other information' :
                  c = dam2()
                  Z1 = input(" Any more questions ")
                  da3 = filter1(Z1)

                  if da3 == 'mentioned details right next steps' or da3 == 'agree details provided correct move' or da3 == 'everything seems accurate process continue' or da3 == 'checked details correct next course action' or da3 == 'details accurate side advise next steps' or da3 == 'information provided correct done next' or da3 == 'details appear correct proceed' or da3 == 'accuracy given information next' or da3 == '' or da3 == 'mentioned details correct proceed' or da3 == 'verify provided details accurate next step' or da3 == 'details correct proceed' :
                    d = dam3()
                    Z1 = input(" Any more questions ")
                    da4 = filter1(Z1)

                    if da4 == 'now thanks':
                      dam4()
    elif key == 'musical Instrument' or key == 'cello' or key == 'guitar' or key == 'hunting equipment' or key == 'sports equipment' or key == 'archery' or key == 'bows' or key == 'arrow' or key == 'avalanche' or key == 'bat' or key == 'balls' or key == 'bicycles' or key == 'boating equipment' or key == 'fishing equipment' or key == 'boogies board' or key == 'skateboard' or key == 'broomball' or key == 'curling' or key == 'climbing gear'or key == 'equestrian equipment' or key == 'fencing' or key == 'firearms for hunting' or key == 'golf clubs' or key == 'hammer' or key == 'hockey' or key == 'lacrosse' or key == 'ringette' or key == 'cricket' or key == 'skates'or key == 'kayak' or key == 'parachutes' or key == 'pole vaults' or key == 'javelin' or key == 'hang glider'or key == 'luge' or key == 'windsurfing' or key == 'traveling special item information' or key == 'guidance traveling special item' or key == 'bringing special item details' or key == 'rules traveling special item' or key == 'information carrying special item trip' or key == 'travel special item' or key == 'process bringing special item flight' or key == 'special item travel guidance' or key == 'understanding requirements traveling special item' or key == 'assist information carrying special item onboard' or key == 'traveling soon special item policies' :
            a = special()
            Z1 = input(" Any more questions ")
            sp1 = filter1(Z1)


            if sp1 =='extra fee traveling guitar' or sp1 == 'additional charges carrying guitar' or sp1 == 'costs associated bringing guitar board' or sp1 == 'fees apply transporting guitar flight' or sp1 == 'details extra costs checking guitar' or sp1 == 'additional cost carrying guitar trip' or sp1 == 'much pay bring guitar' or sp1 == 'fee structure traveling guitar special item' or sp1 == 'handling charges guitar flight' or sp1 == 'charges traveling guitar baggage' :
                  b = special2()
                  Z1 = input(" Any more questions ")
                  sp2 = filter1(Z1)
                  if sp2 == 'traveling fragile painting' or sp2 == 'delicate painting bring' or sp2 == 'special item carrying fragile painting' or sp2 == 'transporting delicate painting trip' or sp2 == 'bringing fragile painting flight' or sp2 == 'traveling delicate painting' or sp2 == 'item carrying fragile piece artwork' or sp2 == 'take delicate painting' or sp2 == 'painting extra care traveling' or sp2 == 'flying fragile painting guidance' :
                    c = special3()
                    Z1 = input(" Any more questions ")
                    sp3 = filter1(Z1)

                    if sp3 == 'other fees aware' or sp3 == 'extra charges added' or sp3 == 'other costs associated' or sp3 == 'additional fee consider' or sp3 == 'further charges hidden extra costs involved' or sp3 == 'other charges pay' or sp3 == 'fees apart ones mentioned' or sp3 == 'clarify other fees applicable' or sp3 == 'expect further costs beyond':
                      d = special4()
                      e = special5()
                      Z1 = input(" Any more questions ")
                      sp4 = filter1(Z1)

                      if sp4 == 'thank include booking' or sp4 == 'information great please add booking' or sp4 == 'helpful proceed adding booking' or sp4 == 'thanks details include item booking' or sp4 == 'clarified things add booking now' or sp4 == 'information proceed adding booking' or sp4 == 'exactly needed please add booking' or sp4 == 'thanks explaining d move adding booking' or sp4 == 'great assist adding booking' or sp4 == 'been helpful d finalize adding booking':
                        f = special6()
                        Z1 = input(" Any more questions ")
                        sp5 = filter1(Z1)

                        if sp5 == 'thanks helpful reference number abc' or sp5 == 'code abc' or sp5 == 'great thank number abc' or sp5 == 'thanks your abc' or sp5 == 'useful information booking reference abc' or sp5 == 'thanks helpful code abc' or sp5 == 'great hear reference abc' or sp5 == 'thank booking abc' or sp5 == 'clarification reservation code abc' or sp5 == 'thanks now reference number abc':
                          g = special7()
                          Z1 = input(" Any more questions ")
                          sp6 = filter1(Z1)

                          if sp6 == 'your' or sp6 == 'thank your'  or sp6 == 'thanks lot your'  or sp6 == 'grateful your'  or sp6 == 'thank your'  or sp6 == 'thank'  or sp6 == 'thanks your time'  or sp6 == 'thankful your'  or sp6 == 'thanks much assisting'  or sp6 == 'helping out':
                            h = special8()
    elif key == 'supposed fly january th but heard might cancellations check flight' or key == 'booked fly january th but heard cancellations flight status' or key == 'flight scheduled january th ve heard cancellations check flight affected' or key == 'flight january th heard cancellations weather verify mine cancelled' or key == 'supposed fly january th but ve heard possible cancellations check flight' or key == 'flying january th heard chance cancellations check flight impacted' or key == 'flight booked january th concerned cancellations status flight' or key == 'scheduled fly january th ve heard flights cancelled check mine one' or key == 'fly january th ve heard might cancellations verify whether flight' or key == 'flight january th ve heard cancellations weather mine affected' or key == 'flight january th ve been hearing potential cancellations check operating' :
            a =natural()
            Z1 = input(" Any more questions ")
            nl = filter1(Z1)
            if nl == 'rebook flight please' or n1 == 'reschedule flight please' or n1 == 'assist rebooking flight' or n1 == ' change flight booking please' or n1 == ' book flight travel please' or n1 == 'rebooking flight'or n1 == ' change date flight please' or n1 == ' please rebooking ticket' or n1 == 'flight please' or n1 == 'assist changing flight details' or n1 == ' adjust flight plans rebook flight':
                  b = natural1()
                  Z1 = input(" Any more questions ")
                  nl1 = filter1(Z1)
                  if nl1 == 'fly january th preferably afternoon' or nl1 == 'prefer fly january th ideally afternoon' or nl1 == 'book flight january th preferably afternoon' or nl1 == 'schedule flight january th preferably afternoon' or nl1 == 'fly january th ideally afternoon' or nl1 == 'travel january th preference afternoon' or nl1 == 'book flight january th afternoon' or nl1 == 'flight january th ideally afternoon' or nl1 == 'prefer fly january th afternoon possible' or nl1 == 'schedule flight january th ideally afternoon' or nl1 == 'fly january th preferably afternoon time slot' :
                    c = natural2()
                    d = natural3()
                    Z1 = input(" Any more questions ")
                    nl2 = filter1(Z1)

                    if nl2 == 'please ahead' or nl2 == 'please proceed' or nl2 == 'ahead booking' or nl2 ==  'feel free ahead' or nl2 == 'please continue arrangement' or nl2 ==  'proceed booking' or nl2 == 'please carry' or nl2 == 'please ahead' or nl2 == 'please move' or nl2 ==  'ahead finalize booking' or nl2 == 'ahead necessary changes' :

                      e = natural4()
                      Z1 = input(" Any more questions ")
                      sp4 = filter1(Z1)

                      if sp4 == 'no thank' or sp4 == 'thank' or sp4 == 'set thanks' or sp4 == 'good now thank' or sp4 == 'nothing else thanks' or sp4 == 'everything thank' or sp4 == 'finished thanks' or sp4 == 'done now thank' or sp4 == 'no further requests thank' :
                        natural5()
    elif key == 'traveling soon documents carry' or key == 'documents bring upcoming trip' or key == 'travel documents prepare journey' or key == 'flying soon required documents' or key == 'list documents trip' or key == 'paperwork upcoming flight' or key == 'understand documents necessary travel' or key == 'documents carry travel plans' or key == 'documents bring along upcoming journey' or key == 'checklist travel documents' or key == 'clarify documents required trip' :
            a = doc()
            Z1 = input(" Any more questions ")
            d1 = filter1(Z1)


            if d1 == 'international flight' or d1 == 'traveling abroad flight'  or d1 == 'overseas trip'  or d1 =='flight international destination'  or d1 == 'flying out country' or d1 == 'journey international flight'  or d1 == 'traveling internationally trip'  or d1 == 'flight taking outside country'  or d1 == 'flight foreign destination'  or d1 == 'travel involves crossing international borders'  or d1 == 'going different country flight' :
                  b= doc1()
                  Z1 = input(" Any more questions ")
                  d2 = filter1(Z1)

                  if d2 == 'traveling child minor' or d2 == 'traveling child under' or d2 == 'going trip minor child' or d2 == 'travel plans include child minor' or d2 == 'taking child adult trip' or d2 == 'traveling underage child' or d2 == 'flying child minor' or d2 == 'going abroad child under years old' or d2 == 'minor child accompanying trip' or d2 == 'travel child reached adulthood' or d2 == 'child minor traveling' :
                    c = doc2()
                    d = doc3()
                    Z1 = input(" Any more questions ")
                    d3 = filter1(Z1)
                    if d3 == 'got adult traveling internationally' or d3 == 'documents adult international travel' or d3 == 'requirements adult flying internationally' or d3 == 'paperwork necessary adult traveling abroad' or d3 == 'required documents international trip adult' or d3 == 'list documents adult international travel' or d3 == 'adult carry international flight' or d3 == 'adult traveling internationally' or d3 == 'documents required adult international journey' or d3 == 'documents needed adult traveling another country' or d3 == 'travel requirements adult going international trip' :
                      e = doc4()
                      f = doc5()
                      Z1 = input(" Any more questions ")
                      d4 = filter1(Z1)

                      if d4 == 'helpful students traveling internationally' or d4 == 'documents student international travel' or d4 == 'list requirements student traveling abroad' or d4 == 'paperwork necessary student traveling internationally' or d4 == 'required documents student flying internationally' or d4 == 'travel document checklist students going abroad' or d4 == 'student carry international trip' or d4 == 'student traveling another country' or d4 == 'required documents international student travel' or d4 == 'travel requirements students heading overseas' or d4 == 'documents needed student traveling internationally' :
                        g = doc6()
                        h = doc7()
                        Z1 = input(" Any more questions ")
                        d5 = filter1(Z1)

                        if d5 == 'great domestic travel quick summary' or d5 == 'summarize document requirements domestic travel' or d5 == 'documents needed domestic trip' or d5 == 'quick rundown required domestic travel' or d5 == 'carry domestic flight' or d5 == 'list necessary documents traveling domestically' or d5 == 'paperwork needed domestic journey' or d5 == 'requirements traveling within country' or d5 == 'document requirements domestic flight' or d5 == 'brief summary needed domestic travel' or d5 == 'traveling domestically' :
                            i = doc8()
                            j = doc9()
                            k = doc10()
                            Z1 = input(" Any more questions ")
                            d6 = filter1(Z1)

                            if d6 == 'helpful' or d6 == 'helpful assist' or d6 == 'your appreciated' or d6 == 'your great grateful your' or d6 == 'assist helpful' or d6 == 'your valuable' or d6 == 'thankful' or d6 == 'your really useful assist' or d6 == 'really your matter' :
                              l = doc11()
                              Z1 = input(" Any more questions ")
                              d7 = filter1(Z1)

                              if d7 == 'example com' or d7 == 'mailto example com' :
                                  m = doc12()
                                  Z1 = input(" Any more questions ")
                                  d8 = filter1(Z1)

                                  if d8 == 'no thank' :
                                    n =doc13()
    elif key =='connecting flight bit unsure after first flight process' or key == 'traveling connecting flight after first flight' or key == 'steps follow after first flight connecting flight' or key == 'connecting flights work after land first flight' or key == 'layover sure next clarify' or key == 'after initial flight whats process catching connecting flight' or key == 'bit confused connecting flights work' or key == 'once finish first flight board next one' or key == 'instructions handling connecting flight after land' or key == 'steps take after first flight connection' or key == 'connecting flight unsure next steps' :
          a = connect()
          Z1 = input(" Any more questions ")
          cn = filter1(Z1)


          if cn == 'got baggage pick up recheck' or cn == 'collect baggage check again connecting flight' or cn == 'pick up luggage after first flight connection' or cn == 'baggage automatically transferred next flight' or cn == 'recheck bags connecting flight' or cn == 'happens luggage when connecting flight' or cn == 'baggage sent directly final destination claim' or cn == 'handle luggage between first flight connection' or cn ==  'bags transferred automatically next flight' or cn == 'necessary pick up recheck baggage layover' or cn == 'checked baggage automatically manage myself' :
              b = connect1()
              Z1 = input(" Any more questions ")
              cn1 = filter1(Z1)

              if cn1 == 'helpful gate changes' or cn1 == 'gate flight gets changed' or cn1 == 'handle gate change connecting flight' or cn1 == 'happens boarding gate updated' or cn1 == 'theres change gate' or cn1 == 'gate changes' or cn1 == 'whats procedure flight gate switched different one' or cn1 == 'stay updated case theres gate change flight' or cn1 == 'steps take gate assignment changes' or cn1 == 'gate flight changes find one' or cn1 == 'deal gate change airport' :
                c = connect2()
                Z1 = input(" Any more questions ")
                cn2 = filter1(Z1)
                if cn2 == 'thank miss connecting flight' or cn2 == 'miss connecting flight' or cn2 ==  'process fail catch connection' or cn2 == 'happens connecting flight time' or cn2 ==  'handle situation miss second flight' or cn2 ==  'whats procedure cant board connecting flight' or cn2 == 'contact miss connecting flight' or cn2 == 'miss connection options' or cn2 ==  'whats next step catch connecting flight' or cn2 ==  'case miss connecting flight' or cn2 == 'expect next flight':
                  d = connect3()
                  Z1 = input(" Any more questions ")
                  cn3 = filter1(Z1)
                  if cn3 == 'reassuring thanks explaining everything clearly' or cn3 == 'really comforting thank explaining well' or cn3 ==  'explanation its very reassuring' or cn3 ==  'thanks making easy understandthis really helps explained' or cn3 == 'perfectly puts mind ease thank' or cn3 ==  'everything much clearer thanks reassurance' or cn3 ==  'feel much confident now thanks explanation' or cn3 == 'clarityits very helpful comforting thank' or cn3 == 'made simple understand really' or cn3 == 'thanks breaking do wn well its very reassuring' or cn3 == 'explanation really helps put ease thank much' :
                      connect4()
    elif key == 'wanted ask restricted items flight allowed carry' or key == 'items restricted flight' or key == ' information prohibited items air travel' or key == ' things allowed bring flight' or key == ' items restricted when flying' or key == ' rules restricted items trip'or key == ' unsure allowed flight clarify' or key == ' items restricted air travel' or key == ' items shouldn carry flight assist' or key == 'specific things bring plane' or key == 'items prohibited travel upcoming flight':
            a = resi()
            Z1 = input(" Any more questions ")
            res = filter1(Z1)
            if res == 'power bank snacks allowed' or res == 'power banks snacks permitted flights' or res == 'bring power bank snacks plane' or res == 'snacks power bank carry traveling' or res == 'take both snacks power bank flight' or res == 'restrictions carrying power bank snacks' or res == 'face issues bringing snacks power bank board' or res == 'power banks snacks allowed travel' or res == 'permitted carry snacks power bank flight' or res == 'problem carrying snacks power bank trip' or res == 'snacks power banks typically allowed flights':
                  b = resi1()
                  Z1 = input(" Any more questions ")
                  res1 = filter1(Z1)
                  if res1 == 'please' or res1 == 'sure great' or res1 == 'please thank' or res1 == 'helpful' or res1 == 'definitely' or res1 == 'ahead check please' or res1 == 'sure love information' or res1 == 'thanks offering check' or res1 == 'please check':
                    c = resi2()
                    Z1 = input(" Any more questions ")
                    res3 = filter1(Z1)
                    if res3 == 'flying abc airlines united states check rules' or res3 == 'flight abc airlines check rules' or res3 == 'traveling abc airlines find out policies' or res3 == 'check abc airlines rules flights' or res3 == 'flying abc airlines restricted items' or res3 == 'airline abc airlines heading up rules' or res3 == 'flying abc airlines united states verify policies' or res3 == 'check restricted item rules abc airlines' or res3 == 'traveling abc airlines please check guidelines' or res3 == 'flight abc airlines allowed' or res3 == 'abc airlines flight united states check rules ':
                      d = resi3()
                      Z1 = input(" Any more questions ")
                      res7 = filter1(Z1)
                      if res7 == 'helpful':
                        e = resi4()
                        Z1 = input(" Any more questions ")
                        res5 = filter1(Z1)
                        if res5 == 'got way happens accidentally pack something restricted checked bag' or res5 == 'thanks mistakenly pack restricted item checked luggage' or res5 == 'got happens restricted item checked bag' or res5 == 'understood expect accidentally include restricted item luggage' or res5 == 'thanks info unknowingly put restricted item checked bag' or res5 == 'got checked baggage contains restricted item' or res5 == 'but accidentally put something prohibited checked luggage' or res5 == 'thanks procedure restricted item found checked baggage' or res5 == 'understood happens checked luggage restricted item mistake' or res5 == 'thanks clarification accidentally pack something allowed' or res5 == 'see restricted item mistakenly placed checked bag':

                            f = resi5()
                            Z1 = input(" Any more questions ")
                            res6 = filter1(Z1)
                            if res6 == 'moment thanks your' or res6 ==  'no now thanks assisting' or res6 ==  'right now but thank your' or res6 == 'no questions moment thanks much' or res6 == 'everything now thanks lot' or res6 ==  'no good now thanks your' or res6 ==  'now thanks your' or res6 ==  'no further questions moment thanks your time' or res6 ==  'think thanks' or res6 == 'nothing else now thanks helping out' or res6 == 'good now but thanks lot your':
                              g = resi6()
    elif key == 'just wanted check flight status' or key == 'check status flight' or key == 'flight time' or key == 'current status flight' or key == 'check flight schedule' or key == 'flight time' or key == 'flight status' or key == 'when flight departing' or key == 'check timing flight please' or key == 'current schedule flight' or key == 'departure time flight' :
            a = lead()
            Z1 = input(" Any more questions ")
            ld = filter1(Z1)

            if ld == 'reference lead':
                  b = lead1()
                  Z1 = input(" Any more questions ")
                  lea = filter1(Z1)
                  if lea == 'sms updates great' or lea == 'sure send updates via sms' or lea == 'receive text updates' or lea == 'prefer getting updates sms' or lea == 'please send updates text messages' or lea == 'text updates work thanks' or lea == 'please updates via sms' or lea == 'notifications sms' or lea == 'text message updates helpful' or lea == 'sms notifications sound good please enable' or lea == 'sure take updates via text messages':
                    c = lead2()
                    Z1 = input(" Any more questions ")
                    lea1 = filter1(Z1)
                    if lea1 == 'aware' or lea1 == 'existed details' or lea1 == 'heard before' or lea1 == 'really love learn' or lea1 == 'aware information' or lea1 == 'details' or lea1 == 'interesting hear' or lea1 == 'realize please further' or lea1 == 'information program details aware':
                      d = lead3()
                      lea2 = input(" Any more questions ")
                      cn = filter1(Z1)
                      if lea2 == 'sign up' or lea2 == 'sure please enroll' or lea2 == 'join' or lea2 == 'count program' or lea2 == 'please ahead register' or lea2 == 'love sign up' or lea2 == 'part program' or lea2 == 'sure started' or lea2 == 'please proceed signing up' or lea2 == 'absolutely add program' or lea2 == 'ready join sign up':
                        e = lead4()
                        Z1 = input(" Any more questions ")
                        lea3 = filter1(Z1)
                        if lea3 == 'no benefits' or lea3 == 'perks' or lea3 == ' no tried include' or lea3 == ' familiar included' or lea3 == ' no worth' or lea3 == ' really advantages' or lea3 == 'no experienced benefits' or lea3 == 'gain' or lea3 == 'much overview' or lea3 == ' no looked special offers':
                            f = lead5()
                            Z1 = input(" Any more questions ")
                            lea4 = filter1(Z1)
                            if lea4 == 'sure send details' or lea4 == 'please information' or lea4 == 'see details please send' or lea4 == 'ahead send information' or lea4 == 'please specifics' or lea4 == 'receiving details' or lea4 == 'send full information please' or lea4 == 'sure details' or lea4 == 'send info' or lea4 == 'please details soon possible' or lea4 == ' review specifics':
                              g = lead6()
                              Z1 = input(" Any more questions ")
                              lea5 = filter1(Z1)
                              if lea5 == 'think much cost' or lea5 == 'hadn considered price' or lea5 == 'realize much'  or lea5 == 'thought cost'  or lea5 == 'good point much pay'  or lea5 == 'cross mind pricing'  or lea5 == 'consider cost'  or lea5 == 'interesting much'  or lea5 == 'think price'  or lea5 == 'charge service'  or lea5 == 'thought fee':
                                  h = lead7()
                                  Z1 = input(" Any more questions ")
                                  lea6 = filter1(Z1)
                                  if lea6 == 'add' or lea6 == 'sure please include' or lea6 == 'ahead add' or lea6 == 'please add booking' or lea6 == 'include' or lea6 == 'sure please proceed adding' or lea6 == 'add itinerary please' or lea6 == 'include trip' or lea6 == 'please ahead include' or lea6 == 'absolutely add booking' or lea6 == 'include plan please' :
                                    i = lead8()
                                    Z1 = input(" Any more questions ")
                                    lea7 = filter1(Z1)
                                    if lea7 == 'download now' or lea7 == 'no downloaded now' or lea7 == 'far but right away' or lea7 == 'installed but download now' or lea7 == 'no grab now' or lea7 == ' done download immediately' or lea7 == 'but app now' or lea7 == 'no but install right away' or lea7 == 'but download right now' or lea7 == 'download now since' or lea7 == 'but take care now' :
                                        j = lead9()
    elif key == 'explore bistro meal options available see available family' or key == 'sure check out meal options family' or key == 'menu myself family' or key == 'please meal choices family members' or key == 'see food options family' or key == 'sure available meals family' or key == 'love whats available us flight' or key == 'display meal choices family' or key == 'please see bistro meal options us' or key == 'explore food options family myself' or key == 'menu family':
            a = bistro()
            Z1 = input(" Any more questions ")
            bis = filter1(Z1)
            if bis == 'take grilled salmon spouse vegan buddha bowl kids mini pepperoni pizza grilled cheese sandwich' or bis == 'grilled salmon spouse vegan buddha bowl kids mini pepperoni pizza grilled cheese sandwich'  or bis == ' grilled salmon spouse prefers vegan buddha bowl kids mini pepperoni pizza grilled cheese sandwich'  or bis == ' grilled salmon spouse vegan buddha bowl kids mini pepperoni pizza grilled cheese sandwich'  or bis == ' choose grilled salmon myself vegan buddha bowl spouse kids'  or bis == 'mini pepperoni pizza grilled cheese sandwich'  or bis == ' grilled salmon vegan buddha bowl spouse mini pepperoni pizza grilled cheese sandwich'  or bis == ' kids grilled salmon spouse take vegan buddha bowl kids mini pepperoni pizza grilled cheese sandwich'  or bis == 'grilled salmon spouse vegan buddha bowl kids mini pepperoni pizza grilled cheese sandwich'  or bis == 'taking grilled salmon spouse vegan buddha bowl kids mini pepperoni pizza grilled cheese sandwich'  or bis == 'grilled salmon vegan buddha bowl spouse kids enjoy mini pepperoni pizza grilled cheese sandwich'  or bis == 'grilled salmon spouse vegan buddha bowl kids choose mini pepperoni pizza grilled cheese sandwich':
                  b = bistro1()
                  Z1 = input(" Any more questions ")
                  bis1 = filter1(Z1)
                  if bis1 == 'please add one fruit salad two ice cream sundaes kids' or bis1 == 'add fruit salad two ice cream sundaes kids please' or bis1 == 'include one fruit salad two ice cream sundaes kids please' or bis1 == 'add fruit salad two ice cream sundaes order add one fruit salad two ice cream sundaes kids' or bis1 ==  'add fruit salad two ice cream sundaes selection please' or bis1 ==  'include one fruit salad two ice cream sundaes meal' or bis1 == 'please add one fruit salad two ice cream sundaes children' or bis1 ==  'add fruit salad two ice cream sundaes order please' or bis1 == 'include fruit salad two ice cream sundaes kids' or bis1 == 'please add one fruit salad two ice cream sundaes children':
                    c = bistro2()
                    Z1 = input(" Any more questions ")
                    bis2 = filter1(Z1)
                    if bis2 == 'no everything thanks your':
                       d = bistro3()
    elif key == 'reward points buy travel vouchers myself family' or key == 'points travel vouchers interested reward points travel vouchers'  or key == ' family hey points buy travel vouchers family'  or key == 'process redeeming travel vouchers reward points'  or key == 'redeem travel vouchers points family'  or key == ' points vouchers family redeem points travel vouchers'  or key == ' options getting travel vouchers points'  or key == ' whats process redeeming travel vouchers reward points'  or key == 'hey reward points buy travel vouchers family':
            a = voucher()
            Z1 = input(" Any more questions ")
            vo = filter1(Z1)

            if vo == 'take voucher myself two vouchers spouse child' or vo == 'one voucher two vouchers family' or vo == 'please redeem voucher two vouchers spouse child' or vo == 'take voucher myself vouchers spouse kid' or vo == 'one voucher two vouchers family' or vo == 'choose voucher myself two ones spouse kid' or vo == 'please travel voucher two ones family' or vo =='redeem one voucher vouchers spouse child' or vo == 'voucher myself ones spouse child' or vo == 'travel voucher two vouchers family' or vo == 'please redeem voucher vouchers spouse kid':
                  b = voucher1()
                  Z1 = input(" Any more questions ")
                  vo1 = filter1(Z1)
                  if vo1 == 'please proceed' or vo1 == 'ahead process redemption' or vo1 == ' sure please proceed voucher redemption' or vo1 == ' ahead selection' or vo1 == 'please proceed redeeming vouchers' or vo1 == 'move redemption' or vo1 == 'sure ahead process vouchers' or vo1 == 'ready proceed selection' or vo1 == 'please ahead redeem vouchers' or vo1 == 'redemption' or vo1 == 'sure finalize redemption':
                    c = voucher2()
                    Z1 = input(" Any more questions ")
                    vo2 = filter1(Z1)

                    if vo2 == 'no now thanks your' or vo2 == 'no good now thanks helping' or vo2 == 'no your' or vo2 ==  'no anything else thanks your' or vo2 == 'no fine now thanks assisting' or vo2 ==  'no everything now thanks your' or vo2 == 'no set thanks your' or vo2 == 'no questions thanks' or vo2 == 'no got everything thanks helping' or vo2 == 'no your' or vo2 == 'no done now thanks helping':
                      d = voucher3()
    elif key == 'special offers discounts available booking flights right now' or key == 'festive discounts deals flights right now' or key == 'current offers booking flights' or key == 'special deals flights' or key == 'discounts running moment flight bookings' or key == 'ongoing offers booking tickets' or key == 'available deals flights' or key == 'interested festive discounts available' or key == 'promotional offers flights currently' or key == 'latest discounts flight bookings' or key == 'festive season deals tickets now':
            a = festive()
            Z1 = input(" Any more questions ")
            fv = filter1(Z1)

            if fv == 'trip winter winter holiday offers' or fv == 'thinking traveling winter offers available' or fv == 'details winter holiday discounts' or fv == ' winter trip current deals' or fv == 'discounts traveling winter holidays winter holiday' or fv == 'offers take advantage' or fv == 'deals winter travel' or fv == 'included your winter holiday discounts' or fv == 'details offers winter trips' or fv == 'considering winter trip discounts' or fv == 'special deals traveling winter':
                  b = festive1()
                  Z1 = input(" Any more questions ")
                  fv1 = filter1(Z1)
                  if fv1 == 'book tickets family europe'  or fv1 == 'book tickets europe our family'  or fv1 == 'book tickets familys trip europe'  or fv1 == 'family trip europe book tickets'  or fv1 == 'proceed booking our family trip europe'  or fv1 == 'tickets familys holiday europe'  or fv1 == 'visit europe tickets family'  or fv1 == 'book tickets family trip europe'  or fv1 == 'move booking tickets europe family'  or fv1 == 'heading europe family tickets'  or fv1 == 'book tickets our family holiday europe':
                    c = festive2()
                    Z1 = input(" Any more questions ")
                    fv2 = filter1(Z1)
                    if fv2 == 'us adults kids' or fv2 == 'us traveling adults kids' or fv2 == 'passengers adults children' or fv2 == 'group includes adults kids' or fv2 == 'spouse kids' or fv2 == 'traveling group adults kids' or fv2 == 'family adults children' or fv2 == 'people grownups kids' or fv2 == 'booking passengers adults kids' or fv2 == 'trip people adults kids' or fv2 == 'traveling family including kids ':
                      d = festive3()
                      Z1 = input(" Any more questions ")
                      fv3 = filter1(Z1)
                      if fv3 == 'explore flight options first' or fv3 == 'available flight options first' or fv3 == 'review flight choices before proceeding' or fv3 == 'take flights available' or fv3 == 'flight options before move' or fv3 == 'prefer explore flight schedules fares first' or fv3 == 'available flights choose' or fv3 == 'see flight options before confirming' or fv3 == 'list available flights review' or fv3 == 'check flight options before finalize booking' or fv3 == 'flight availability first':
                        e = festive4()
                        Z1 = input(" Any more questions ")
                        fv4 = filter1(Z1)
                        if fv4 == 'flight york paris' or fv4 == 'choose flight york paris' or fv4 == 'book flight york paris' or fv4 == ' flight york paris works' or fv4 == 'take flight departing york paris' or fv4 == 'flight york paris choice' or fv4 == 'ahead flight york paris' or fv4 == 'decided flight york paris' or fv4 == 'flight york paris suits' or fv4 == 'proceed booking flight york paris' or fv4 == 'flight york paris one':
                            f = festive5()
                            Z1 = input(" Any more questions ")
                            fv5 = filter1(Z1)
                            if fv5 == 'please proceed booking':
                              f = festive6()
                              Z1 = input(" Any more questions ")
                              fv6 = filter1(Z1)
                              if fv6 == 'no thanks your work':
                                 g = festive7()
    elif key == 'current promotions take advantage booking flights packages' or key == 'ongoing deals discounts flights packages' or key == 'latest promotions bookings special offers available right now' or key == 'current discounts flights hotels packages' or key == 'promotions running moment bookings' or key == 'package deals discounts' or key == 'details current promotional offers' or key == 'latest deals flights packages available' or key == 'offers available booking flights vacation packages' or key == 'ongoing promotions benefit booking':
            a = promo()
            Z1 = input(" Any more questions ")
            pr = filter1(Z1)
            if pr == 'vacation packages might book one family' or pr == 'details vacation packages' or pr == 'interested vacation packages options' or pr == 'family vacation deals' or pr == 'your vacation packages include' or pr == 'information your package offers' or pr == 'thinking booking vacation package available' or pr == 'family friendly vacation packages offer' or pr == 'deals vacation packages' or pr == 'kind discounts family vacation packages' or pr == 'vacation packages families':
                  b = promo1()
                  Z1 = input(" Any more questions ")
                  pr1 = filter1(Z1)
                  if pr1 == 'interested tropical getaway options' or pr1 == 'tropical getaway packages offer' or pr1 == 'tropical vacation deals' or pr1 == 'interested beach holiday packages available' or pr1 == 'tropical destinations packages' or pr1 == 'your deals tropical getaways' or pr1 == 'tropical vacation options' or pr1 == 'suggest available deals tropical holiday destinations' or pr1 == 'vacation packages tropical destinations' or pr1 == 'explore tropical getaway options mentioned' or pr1 == 'details tropical vacation packages':
                    c = promo2()
                    Z1 = input(" Any more questions ")
                    pr2 = filter1(Z1)
                    if pr2 == 'bahamas package family' or pr2 == 'choose bahamas package family'  or pr2 == ' book bahamas vacation package'  or pr2 == 'proceed bahamas package'  or pr2 == 'ahead bahamas deal mentioned'  or pr2 == 'decided bahamas vacation package'  or pr2 == 'bahamas package family'  or pr2 == 'bahamas trip option'  or pr2 == 'book bahamas package our trip'  or pr2 == 'bahamas package looks great book'  or pr2 == 'take bahamas vacation package family':
                      d = promo3()
                      Z1 = input(" Any more questions ")
                      pr3 = filter1(Z1)
                      if pr3 == 'four us two adults one kid' or pr3 == 'group four two adults one child' or pr3 == 'four travelers total including two adults kid' or pr3 == 'four us two grown ups one child' or pr3 == 'traveling family four two adults one kid' or pr3 == 'our group includes four people two adults one child' or pr3 == 'family four consisting two adults kid' or pr3 == 'four passengers two adults one child' or pr3 == 'booking four people two adults child' or pr3 == 'party four two adults one kid' or pr3 == 'traveling group four two adults one child':
                        e = promo4()
                        Z1 = input(" Any more questions ")
                        pr4 = filter1(Z1)
                        if pr4 == 'please add airport transfers' or pr4 == 'include airport transfers' or pr4 == 'please add airport transfers booking' or pr4 == 'sure ahead add airport transfers' or pr4 == 'include airport transfers' or pr4 == 'please add airport transfers us' or pr4 == 'airport transfers included booking' or pr4 == 'sure please include airport transfers' or pr4 == 'add airport transfers ahead include airport transfers please' or pr4 == 'please ensure airport transfers part booking':
                            f =promo5()
                            Z1 = input(" Any more questions ")
                            pr5 = filter1(Z1)
                            if pr5 == 'proceed booking transfer':
                              g = promo6()
                              Z1 = input(" Any more questions ")
                              pr6 = filter1(Z1)
                              if pr6 == 'no now thanks your great work':
                                 h = promo7()
    elif key == 'flight offer wi fi' or key == 'flight offer wifi' or key == 'flight offer wi fi' or key == 'flight offer wifi' or key == 'wi fi available flight' or key == 'wifi available flight' or key == 'flight internet' or key == 'wifi flight' or key =='wi fi fligt' or key == 'flight wi fi provided flight' or key == 'flight wifi provided flight' or key == 'flight internet service onboard' or key == 'wi fi available flight' or key == 'wifi available flight' or key == 'flight flight wi fi' or key == 'flight flight wifi' or key == 'wi fi option upcoming flight' or key == 'wifi option upcoming flight' or key == 'internet flight connect wi fi journey' or key == 'internet flight connect wifi journey':
            a = wifi()
            Z1 = input(" Any more questions ")
            wi = filter1(Z1)

            if wi == 'sure flying london mumbai' or wi == 'traveling london mumbai' or wi == ' flight london mumbai' or wi == 'flying between london mumbai' or wi == 'flight london mumbai' or wi == 'taking flight london mumbai' or wi == 'route london mumbai' or wi == 'flight booked london mumbai' or wi == 'scheduled fly london mumbai' or wi == 'trip taking london mumbai' or wi == 'traveling london mumbai':
                  b = wifi1()
                  Z1 = input(" Any more questions ")
                  wi1 = filter1(Z1)
                  if wi1 == 'setup process connecting wi fi flight' or wi1 == 'setup process connecting wifi flight' or wi1 == 'set up flight wifi' or wi1 == 'set up flight wi fi' or wi1 == 'connect wi fi onboard' or wi1 == 'connect wifi onboard' or wi1== 'procedure wi fi flight'  or wi1== 'procedure wifi flight'  or wi1== 'wi fi flight' or wi1== 'wifi flight' or wi1 == 'connected flight wi fi' or wi1 == 'connected flight wifi' or wi1 == 'steps set up wi fi plane' or wi1 == 'steps set up wifi plane' or wi1 == 'connect device wi fi onboard' or wi1 == 'connect device wifi onboard' or wi1== 'walk wi fi setup process' or wi1== 'walk wifi setup process' or wi1 == 'process accessing wi fi flight'  or wi1 == 'process accessing wifi flight' or wi1 == 'flight internet service':
                    c = wifi2()
                    Z1 = input(" Any more questions ")
                    wi2 = filter1(Z1)

                    if wi2 == 'prepurchase premium plan flight' or wi2 == 'buy premium plan advance flight' or wi2 == 'please pre book premium wi fi journey' or wi2 == 'please pre book premium wifi journey' or wi2 =='reserve premium wi fi' or wi2 =='reserve premium wifi' or wi2 == 'plan now pre premium wi fi plan trip' or wi2 == 'plan now pre premium wifi plan trip' or wi2 == 'take premium plan flight please' or wi2 == 'please premium wi fi plan' or wi2 ==  'pre pay premium wi fi service' or wi2 == 'premium plan before flight' or wi2 == 'add premium wi fi plan booking' or wi2 == 'premium wi fi option advance':
                      d = wifi3()
                      Z1 = input(" Any more questions ")
                      wi3 = filter1(Z1)
                      if wi3 == 'take premium plan return flight too' or wi3 == 'please add premium plan return flight well' or wi3 == ' premium wi fi return trip too' or wi3 == 'include premium plan both flights please' or wi3 == 'premium wi fi return journey too' or wi3 == 'please reserve premium plan return leg well' or wi3 == 'premium wi fi option both outbound return flights' or wi3 == 'add premium plan return flight too' or wi3 == 'premium plan return flight well' or wi3 == 'buy premium wi fi way back too' or wi3 == 'include premium wi fi return flight please':
                        e = wifi4()
                        Z1 = input(" Any more questions ")
                        wi4 = filter1(Z1)
                        if wi4 == 'ahead proceed':
                            f = wifi5()
                            Z1 = input(" Any more questions ")
                            wi5 = filter1(Z1)
                            if wi5 == 'no now thanks your no queries':
                              g = wifi6()
    elif key == 'add family members account' or key == 'possible add family members account' or key == ' include family members under account' or key == 'add family members account' or key == 'allowed add family members account' or key == 'register family members account' or key == 'option add family members account' or key == 'add family members account' or key == 'family members linked account' or key == 'account include family members' or key == 'add family members account':
            a =family()
            Z1 = input(" Any more questions ")
            fa = filter1(Z1)

            if fa == 'add spouse child' or fa == 'sure add spouse child' or fa == 'please add spouse child account' or fa == 'include spouse child under account' or fa == ' add spouse child account' or fa == 'register spouse child family members' or fa == 'add spouse child family members' or fa == 'please ahead add spouse child account' or fa == 'link spouse child account' or fa == 'include spouse child family member section' or fa == 'please add both spouse child account':
                  b = family1()
                  Z1 = input(" Any more questions ")
                  fa1 = filter1(Z1)
                  if fa1 == 'spouses name emily johnson born june' or fa1 == 'spouse emily johnson her date birth june' or fa1 == 'emily johnson spouse born june' or fa1 == 'details spouse emily johnson born june' or fa1 == 'emily johnson spouse her birthdate june' or fa1 == 'spouses details emily johnson dob june' or fa1 == 'add emily johnson spouse born june' or fa1 == 'spouse emily johnson birthdate june' or fa1 == 'spouse emily johnson born june' or fa1 == 'person add emily johnson spouse born june' or fa1 == 'please add spouse emily johnson birthdate june':
                    c = family2()
                    Z1 = input(" Any more questions ")
                    fa2 = filter1(Z1)
                    if fa2 == 'childs name alex johnson born october' or fa2 == 'child alex johnson born october' or fa2 == 'alex johnson child birthdate october' or fa2 == 'details child alex johnson born october' or fa2 == 'alex johnson child born october' or fa2 == 'add alex johnson child born october' or fa2 == 'child alex johnson born october' or fa2 == 'please add alex johnson child born october' or fa2 == 'childs details alex johnson birthdate october' or fa2 == 'person add alex johnson child born october' or fa2 == 'child alex johnson birthdate october':
                      d = family3()
                      Z1 = input(" Any more questions ")
                      fa3 = filter1(Z1)
                      if fa3 == 'no nothing else thanks':
                        e = family4()

    elif key == 'check flight' or key == 'check process' or key == 'checking flight' or key == 'check upcoming flight' or key == 'figuring out check flight' or key == 'check flight' or key == 'assist check process flight' or key == 'sure check' or key == 'instructions check flight' or key == 'walk check process flight':
            a =check()
            Z1 = input(" Any more questions ")
            ch = filter1(Z1)

            if ch == 'phone' or ch == 'check mobile phone' or ch == 'phone check' or ch == 'prefer check via mobile' or ch == 'complete check mobile app' or ch == 'check smartphone' or ch == 'check app phone' or ch == 'check phone plan phone' or ch == 'check process' or ch == 'prefer handle check via mobile device':
                  b = check1()
                  Z1 = input(" Any more questions ")
                  ch1 = filter1(Z1)
                  if ch1 == 'please send application link download' or ch1 == 'sure send link download application' or ch1 == 'please app download link' or ch1 == 'link application' or ch1 == 'please send link app' or ch1 == 'link download application' or ch1 == 'application link download' or ch1 == 'send app link downloading' or ch1 == 'link download app please' or ch1 == 'please application download link' or ch1 == 'send over link app download':
                    c = check2()
                    Z1 = input(" Any more questions ")
                    ch2 = filter1(Z1)
                    if ch2 == 'check laptop' or ch2 == 'steps web check' or ch2 == 'check website instead' or ch2 == 'check laptop' or ch2 == 'web check work' or ch2 == 'check website' or ch2 == 'process checking computer' or ch2 == 'handle check laptop' or ch2 == 'web check' or ch2 == 'check laptop':
                      d = check3()
                      Z1 = input(" Any more questions ")
                      ch3 = filter1(Z1)
                      if ch3 == 'really great':
                        e = check4()
                        Z1 = input(" Any more questions ")
                        ch4 = filter1(Z1)

                        if ch4 == 'thanks your good work':
                           f = check5()
    elif key == 'hotel stay trip' or key == 'finding hotel trip' or key == 'book hotel upcoming journey' or key == 'assist finding place stay trip' or key == 'stay hotel trip' or key == 'booking hotel travel' or key == 'find hotel trip' or key == 'accommodation travel' or key == 'reserve hotel stay assist' or key == 'hotel trip':
            a =hotel()
            Z1 = input(" Any more questions ")
            ho = filter1(Z1)

            if ho == 'sure traveling toronto hotel january th january th' or ho == 'going toronto hotel january th january th' or ho == 'toronto accommodation january th january th' or ho == 'stay toronto january th january th hotel' or ho == 'trip toronto january th january th hotel' or ho == 'hotel toronto january th january th' or key == 'toronto those dates find hotel' or key == 'book hotel toronto january th january th' or key == 'accommodation toronto january th january th' or key == 'travel dates toronto january th january th place stay' or key == 'hotel toronto january th january th':
                  b = hotel1()
                  Z1 = input(" Any more questions ")
                  ho1 = filter1(Z1)
                  if ho1 == 'star hotel free wi fi breakfast' or ho1 == 'find star hotel offers free wi fi breakfast' or ho1 == 'star hotel complimentary wi fi breakfast included' or ho1 == 'please book star hotel free wi fi breakfast' or ho1 == 'star accommodation breakfast wi fi included' or ho1 == 'star hotel offering free breakfast wi fi' or ho1 == 'stay star hotel includes wi fi breakfast package' or ho1 == 'please find star hotel complimentary breakfast free wi fi' or ho1 == 'interested booking star hotel offers breakfast wi fi free' or ho1 == 'reserve star hotel wi fi breakfast provided free charge' or ho1 == 'prefer star hotel free breakfast internet':
                    c = hotel2()
                    Z1 = input(" Any more questions ")
                    ho2 = filter1(Z1)
                    if ho2 == 'book maple grand hotel' or ho2 == 'please ahead book maple grand hotel' or ho2 == 'maple grand hotel reservation' or ho2 == 'reserve maple grand hotel stay' or ho2 == 'book maple grand hotel' or ho2 == 'please reservation maple grand hotel' or ho2 == 'proceed booking maple grand hotel' or ho2 == 'ahead book maple grand hotel' or ho2 == 'please take maple grand hotel please booking' or ho2 == 'maple grand hotel works please reserve' or ho2 == 'maple grand hotel please book':
                      d = hotel3()
                      Z1 = input(" Any more questions ")
                      ho3 = filter1(Z1)
                      if ho3 == 'actually rent car trip' or ho3 == 'rent car travel' or ho3 == 'car rental along hotel booking' or ho3 == 'rent car trip well' or ho3 == 'book car rental too' or ho3 == 'car travel addition hotel rental car well d add car rental bookings possible rent car trip too rent car trip assist car rental journey well':
                        e = hotel4()
                        Z1 = input(" Any more questions ")
                        ho4 = filter1(Z1)
                        if ho4 == 'car january th january th picking up dropping off toronto airport' or ho4 == 'car rental january th january th pickup drop off toronto airport' or ho4 == 'please car january th january th starting ending toronto airport' or ho4 == 'book car january th january th picking up returning toronto airport' or ho4 == 'reserve car january th january th pickup drop off toronto airport' or ho4 == 'require car rental january th january th pickup return toronto airport' or ho4 == 'please book car january th january th both pickup drop off toronto airport' or ho4 == 'rent car between january th january th picking up dropping off toronto airport' or ho4 == 'car rental january th january th pickup drop off toronto airport' or ho4 == 'rent car january th january th starting ending toronto airport' or ho4 == 'please reserve rental car january th january th picking up returning toronto airport':
                            f = hotel5()
                            Z1 = input(" Any more questions ")
                            ho5 = filter1(Z1)
                            if ho5 == 'suv':
                              g = hotel6()
                              Z1 = input(" Any more questions ")
                              ho6 = filter1(Z1)
                              if ho6 == 'car hotel bookings' or ho6 == 'please ahead car hotel bookings' or ho6 == 'both car hotel reservations' or ho6 == 'please proceed finalize car hotel bookings' or ho6 == 'car hotel reservations' or ho6 == 'bookings both car hotel' or ho6 == 'please ensure both car hotel booked' or ho6 == 'ahead finalize hotel car reservations' or ho6 == 'car hotel bookings now' or ho6 == 'proceed confirming car hotel reservations' or ho6 == 'please reservations car hotel':
                                  h = hotel7()
                                  Z1 = input(" Any more questions ")
                                  ho7 = filter1(Z1)
                                  if ho7 == 'no no further' :
                                    i = hotel8()
    elif key == 'flight california lisbon' or key == 'flight california lisbon' or key == 'find flight lisbon california' or key == 'searching flights california lisbon' or key == 'flight recommendations california lisbon' or key == 'book flight california lisbon' or key == 'options traveling california lisbon' or key == 'flights california lisbon' or key == 'travel california lisbon assist' or key == 'checking flights california lisbon' or key == 'please find flight california lisbon':
            a = reco()
            Z1 = input(" Any more questions ")
            rc1 = filter1(Z1)

            if rc1 == 'travel november th budget k aisle seat' or rc1 == 'traveling november th budget k prefer aisle seat' or rc1 == 'trip november th spend up k aisle seat' or rc1 == 'november th travel date budget k prefer aisle seat' or rc1 == 'book november th k budget aisle seat preference' or rc1 == 'traveling november th budget k prefer aisle seat' or rc1 == 'flight november th k budget aisle seat' or rc1 == 'travel date november th aisle seat within k' or rc1 == 'booking november th budget k aisle seat' or rc1 == 'november th k budget aisle seat preference flight' or rc1 == 'flights november th under k aisle seat':
                  b = reco1()
                  Z1 = input(" Any more questions ")
                  rc = filter1(Z1)
                  if rc == 'shortest duration option' or rc == 'select shortest duration option' or rc == 'prefer flight shortest travel time' or rc == 'flight shortest duration' or rc == 'choose flight shortest travel time' or rc == 'shortest duration flight works' or rc == 'pick option least travel time' or rc == 'shortest duration sounds good take one' or rc == 'opt flight shortest duration' or rc == 'proceed shortest travel time flight' or rc == 'ahead shortest duration option':
                    c = reco2()
                    Z1 = input(" Any more questions ")
                    rc2 = filter1(Z1)
                    if rc2 == 'please book flight' or rc2 == 'flight please book flight' or rc2 == 'proceed flight' or rc2 == 'ahead book option' or rc2 == 'flight works please booking' or rc2 == 'book ticket' or rc2 == 'finalize flight booking' or rc2 == 'please proceed booking flight' or rc2 == 'reservation flight' or rc2 == 'flight please book':
                      d = reco3()
                      Z1 = input(" Any more questions ")
                      rc3 = filter1(Z1)
                      if rc3 == 'everything fine booking' or rc3 == 'details correct please' or rc3 == 'everything looks good ahead' or rc3 == 'perfect please finalize booking' or rc3 == 'happy details reservation' or rc3 == 'ticket everything fine' or rc3 == 'details correct please proceed confirmation' or rc3 == 'good booking' or rc3 == 'ahead finalize booking' or rc3 == 'everything order please' or rc3 == 'details reservation now':
                        e = reco4()
                        Z1 = input(" Any more questions ")
                        rc4 = filter1(Z1)
                        if rc4 == 'no set thank':
                           f = reco5()
    elif key == 'browsing flights earlier but book anything check cart' or key == 'flights earlier but complete booking' or key == 'left flight cart earlier check' or key == 'flight started booking but finish' or key == 'cart earlier' or key == 'middle booking flight check cart' or key == 'review flight earlier' or key == 'left booking incomplete saved cart' or key == 'pull up flight book before' or key == 'think left flight cart' or key == 'check saved flights cart':
            a = cart()
            Z1 = input(" Any more questions ")
            cr = filter1(Z1)
            if cr == 'please cart' or cr == 'sure saved cart' or cr == 'see flights cart' or cr == 'please cart' or cr == 'bring up items cart' or cr == 'please cart details' or cr == 'review flights cart' or cr == 'sure see cart' or cr == 'saved flight options' or cr == 'display items cart' or cr == 'sure see left cart':
                  b = cart1()
                  Z1 = input(" Any more questions ")
                  cr1 = filter1(Z1)
                  if cr1 == 'great deal price includes luggage' or cr1 == 'sounds good price include baggage' or cr1 == 'nice offer luggage come fare' or cr1 == 'discount baggage included price' or cr1 == 'good deal flight price cover luggage' or cr1 == 'offer great baggage fees' or cr1 == 'good price bags included cost' or cr1 == 'great discount clarify luggage included' or cr1 == 'works include baggage' or cr1 == 'good deal luggage part price' or cr1 == 'discount great baggage policy':
                    c = cart2()
                    Z1 = input(" Any more questions ")
                    cr2 = filter1(Z1)
                    if cr2 == 'right now select seat booking process' or cr2 == 'moment choose seat checkout' or cr2 == 'now but pick seat booking' or cr2 == 'skip now select seat later process' or cr2 == 'no baggage now choose seat booking' or cr2 == 'adding baggage but seat selection' or cr2 == 'no luggage now able select seat booking' or cr2 == 'skipping baggage choose preferred seat checkout' or cr2 == 'no bag now seat selection booking' or cr2 == 'add luggage pick seat later' or cr2 == 'adding bag seat selection options':
                      d = cart3()
                      Z1 = input(" Any more questions ")
                      cr3 = filter1(Z1)
                      if cr3 == 'proceed add travel insurance booking' or cr3 == 'continue include travel insurance booking' or cr3 == 'move travel insurance' or cr3 == 'proceed booking add travel insurance' or cr3 == 'move ahead travel insurance options' or cr3 == 'travel insurance available add' or cr3 == 'continue include insurance booking' or cr3 == 'move booking travel insurance added' or cr3 == 'proceed add travel insurance reservation' or cr3 == 'continue booking add travel insurance well ahead details adding travel insurance':
                        e = cart4()
                        Z1 = input(" Any more questions ")
                        cr4 = filter1(Z1)
                        if cr4 == 'please add travel insurance redeem reward points booking' or cr4 == 'add travel insurance booking reward points' or cr4 == 'please include travel insurance apply reward points booking well' or cr4 == 'add travel insurance possible redeem reward points' or cr4 == 'ahead include travel insurance available reward points booking' or cr4 == 'add travel insurance redeem points ticket' or cr4 == 'please add travel insurance option reward points too' or cr4 == 'travel insurance apply rewards reduce cost booking' or cr4 == 'sure add travel insurance reward points reservation' or cr4 == 'travel insurance reward points available redeem booking' or cr4 == 'please include travel insurance offset cost rewards points':
                            f =cart5()
                            Z1 = input(" Any more questions ")
                            cr5 = filter1(Z1)
                            if cr5 == 'apply points finalize booking' or cr5 == 'apply points booking' or cr5 == 'reward points complete reservation' or cr5 == 'redeem points proceed booking' or cr5 == 'apply points book flight' or cr5 == 'points finalize reservation' or cr5 == 'redeem points complete ticket booking' or cr5 == 'apply rewards booking' or cr5 == 'please points proceed finalize flight' or cr5 == 'redeem points now complete reservation process' or cr5 == 'available points finish booking':
                              g = cart6()
                              Z1 = input(" Any more questions ")
                              cr6 = filter1(Z1)
                              if cr6 == 'needed thanks your guidance':
                                 h = cart7()
    elif key == 'traveling air canada wondering much additional bag cost' or key == 'cost adding extra bag flight' or key == 'fee additional piece luggage trip' or key == 'details cost checking extra bag air canada' or key == 'much cost bring another bag flight' or key == 'fees additional baggage booking' or key == 'interested knowing price adding second bag trip' or key == 'charges checking extra bag air canada' or key == 'clarify extra baggage fees flight' or key == 'information cost carrying additional suitcase' or key == 'understand fees extra luggage air canada flights':
            a = addb()
            Z1 = input(" Any more questions ")
            ab = filter1(Z1)

            if ab == 'please flight toronto vancouver' or ab == 'sure flight between toronto vancouver' or ab == 'route toronto vancouver' or ab == 'flying toronto vancouver' or ab == 'domestic flight between toronto vancouver' or ab == 'journey toronto vancouver check' or ab == 'flight toronto vancouver' or ab == 'traveling toronto vancouver details' or ab == 'route toronto vancouver' or ab == 'flying domestically toronto vancouver' or ab == 'trip toronto vancouver baggage fees':
                  b= addb1()
                  Z1 = input(" Any more questions ")
                  ab1 = filter1(Z1)
                  if ab1 == 'great economy standard fare' or ab1 == 'ticket economy standard' or ab1 == 'sure fare type economy standard' or ab1 == 'booked economy standard ticket' or ab1 == 'traveling economy standard fare please check' or ab1 == 'economy standard class booking' or ab1 == 'please economy standard' or ab1 == 'ticket type economy standard' or ab1 == 'flying economy standard fare check' or ab1 == 'sure fare type economy standard details' or ab1 == 'booked economy standard ticket assist':
                    c = addb2()
                    Z1 = input(" Any more questions ")
                    ab2 = filter1(Z1)
                    if ab2 == 'process paying fee' or ab2 == 'right now pay extra bag'or ab2 == 'no moment pay additional luggage'or ab2 == 'just describe process payment'or ab2 == 'now pay extra baggage'or ab2 == 'moment process paying fee' or ab2 == 'payment extra suitcase' or ab2 == 'right now payment process works' or ab2 == 'no ready pay additional baggage fee' or ab2 == 'time handle payment extra bag' or ab2 == 'steps paying additional baggage':
                      d = addb3()
                      Z1 = input(" Any more questions ")
                      ab3 = filter1(Z1)
                      if ab3 == 'please correct link':
                        e = addb4()
                        Z1 = input(" Any more questions ")
                        ab4 = filter1(Z1)
                        if ab4 == 'everything needed thank your':
                            f = addb5()
    if key == 'booking flight air canada choosing seat' or key == 'booking flight air canada selecting seat' or key == 'process booking air canada flight guidance seat options' or key == 'choosing right seat air canada flight' or key == 'booking flight air canada advice seat selection' or key == 'assist picking seat air canada booking' or key == 'seat selection booking air canada flight' or key == 'air canada flight deciding seat' or key == 'seat options reserving air canada ticket' or key == 'choosing best seat air canada flight booking' or key == 'seat selection air canada flight booking':
            a = upgrade()
            Z1 = input(" Any more questions ")
            up = filter1(Z1)
            if up == 'options seat upgrades' or up == 'interested learning seat upgrade options' or up == 'sure available seat upgrades' or up == 'explore different seat upgrade choices' or up == 'please details seat upgrade options' or up == 'options upgrading seat' or up == 'seat upgrades offer' or up == 'available seat upgrade possibilities' or up == 'sure curious options upgrading seat' or up == 'please seat upgrade features' or up == 'additional information upgrade seat':
                  b = upgrade1()
                  Z1 = input(" Any more questions ")
                  up1 = filter1(Z1)
                  if up1 == 'prefer window seat extra legroom' or up1 == 'window seat offers extra legroom' or up1 == 'window seat additional legroom preference' or up1 == 'prefer window seat legroom' or up1 == 'book window seat extended legroom' or up1 == 'choose window seat extra space legs' or up1 == 'preference window seat extra legroom' or up1 == 'window seat added legroom please' or up1 == 'really window seat extra legroom' or up1 == 'window seat increased legroom ideal' or up1 == 'please reserve window seat extra legroom':
                    c = upgrade5()
                    Z1 = input(" Any more questions ")
                    up2 = filter1(Z1)
                    if up2 == 'please sounds perfect please proceed'or up2 == 'please works perfectly ahead' or up2 == 'absolutely ideal please proceed' or up2 == 'just right move' or up2 == 'sure sounds great please ahead' or up2 == 'please exactly wanted proceed' or up2 == 'perfect thank please continue' or up2 == 'perfect finalize' or up2 == 'definitely please proceed' or up2 == 'great please carry' or up2 == 'perfect please ahead process':
                      d = upgrade2()
                      Z1 = input(" Any more questions ")
                      up3 = filter1(Z1)
                      if up3 == 'no thank happy current selection' or up3 == 'no thanks satisfied current choice' or up3 == 'no thank fine selected' or up3 == 'no good stick current selection' or up3 == 'no happy chosen' or up3 == 'no thank current option works perfectly' or up3 == 'no content existing selection' or up3 == 'no necessary happy current choice' or up3 == 'no already selected' or up3 == 'no thank keep current selection' or up3 == 'no good current option chosen':
                        d = upgrade3()
                        Z1 = input(" Any more questions ")
                        up4 = filter1(Z1)
                        if up4 == 'now thank your work':
                           e = upgrade4()
    elif key == 'talk agent' or key == 'speak someone directly' or key == 'please transfer agent right away' or key == 'real person issue' or key == 'human agent assist' or key == 'connect one your team members' or key == 'think chatbot please escalate' or key == 'feel comfortable discussing agent' or key == 'live agent' or key == 'seems complicated talk someone your team' or key == 'someone available handle':
            a = transfer()
            Z1 = input(" Any more questions ")
            tf = filter1(Z1)

            if tf == 'trouble completing booking' or tf == 'transfer agent assist further' or tf == 'escalate your request human representative now' or tf == 'connecting agent please hold moment' or tf == 'sure routing your issue our team' or tf == 'one moment connect live agent' or tf =='escalating request one our experts' or tf == 'please hold human agent assist' or tf =='transferring specialist' or tf == 'route your concern agent right away' or tf == 'connect right person address':
                  b = transfer1()
                  Z1 = input(" Any more questions ")
                  tf1 = filter1(Z1)
                  if tf1 == 'connect right away':
                    c = transfer2()
    elif key == 'upset luggage issue handled' or key == 'happy way luggage problem dealt' or key == 'frustrated luggage issue managed' or key == 'feel dissatisfied handling baggage situation' or key == 'unhappy lack progress luggage issue' or key == 'disappointed baggage problem resolved' or key == 'feel down way luggage situation handled' or key == 'annoyed current approach solving baggage issue' or key == 'pleased luggage matter addressed' or key == 'feeling upset poor handling baggage situation' or key == 'concerned way luggage problem taken care':
            d = transfer3()
            Z1 = input(" Any more questions ")
            tf3 = filter1(Z1)
            if tf3 == 'your responses resolved issue' or tf3 == 'frustrated managed' or tf3 == 'working unhappy' or tf3 == 'very upset lack resolution' or tf3 == 'someone take responsibility issue' or tf3 == 'problem really bothering real' or tf3 == 'your responses aren fixing issue losing patience' or tf3 == 'angry handled' or tf3 == 'feel ignored immediate' or tf3 == 'believe dealing please escalate now' or tf3 == 'dissatisfied level receiving ':
                  e = transfer4()
                  Z1 = input(" Any more questions ")
                  tf2 = filter1(Z1)
                  if tf2 == 'please asap':
                    transfer5()
    elif key == 'extremely upset luggage issue handled' or key == 'really angry way baggage issue addressed' or key == 'luggage problem completely unacceptable upset' or key == 'frustrated lack resolution baggage issue' or key == 'unhappy missing bag handled' or key == 'situation luggage making very upset' or key == 'feel down way baggage issue managed' or key == 'disappointed service regarding luggage problem' or key == 'angry receiving proper updates missing baggage' or key == 'irritated mishandling luggage situation' or key == 'luggage issue causing lot frustration ':
            a = follow()
            Z1 = input(" Any more questions ")
            fu = filter1(Z1)
            print(fu)
            if fu == 'bag arrive destination no one giving updates' or fu == 'luggage shown up getting information' or fu == 'receive bag been no your team' or fu == 'baggage missing had no communication' or fu == 'arrived without luggage no one helping' or fu == 'bag lost going' or fu == 'find baggage no one updated status' or fu == 'suitcase arrive haven heard back anyone' or fu == 'bag been delivered no' or fu == 'been waiting luggage getting no information' or fu == 'baggage delayed no one provided details':
                  b = follow1()
                  Z1 = input(" Any more questions ")
                  fu2 = filter1(Z1)
                  print(fu2)
                  if fu2 == 'email emailexamplecom phone number':
                    c = follow2()
                    Z1 = input(" Any more questions ")
                    fu3 = filter1(Z1)
                    print(fu3)
                    if fu3 == 'correct but when bag back' or fu3 == 'right when receive luggage' or fu3 == 'accurate when expect bag' or fu3 == 'information correct timeline baggage' or fu3 == 'confirmed when bag returned' or fu3 == 'correct when suitcase' 'accurate timeline bag' or fu3 == 'correct when anticipate luggage arrival' or fu3 == 'everything fine but when baggage delivered' or fu3 == 'details right bag return' or fu3 == 'true when luggage back':
                      d = follow3()
                      Z1 = input(" Any more questions ")
                      fu4 = filter1(Z1)
                      print(fu4)
                      if fu4 == 'fine but really inconvenient' or fu4 == 'but very frustrating' or fu4 == 'understand but situation quite inconvenient' or fu4 == 'fine but hassle' 'but hazzppy inconvenience' 'fine but issue caused lot trouble' 'but inconvenient experience' 'but been really bothersome' 'but annoyed inconvenience' 'fine but been significantly inconvenienced' 'but whole thing very disruptive':
                        e = follow4()
                        Z1 = input(" Any more questions ")
                        fu5 = filter1(Z1)

                        if fu5 == 'thank got necessay information':
                              g = follow5()
    elif key == 'existing travel' or key == 'existing booking' or key == 'existing reservation' or key == 'existing ticket' or key == 'manage booking' or key == 'manage reservation' or key == 'manage travel' or key == 'change booking' or key == 'change reservation' or key == 'modify booking' or key == 'modify reservation' or key == 'change ticket'or key == 'modify ticket' or key == 'change dates'or key == 'modify dates'or key == 'change flights' or key == 'modify flights'or key == 'manage ticket' or key == 'existing booking' or key == 'assist current booking' or key == 'reservation already made' or key == 'booking done' or key == 'regarding existing flight booking' or key == 'check current reservation' or key == 'changes existing booking' or key == 'require previously made reservation' or key == 'booking already confirmed' or key == 'managing current flight reservation':
            a = existing()
            Z1 = input(" Any more questions ")
            ex = filter1(Z1)
            print(Z1)
            if ex == 'sure ac' or ex == 'reference number ac' or ex == 'booking number ac' or ex == 'reservation code ac' or ex == 'find booking number ac reference booking ac booking confirmation number ac reservation code ac booking reference ac booking ac reservation number ac':
                  b = existing1()
                  Z1 = input(" Any more questions ")
                  ex1 = filter1(Z1)
                  if ex1 == 'change return flight date th month' or ex1 == 'move return flight th' or ex == 'change return flight th' or ex == 'return flight th' or ex == 'month reschedule return flight th' or ex == 'please modify return flight th month' or ex == 'return flight changed th' or ex == 'adjust return flight th' or ex == 'return flight date updated th month' or ex == 'please change return flight booking th' or ex == 'reschedule return flight th':
                    c = existing2()
                    Z1 = input(" Any more questions ")
                    ex2 = filter1(Z1)
                    if ex2 == 'prefer evening flight' or ex2 == 'evening departure please' or ex2 == 'please flights evening' or ex2 == 'evening flight preference' or ex2 == 'interested evening flights' or ex2 == 'find flight leaves evening' or ex2 == 'prefer later flight day' or ex2 == 'flights departing evening' or ex2 == 'take flight evening possible' or ex2 == 'evening departure work best' or ex2 == 'please evening flight options':
                      d = existing3()
                      Z1 = input(" Any more questions ")
                      ex3 = filter1(Z1)
                      if ex3 == 'please ahead':
                        e = existing4()
                        Z1 = input(" Any more questions ")
                        ex4 = filter1(Z1)
                        if ex4 == 'no needed now':
                           f =  existing5()
    elif key == 'air canada flight' or key == 'air canada flight' or key == 'details flight please' or key == 'flight works' or key == 'curious air canada flight elaborate' or key == 'flight options' or key == 'information flight' or key == 'understand flight includes' or key == 'benefits flight' or key == 'air canada flight offer':
            a = flightpass()
            Z1 = input(" Any more questions ")
            fp = filter1(Z1)
            print(fp)
            if fp == 'interested individual' or fp == 'details individual flight' or fp == 'individual option' or fp == 'flight individuals' or fp == 'specifically interested individual plan' or fp == 'information personal flight' or fp == 'details individual travel option' or fp == 'options individual flight' or fp == 'please focus individual flight details' or fp == 'individual plans' or fp == 'interest flight single travelers':
                  b = flightpass1()
                  Z1 = input(" Any more questions ")
                  fp1 = filter1(Z1)
                  print(fp1)
                  if fp1 == 'travel within canada us' or fp1 == 'travel canada us' or fp1 == 'focus flights within canada us' or fp1 == 'considering trips across canada us' or fp1 == 'intended region canada us' or fp1 == 'travel options canada us' or fp1 == 'zone interest canada united states' or fp1 == 'exploring travel options within canada us' or fp1 == 'canada us regions focusing' or fp1 == 'targeting flights within canada us zone' or fp1 == 'travel exclusively canada us':
                    c = flightpass2()
                    Z1 = input(" Any more questions ")
                    fp2 = filter1(Z1)
                    print(fp2)
                    if fp2 == 'prefer premium economy option' or fp2 == 'interested premium economy travels' or fp2 == 'preference premium economy' or fp2 == 'premium economy option' or fp2 == 'please premium economy' or fp2 == 'premium economy sounds good fit' or fp2 == 'focus premium economy plan' or fp2 == 'choice premium economy now' or fp2 == 'leaning towards premium economy option' or fp2 == 'discuss premium economy' or fp2 == 'premium economy preferred class':
                      d = flightpass3()
                      Z1 = input(" Any more questions ")
                      fp3 = filter1(Z1)
                      print(fp3)
                      if fp3 == 'please pricing package details' or fp3 == 'sure pricing packages' or fp3 == 'see prices plans' or fp3 == 'please package options costs' or fp3 == 'details pricing plans' or fp3 == 'information costs packages' or fp3 == 'please pricing structure' or fp3 == 'sure understand package rates' or fp3 == 'costs packages' or fp3 == 'pricing package details helpful thanks' or fp3 == 'love info costs options':
                        e = flightpass4()
                        Z1 = input(" Any more questions ")
                        fp4 = filter1(Z1)
                        print(fp4)
                        if fp4 == 'please send brochure' or fp4 == 'email brochure' or fp4 == 'please brochure' or fp4 == 'receive brochure thanks' or fp4 == 'send brochure email' or fp4 == 'please brochure' or fp4 == 'copy brochure please' or fp4 == 'brochure reference' or fp4 == 'send brochure when chance' or fp4 == 'send brochure' or fp4 == 'please email brochure':
                            f = flightpass5()
                            Z1 = input(" Any more questions ")
                            fp5 = filter1(Z1)
                            print(fp5)
                            if fp5 == 'no now thanks your done':
                                g = flightpass6()





    elif key == 'please complete information refunds applied under ticket number ac' or key == 'furnish details refund request ticket ac' or key == 'information refund associated ticket number ac including specifics' or key == 'refund details including processing status ticket ac' or key == 'breakdown refund process status ticket number ac' or key == 'details refund request ticket number ac' or key == 'refund status information regarding ticket number ac' or key == 'please refund details associated ticket number ac including relevant updates' or key == 'status details refunds ticket number ac' or key == 'complete details refunds applied under ticket number ac' or key =='details refunds applied ticket number ac including details'  :

      a = ref()

      Z1 = input(" Any more questions ")
      a11 = filter1(Z1)
      if a11 == 'thank information next course action refund been finalized' or a11 == 'thanks providing details let next steps unresolved refund' or a11 == 'thanks clarification happens next pending refund request' or a11 == 'information expect next refund still process' or a11 == 'thank detailed next steps pending refund' or a11=='thanks detailed information next steps pending refund' :

        b = ref1()
        Z1 = input(" Any more questions ")
        re2 = filter1(Z1)
        if re2 == 'information decision deny refund missed connecting flight' or re2 == 'reasons given refusing refund missed connecting flight' or re2 == 'details denied refund missed connecting flight' or re2 == 'refund missed connecting flight approved' or re2 == 'reasons refund denied missed connecting flight' or re2 == 'details regarding denial refund missed connecting flight' :
           c = ref2()
           Z1 = input(" Any more questions ")
           re4 = filter1(Z1)
           if re4 == 'helps approved refund' or re4 == 'details refund been approved ticket' or re4 == 'refund approved including specific details' or re4 == 'information regarding approved refund booking' or re4 == 'details associated refund approved ticket' or re4 == 'please specifics refund been confirmed approved' :
              d = ref3()
              Z1 = input(" Any more questions ")
              re5 = filter1(Z1)
              if re9 == 'list down reason refund' or re9 == 'reason behind refund ticket' or re9 == 'justification refund booking' or re9 == 'specify refund issued flight' or re9 == 'cause reason refund received' or re9 == 'details refund processed ticket' :
                i = ref4()
                Z1 = input(" Any more questions ")
                re5 = filter1(Z1)
                if re5 == 'refund credited account' or re5 == 'mode refund amount processed' or re5 == 'specify method transfer refund' or re5 == 'receive refund payment ticket' or re5 == 'clarify channel refund credited' or re5 == 'payment method processed refund' :
                  e = ref5()
                  Z1 = input(" Any more questions ")
                  re6 = filter1(Z1)
                  if re6 == 'please mobile number email raised refund request' or re6 == 'verify mobile number email address associated refund requests' or re6 == 'please contact details including phone number email refund applications' or re6 == 'registered email mobile number raised refund requests' or re6 == 'confirmation email phone details linked refund cases' or re6 == 'please verify email address mobile number connected refund requests' :
                      f = ref6()
                      Z1 = input(" Any more questions ")
                      re7 = filter1(Z1)
                      if re7 == 'refund got denied missed connecting flight' or re7 == 'reason refund missed connecting flight denied' or re7 == 'justification denying refund missed connecting flight' or re7 == 'refund missed connecting flight approved' or re7 == 'reason denial refund request missed connecting flight' or re7 == 'clarify refund request missed connecting flight rejected' :
                        g = ref7()
                        Z1 = input(" Any more questions ")
                        re8 = filter1(Z1)
                        if re8 == 'helps approved refund' or re8 == 'details approved refund' or re8 == 'status details refund been approved' or re8 == 'regarding refund been processed approved' or re8 == 'specifics refund been approved' or re8 == 'details approved refund request' :
                          h = ref8()
                          Z1 = input(" Any more questions ")
                          re9 = filter1(Z1)
                          if re9 == 'great thanks needed now' :
                                i = ref9()
    elif key == 'pet' or key =='traveling pet' or key == 'animal' or pet == 'dog' or key == 'cat' or key == 'register pet' or key == 'understanding process traveling pet' or key == 'process bringing pet board' or key == 'details traveling pet' or key == 'travel pet flight' or key == 'information pet travel rules' or key == 'bring pet plane' or key == 'guidance flying pet' or key ==  'procedure pet travel' or key == 'understand fly pet' or key == 'information traveling pets' or key == 'process pet travel' :
      a = pet()
      Z1 = input(" Any more questions ")
      pe = filter1(Z1)
      if pe  == 'traveling small dog' or pe4 == 'small dog traveling' or pe4 == 'bringing small dog flight' or pe4 == 'pet small dog traveling' or pe4 == 'taking small dog trip' or pe4 == 'flying small dog' or pe4 == 'travel companion small dog' or pe4 == 'small dog' or pe4 == 'coming bringing small dog along' or pe4 == 'pet trip small dog' or pe4 == 'traveling small sized dog' :
        b = pet1()
        Z1 = input(" Any more questions ")
        pe1 = filter1(Z1)
        if pe1 == 'please kind carrier allowed' or pe1 == 'requirements pet carriers' or pe1 == 'sure allowed carrier types' or pe1 == 'details pet carrier specifications' or pe1 == 'please information acceptable carriers' or pe1 == 'rules pet carriers' or pe1 == 'kind pet carrier permitted' or pe1 == 'carrier requirements pet' or pe1 == 'sure carrier types allowed pets' or pe1 == 'guidance approved carrier pet' or pe1 == 'carrier rules pet travel' :
           c = pet2()
           Z1 = input(" Any more questions ")
           pe2 = filter1(Z1)
           if pe2 == 'much cost bring dog cabin' or pe2 == 'fee bringing dog cabin' or pe2 == 'much cost pet travel cabin' or pe2 == 'price bringing dog cabin' or pe2 == 'details cost pet travel' or pe2 == 'much pay bring dog board' or pe2 == 'charges dog traveling cabin' or pe2 == 'please fee taking pet cabin' or pe2 == 'much cost travel dog' or pe2 == 'cabin fee dog' or pe2 == 'charges bringing dog' :
              d = pet3()
              Z1 = input(" Any more questions ")
              pe3 = filter1(Z1)
              if pe3 == 'please details prepare' or pe3 == 'prepare pet travel' or pe3 == 'details pet ready trip' or pe3 == 'please information preparing pet flight' or pe3 == 'prepare pet journey' or pe3 == 'guidance getting pet travel ready' or pe3 == 'required prepare pet flight' or pe3 == 'steps take pet ready travel' or pe3 == 'please prepare pet trip' or pe3 == 'tips preparing pet flight' or pe3 == 'before traveling pet' :
                e = pet4()
                Z1 = input(" Any more questions ")
                pe4 = filter1(Z1)
                if pe4 == 'please add dog booking' or pe4 == 'assist adding dog booking'  or pe4 == 'please include dog reservation' or pe4 == 'add dog flight booking'  or pe4 == 'add pet travel plans'  or pe4 == 'adding dog booking'  or pe4 == 'add pet flight reservation'  or pe4 == 'dog added booking'  or pe4 == 'please include dog reservation'  or pe4 == 'booking include pet'  or pe4 == 'add dog flight please' :
                  f = pet5()
                  Z1 = input(" Any more questions ")
                  pe5 = filter1(Z1)
                  if pe5 == 'anything else moment thanks' :
                    f = pet6()
    elif key == 'question carry baggage upcoming flight' or key == 'carry baggage details' or key == 'information carry luggage flight' or key == 'rules carry baggage' or key == 'ask carry luggage requirements' or key == 'carry baggage policy' or key == 'regulations carry bags' or key == 'query carry board' or key == 'clarify carry bag limits' or key == 'carry baggage rules' or key == 'understand carry luggage guidelines' :
      a = carry()
      Z1 = input(" Any more questions ")
      ca = filter1(Z1)
      if ca == 'size weight restrictions carry luggage' or ca == 'size weight limits carry ons' or ca == 'carry size weight rules' or ca == 'maximum size weight carry bags' or ca == 'restrictions carry dimensions weight' or ca == 'details carry size weight limits' or ca == 'allowed size weight carry ons' or ca == 'size weight requirements carry luggage' or ca == 'large heavy carry bag' or ca == 'carry baggage size weight rules' or ca == 'size weight regulations carry luggage' :
        b = carry1()
        Z1 = input(" Any more questions ")
        ca1 = filter1(Z1)
        if ca1 == 'qualifies personal item' or ca1 == 'counts personal item carry baggage' or ca1 == 'items qualify personal luggage' or ca1 == 'considered personal item carry baggage' or ca1 == 'personal item policy carry ons' or ca1 == 'kinds items allowed personal baggage' or ca1 == 'qualifies personal carry item' or ca1 == 'included personal item category flights' or ca1 == 'define considered personal item flight' or ca1 == 'rules personal items carry baggage' or ca1 == 'clarify brought personal item' :
           c = carry2()
           Z1 = input(" Any more questions ")
           ca2 = filter1(Z1)
           if ca2 == 'measure luggage ensure meets size requirements' or ca2 == 'check luggage meets size standards' or ca2 == 'best way measure carry bag' or ca2 == 'verifying luggage size' or ca2 == 'measure luggage dimensions' or ca2 == 'proper way measure carry dimensions' or ca2 == 'luggage right size carry' or ca2 == 'measure carry bag correctly' or ca2 == 'check carry luggage within size limits' or ca2 == 'measure carry' or ca2 == 'process ensuring luggage meets size requirements' :
              d = carry3()
              Z1 = input(" Any more questions ")
              re5 = filter1(Z1)
              if key == 'helpful please proceed option' :
                e = carry4()
                Z1 = input(" Any more questions ")
                re5 = filter1(Z1)
                if key == 'questions thank' :
                  f = carry5()
    elif key == 'flight find one' or key == 'finding flight' or key == 'searching flights assist' or key == 'trip find flight' or key == 'check flight options' or key == 'flight assist' or key == 'find best flights' or key == 'finding flight trip' or key == 'book plane ticket' :
      a = suggest()
      Z1 = input(" Any more questions ")
      sg = filter1(Z1)
      print(sg)
      if sg  == 'traveling paris march th budget' or sg == 'destination paris traveling march th budget' or sg == 'going paris march th budget' or sg == 'flight paris march th staying within' or sg == 'fly paris march th budget'or sg == 'trip paris march th spend' or sg == 'travel paris march th less' or sg == 'heading paris march th budget' or sg == 'travel date march th going paris stay under' or sg == 'flight paris march th within budget' or sg == 'flights paris march th spend' :
        b = suggest1()
        Z1 = input(" Any more questions ")
        sg1 = filter1(Z1)
        print(sg1)
        if sg1 == 'prefer economy class airline' or sg1 == 'fly economy class without airline preference' or sg1 == 'preference economy class mind airline' or sg1 == 'fine economy class airline' or sg1 == 'economy class works flexible airline' or sg1 == 'prefer travel economy class no airline preference' or sg1 == 'airline fine long economy class' or sg1 == 'economy ticket no specific airline mind' or sg1 == 'economy class airline doesn matter' or sg1 == 'prefer economy seat picky airline' or sg1 == 'economy tickets airline matter' :
           c = suggest2()
           Z1 = input(" Any more questions ")
           sg2 = filter1(Z1)
           print(sg2)
           if sg2 == 'please cheapest flights' or sg2 == 'see most affordable flights' or sg2 == 'lowest priced flights available' or sg2 == 'display cheapest flight options' or sg2 == 'please least expensive flight options' or sg2 == 'most budget friendly flights' or sg2 == 'flights cheapest' or sg2 == 'see lowest cost flights' or sg2 == 'view most economical flight options' or sg2 == 'please list cheapest flights' or sg2 == 'most affordable options' :
              d = suggest3()
              Z1 = input(" Any more questions ")
              sg3 = filter1(Z1)
              print(sg3)
              if sg3 == 'flight please proceed booking' or sg3 == 'choose flight book' or sg3 == 'please book flight' or sg3 == 'ahead flight' or sg3 == 'proceed flight' or sg3 == 'take flight please' or sg3 == 'book flight good' or sg3 == 'decided flight book' or sg3 == 'flight please' or sg3 == 'proceed flight book now' or sg3 == 'please finalize flight' :
                e = suggest4()
                Z1 = input(" Any more questions ")
                sg4 = filter1(Z1)
                print(sg4)
                if sg4 == 'sure name james smith email james smith example com' :
                     f = suggest5()
                     Z1 = input(" Any more questions ")
                     sg5 = filter1(Z1)
                     print(sg5)
                     if sg5 == 'number' :
                      g = suggest6()
                      Z1 = input(" Any more questions ")
                      sg6 = filter1(Z1)
                      print(sg6)
                      if sg6 == 'no extras now thanks' :
                          h = suggest7()
                          Z1 = input(" Any more questions ")
                          sg7 = filter1(Z1)
                          print(sg7)
                          if sg7 == 'no good your thank' :
                              i = suggest8()
    elif key == 'traveling air canada soon accessibility services' or key == 'flying air canada soon learn accessibility services' or key == 'available traveling air canada shortly regarding accessibility services assist' or key == 'trip air canada soon information accessibility services' or key == 'flying air canada near future accessibility services' or key == 'scheduled fly air canada soon details accessibility services' or key == 'flying air canada soon information accessibility services offer assist' or key == 'accessibility services upcoming air canada flight' or key == 'travel air canada soon questions accessibility services assist' or key == 'going flying air canada shortly inquire accessibility services' or key == 'soon flying air canada information accessibility services out' :
          a = access()
          Z1 = input(" Any more questions ")
          ac = filter1(Z1)
          if ac == 'mobility airport boarding' or ac == 'require mobility both airport boarding'or ac == 'mobility airport when boarding plane' or ac == 'mobility airport boarding' or ac == 'mobility airport boarding process' or ac == 'mobility aid airport board flight' or ac == 'mobility both airport board' or ac == 'require mobility airport when boarding aircraft' or ac == 'request mobility airport boarding' or ac == 'mobility airport boarding procedure' or ac == 'mobility aid assist both airport when boarding' :
            b = access1()
            Z1 = input(" Any more questions ")
            ac1 = filter1(Z1)
            if ac1 == 'request wheelchair upcoming flight' or ac1 == 'request wheelchair flight' or ac1 == 'wheelchair upcoming flight' or ac1 == 'please wheelchair upcoming flight' or ac1 == 'request wheelchair flight' or ac1 == 'wheelchair upcoming flight' or ac1 == 'wheelchair upcoming flight please' or ac1 == 'wheelchair assist flight' or ac1 == 'request wheelchair service upcoming flight' or ac1 == 'book wheelchair flight' or ac1 == 'please wheelchair upcoming flight' :
              c = access2()
              Z1 = input(" Any more questions ")
              ac2 = filter1(Z1)
              if ac2 == 'booking reference abc please check' :
                d = access3()
                Z1 = input(" Any more questions ")
                ac3 = filter1(Z1)
                if ac3 == 'thank anything flight' or ac3 == 'thank anything flight' or ac3 == 'thanks take actions flight' or ac3 == 'thank anything aware flight' or ac3 == 'thanks specific things flight' or ac3 == 'thank anything prepare air' or ac3 == 'thanks steps take flight' or ac3 == 'thank anything once plane' or ac3 == 'thanks anything manage take care flight' or ac3 == 'thank doing anything course flight' or ac3 == 'thanks things consider board' :
                  e = access4()
                  Z1 = input(" Any more questions ")
                  re5 = filter1(Z1)
                  if key == 'perfect thanks information done conversation' :
                    e = access5()
    elif key == 'inquire maple leaf lounge upcoming flight' or key == 'flying soon maple leaf lounge' or key == 'information maple leaf lounge upcoming flight' or key == 'process accessing maple leaf lounge' or key == 'maple leaf lounge before flight' or key == 'wondering maple leaf lounge next trip' or key == 'learn accessing maple leaf lounge upcoming flight' or key == 'information regarding maple leaf lounge flight' or key == 'maple leaf lounge when travel soon' or key == 'details maple leaf lounge' or key == 'maple leaf lounge next flight' :
           a = maple()
           Z1 = input(" Any more questions ")
           mp = filter1(Z1)
           if mp == '' :
               b = maple1()
               Z1 = input(" Any more questions ")
               mp1 = filter1(Z1)
               if mp1 == '' :
                 c = maple2()
                 Z1 = input(" Any more questions ")
                 mp2 = filter1(Z1)
                 if mp2 == '' :
                     d = maple3()
    else:
            Z = key
    Z = "cancel airline booking"
    Z1 = "any further questions"
    Z2 = "any further response"
    Z3 = "any questions"
    Z4 = "anymore responses"
    Z5 = "anymore responses"
    Z6 = "anymore responses"
    Z7 = "logging app account locked"
    Z8 = "traveling new york Los Angeles"
    Z9 = "travel december 20 2024"
    Z10 = "new questions"
    Z11 = "new reservation responses"
    Z12 = "new reserve responses"
    Z13 = "further responses"
    Z14 = "new book questions"
    Z15 = "reward points exact reward points"
    Z16 = "membership number"
    Z17 = "any more questions"
    Z18 = "reward questions"
    Z19 = "reward points questions"
    Z20 = "seat window upcoming travel"
    Z21 = "any questions"
    Z22 = "anymore questions"
    Z23 = "few questions"
    Z24 = "any questions seat"
    Z25 = "seat responses"
    Z26 = "responses seat selection"
    Z27 = "seat questions"
    Z28 = "seat selection questions"
    Z29 = "book flight ticket new book booking reservation purchase"
    Z30 = "reward questions"
    Z31 = "reward points questions"
    Z32 = "new booking response"
    Z33 = "any questions"
    Z34 = "anymore questions"
    Z35 = "few questions"
    Z36 = "any questions new"
    Z37 = "reserve responses"
    Z38 = "responses booking"
    Z39 = "reservation questions"
    Z40 = "res questions"
    Z41 = "time change schedule changes disruptions policy"
    Z42 = "reference number"
    Z43 = "updated timing"
    Z44 = "arrival time changed"
    Z45 = "res questions"
    Z46 = "perfect thank you letting"
    Z47 = "sc questions"
    Z48 = "account forgotten password assist trouble accessing account forgotten password"
    Z49 = "send link"
    Z50 = "understood next steps"
    Z51 = "sincerely appreciate"
    Z52 = "forgot password questions"
    Z53 = "loyal appreciate detail benefits expect next journey frequent understand benefits entitled next journey"
    Z54 = "elite response"
    Z55 = "elite benefit questions"
    Z56 = "any more questions"
    Z57 = "missing points missing miles portion reward points appears missing. assist matter"
    Z58 = "missing points questions"
    Z59 = "missing point response"
    Z60 = "any more response"
    Z61 = "missing point questions"
    Z62 = "any more questions"
    Z63 = "Child traveling alone unaccompanied minor children traveling little one wanted check special facilities discounts available children"
    Z64 = "child questions"
    Z65 = "children response"
    Z66 = "any more child response"
    Z67 = "children questions"
    Z68 = "any more questions on children"
    Z69 = "incident damage occurred airport damage occurred airport"
    Z70 = "damage questions"
    Z71 = "damaged baggaged response"
    Z72 = "any more response"
    Z73 = "damaged questions"
    Z74 = "traveling special item information guidance traveling special item details rules traveling special item information carrying special item trip travel special item process bringing special item flight special item travel guidance understanding requirements traveling special item assist information carrying special item onboard traveling soon special item policies"
    Z75 = "children questions"
    Z76 = "any more questions on children"
    Z77 = "incident damage occurred airport damage occurred airport"
    Z78 = "damage questions"
    Z79 = "damaged baggaged response"
    Z80 = "any more response"
    Z81 = "damaged questions"
    Z82 = "supposed fly january th but heard might cancellations check flight booked fly january th but heard cancellations flight status flight scheduled january th ve heard cancellations check flight affected flight january th heard cancellations weather verify mine cancelled supposed fly january th but ve heard possible cancellations check flight flying january th heard chance cancellations check flight impacted flight booked january th concerned cancellations status flight scheduled fly january th ve heard flights cancelled check mine one fly january th ve heard might cancellations verify whether flight flight january th ve heard cancellations weather mine affected flight january th ve been hearing potential cancellations check operating"
    Z83 = "incident damage occurred airport damage occurred airport"
    Z84 = "damage questions"
    Z85 = "damaged baggaged response"
    Z86 = "any more response"
    Z87 = "damaged questions"
    Z88 = "traveling soon documents carry documents bring upcoming trip travel documents prepare journey flying soon required documents list documents trip paperwork upcoming flight understand documents necessary travel d documents carry travel plans documents bring along upcoming journey checklist travel documents clarify documents required trip"
    Z89 = "any further questions"
    Z90 = "any further response"
    Z91 = "any questions"
    Z92 = "anymore responses"
    Z93 = "anymore responses"
    Z94 = "anymore responses"
    Z95 = "logging app account locked"
    Z96 = "traveling new york Los Angeles"
    Z97 = "travel december 20 2024"
    Z98 = "new questions"
    Z99 = "new reservation responses"
    Z100 = "new reserve responses"
    Z101 = "further responses"
    Z102 = "connecting flight bit unsure first flight process traveling connecting flight first flight steps follow after first flight connecting flight connecting flights work after land first flight layover sure next  initial flight catching connecting flight connecting flights work once finish first flight board  handling connecting flight after land steps take first flight connection connecting flight"
    Z103 = "conecting flight responses"
    Z104 = "further responses of flight"
    Z105 = "further responses of connecting flight"
    Z106 = "further responses of next flight"
    Z107  = "restricted items flight allowed carry items restricted prohibited items items restricted restricted items unsure allowed flight items restricted items prohibited"
    Z108 = "new reserve responses"
    Z109 = "further responses"
    Z110 = "anymore responses"
    Z111 = "restricted responses"
    Z112 = "further responses of restricted items"
    Z113 = "further responses of prohibited items"

    Z114 = "check flight status check status flight flight time current status flight check flight schedule flight time flight status flight departing check timing flight flight departure time flight"
    Z115 = "further responses of next flight"
    Z116  = "further responses of next flight"
    Z117 = "new reserve responses"
    Z118 = "further responses"
    Z119 = "anymore responses"
    Z120 = "restricted responses"
    Z121 = "further responses of leadgen"
    Z122 = "further responses of new lead"
    Z123 = "further responses of lead"
    Z124 = "explore bistro meal options available family members"
    Z125 = "further responses of meal"
    Z126 = "further responses of bistro meal"
    Z127 = "further responses of bistro"
    Z128 = "voucher myself two vouchers spouse child voucher redeem"
    Z129 = "further responses"
    Z130 = "anymore responses"
    Z131 = "travel voucher responses"
    Z132 = "special offers discounts available booking flights festive discounts deals flights"
    Z133 = "further responses of discounts"
    Z134 = "further responses of festive"
    Z135 = "further responses of festive discounts"
    Z136 = "further responses"
    Z137 = "further responses"
    Z138 = "anymore responses"
    Z139 = "travel voucher responses"
    Z140 = "special offers discounts available booking flights festive discounts deals flights"
    Z141 = "further responses of discounts"
    Z142 = "further responses of festive"
    Z143 = "further responses of festive discounts"
    Z144 = "further responses"
    Z145 = "further responses"
    Z146 = "anymore responses"
    Z147 = "travel voucher responses"
    Z148 = "inflight wifi flight wifi flight wi fi"
    Z149 = "further responses of flight wifi"
    Z150 = "further responses of wifi"
    Z151 = "further responses"
    Z152 = "further responses"
    Z153 = "anymore responses"
    Z154 = "wifi responses"
    Z155 = "add family members account"
    Z156 = "further responses"
    Z157 = "further responses"
    Z158 = "anymore responses"
    Z159 = "wifi responses"
    Z160 = "check flight status check"
    Z161 = "checkin responses"
    Z162 = "further responses"
    Z163 = "further responses"
    Z164 = "anymore responses"
    Z165 = "check responses"
    Z157 = "further responses"
    Z158 = "anymore responses"
    Z159 = "wifi responses"
    Z160 = "check flight status check"
    Z161 = "checkin responses"
    Z162 = "further responses"
    Z163 = "further responses"
    Z164 = "anymore responses"
    Z165 = "check responses"
    Z166 = "hotel stay trip finding hotel trip book hotel upcoming journey assist finding place stay trip stay hotel trip booking hotel travel find hotel trip accommodation travel reserve hotel stay assist hotel trip"
    Z167 = "anymore responses"
    Z168 = "hotel stay responses"
    Z169 = "journey responses"
    Z170 = "hotel stay trip responses"
    Z171 = "further responses"
    Z172 = "further responses"
    Z173 = "anymore responses"
    Z174 = "check responses"
    Z175 = "journey responses"
    Z176 = "hotel stay trip responses"
    Z177 = "further responses"
    Z178 = "further responses"
    Z179 = "anymore responses"
    Z180 = "check responses"
    Z181 = "browsing flights earlier but book anything check cart flights earlier but complete booking"
    Z182 = "check responses"
    Z183 = "journey responses"
    Z184 = "hotel stay trip responses"
    Z185 = "further responses"
    Z186 = "further responses"
    Z187 = "anymore responses"
    Z188 = "check responses"
    Z189 = "traveling air canada wondering much additional bag cost additional baggage"
    Z190 = "additional bag responses"
    Z191 = "further responses"
    Z192 = "further responses"
    Z193 = "anymore responses"
    Z194 = "baggage responses"
    Z195 = "choosing seat booking selecting seat process seat options choosing right seat picking seat seat selection deciding seat seat options choosing best seat flight booking seat selection"
    Z196 = "further responses"
    Z197 = "upgraderesponses"
    Z198 = "anymore responses"
    Z199 = "any responses"
    Z200 = "seat upgrade responses"
    Z201 = "please transfer agent right away"
    Z202 = "upgrade responses"
    Z203 = "anymore responses"
    Z204 = "upset luggage issue handled happy way luggage problem dealt frustrated luggage issue managed"
    Z205 = "seat upgrade responses"
    Z206 = "any responses"
    Z207 = "extremely upset luggage angry way baggage issue luggage problem frustrated resolution baggage unhappy missing bag handled situation luggage baggage issue luggage problem "
    Z208 = "baggage responses"
    Z209 = "anymore responses"
    Z210 = "agent responses"
    Z211 = "escalation upgrade responses"
    Z212 = "any responses"
    Z213 = "existing travel existing booking existing reservation modify booking modify reservation"
    Z214 = "baggage responses"
    Z215 = "anymore responses"
    Z216 = "agent responses"
    Z217 = "escalation upgrade responses"
    Z218 = "any responses"
    Z219 = "flight pass"
    Z220 = "refunds responses"
    Z221 = "request refund anymore responses"
    Z222 = "any responses"
    Z223 = "anymore responses"
    Z224 = "request refund responses"
    Z225 = "anymore responses"
    Z226 = "details refund request refund process refund"
    Z227 = "refund responses"
    Z228 = "any responses"
    Z229 = "anymore responses"
    Z230 = "anymore responses"
    Z231 = "request pet responses"
    Z232 = "anymore responses"
    Z233 = "travel pet responses"
    Z234 = "pet responses"
    Z235 = "any responses"
    Z236 = "understanding process traveling pet travel pet animal"
    Z237 = "carry responses"
    Z238 = "anymore responses"
    Z239 = "carry on baggage responses"
    Z240 = "baggage responses"
    Z241 = "any responses"
    Z242 = "travel pet responses"
    Z243 = "carry on baggage carryon"
    Z244 = "any responses"
    Z245 = "carry on baggage responses"
    Z246 = "carry responses"
    Z247 = "anymore responses"
    Z248 = "carry on baggage responses"
    Z249 = "flight find one finding flight searching flights assist trip find flight"
    Z250 = "any responses"
    Z251 = "suggest more responses"
    Z252 = "suggest responses"
    Z253 = "any responses"
    Z254 = "flight responses"
    Z255 = "suggestive responses"
    Z256 = "anymore responses"
    Z257 = "suggest responses"
    Z258 =  "traveling air canada soon accessibility services"
    Z259 = "any responses"
    Z260 = "flight responses"
    Z261 = "suggestive responses"
    Z262 = "anymore responses"
    Z263 = "suggest responses"

    Y1=fuzz.WRatio(Z, Z1)
    print("A1 =",Y1)
    Y2=fuzz.WRatio(Z, Z2)
    print("cancel =",Y2)
    Y3=fuzz.WRatio(Z, Z3)
    print("cancel1 =",Y3)
    Y4=fuzz.WRatio(Z, Z4)
    print("cancel2 =",Y4)
    Y5=fuzz.WRatio(Z, Z5)
    print("cancel3 =",Y5)
    Y6=fuzz.WRatio(Z, Z6)
    print("cancel4 =",Y6)
    Y7=fuzz.WRatio(Z, Z7)
    print("cancel5 =",Y7)
    Y8=fuzz.WRatio(Z, Z8)
    print("lock =",Y8)
    Y9=fuzz.WRatio(Z, Z9)
    print("lock1 =",Y9)
    Y10=fuzz.WRatio(Z, Z10)
    print("lock2 =",Y10)
    Y11=fuzz.WRatio(Z, Z11)
    print("lock3 =",Y11)
    Y12=fuzz.WRatio(Z, Z12)
    print("lock4 =",Y12)
    Y13=fuzz.WRatio(Z, Z13)
    print("lock5 =",Y13)
    Y14=fuzz.WRatio(Z, Z14)
    print("lock6 =",Y14)
    Y15=fuzz.WRatio(Z, Z15)
    print("lock7 =",Y15)
    Y16=fuzz.WRatio(Z, Z16)
    print("rew =",Y16)
    Y17=fuzz.WRatio(Z, Z17)
    print("rew1 =",Y17)
    Y18=fuzz.WRatio(Z, Z18)
    print("rew2 =",Y18)
    Y19=fuzz.WRatio(Z, Z19)
    print("rew3 =",Y19)
    Y20=fuzz.WRatio(Z, Z20)
    print("rew4 =",Y20)
    Y21=fuzz.WRatio(Z, Z21)
    print("seat1 =",Y21)
    Y22=fuzz.WRatio(Z, Z22)
    print("seat2 =",Y22)
    Y23=fuzz.WRatio(Z, Z23)
    print("seat3 =",Y23)
    Y24=fuzz.WRatio(Z, Z24)
    print("seat4 =",Y24)
    Y25=fuzz.WRatio(Z, Z25)
    print("seat5 =",Y25)
    Y26=fuzz.WRatio(Z, Z26)
    print("seat6 =",Y26)
    Y27=fuzz.WRatio(Z, Z27)
    print("seat7 =",Y27)
    Y28=fuzz.WRatio(Z, Z28)
    print("seat8 =",Y28)
    Y29=fuzz.WRatio(Z, Z29)
    print("new =",Y29)
    Y30=fuzz.WRatio(Z, Z30)
    print("new1 =",Y30)
    Y31=fuzz.WRatio(Z, Z31)
    print("new3 =",Y31)
    Y32=fuzz.WRatio(Z, Z32)
    print("new4 =",Y32)
    Y33=fuzz.WRatio(Z, Z33)
    print("new5 =",Y33)
    Y34=fuzz.WRatio(Z, Z34)
    print("new6 =",Y34)
    Y35=fuzz.WRatio(Z, Z35)
    print("new7 =",Y35)
    Y36=fuzz.WRatio(Z, Z36)
    print("new8 =",Y36)
    Y37=fuzz.WRatio(Z, Z37)
    print("new9 =",Y37)
    Y38=fuzz.WRatio(Z, Z38)
    print("new10 =",Y38)
    Y39=fuzz.WRatio(Z, Z39)
    print("new11 =",Y39)
    Y40=fuzz.WRatio(Z, Z40)
    print("schedule =",Y40)
    Y41=fuzz.WRatio(Z, Z41)
    print("schedule1 =",Y41)
    Y42=fuzz.WRatio(Z, Z42)
    print("schedule2 =",Y42)
    Y43=fuzz.WRatio(Z, Z43)
    print("schedule3 =",Y43)
    Y44=fuzz.WRatio(Z, Z44)
    print("schedule4 =",Y44)
    Y45=fuzz.WRatio(Z, Z45)
    print("schedule5 =",Y45)
    Y46=fuzz.WRatio(Z, Z46)
    print("schedule6 =",Y46)
    Y47=fuzz.WRatio(Z, Z47)
    print("schedule7 =",Y47)
    Y48=fuzz.WRatio(Z, Z48)
    print("forgot =",Y48)
    Y49=fuzz.WRatio(Z, Z49)
    print("forgot1 =",Y49)
    Y50=fuzz.WRatio(Z, Z50)
    print("forgot2 =",Y50)
    Y51=fuzz.WRatio(Z, Z51)
    print("forgot3 =",Y51)
    Y52=fuzz.WRatio(Z, Z52)
    print("forgot4 =",Y52)
    Y53=fuzz.WRatio(Z, Z53)
    print("elite =",Y53)
    Y54=fuzz.WRatio(Z, Z54)
    print("elite1 =",Y54)
    Y55=fuzz.WRatio(Z, Z55)
    print("elite2 =",Y55)
    Y56=fuzz.WRatio(Z, Z56)
    print("elite3 =",Y56)
    Y57=fuzz.WRatio(Z, Z57)
    print("missing =",Y57)
    Y58=fuzz.WRatio(Z, Z58)
    print("missing1 =",Y58)
    Y59=fuzz.WRatio(Z, Z59)
    print("missing2 =",Y59)
    Y60=fuzz.WRatio(Z, Z60)
    print("missing3 =",Y60)
    Y61=fuzz.WRatio(Z, Z61)
    print("missing4 =",Y61)
    Y62=fuzz.WRatio(Z, Z62)
    print("missing5 =",Y62)
    Y63=fuzz.WRatio(Z, Z63)
    print("child =",Y63)
    Y64=fuzz.WRatio(Z, Z64)
    print("child1 =",Y64)
    Y65=fuzz.WRatio(Z, Z65)
    print("child2 =",Y65)
    Y66=fuzz.WRatio(Z, Z66)
    print("child3 =",Y66)
    Y67=fuzz.WRatio(Z, Z67)
    print("child4 =",Y67)
    Y68=fuzz.WRatio(Z, Z68)
    print("child5 =",Y68)
    Y69=fuzz.WRatio(Z, Z69)
    print("dam =",Y69)
    Y70=fuzz.WRatio(Z, Z70)
    print("dam1 =",Y70)
    Y71=fuzz.WRatio(Z, Z71)
    print("dam2 =",Y71)
    Y72=fuzz.WRatio(Z, Z72)
    print("dam3 =",Y72)
    Y73=fuzz.WRatio(Z, Z73)
    print("dam4 =",Y73)
    Y74=fuzz.WRatio(Z, Z74)
    print("special =",Y74)
    Y75=fuzz.WRatio(Z, Z75)
    print("special2 =",Y75)
    Y76=fuzz.WRatio(Z, Z76)
    print("special3 =",Y76)
    Y77=fuzz.WRatio(Z, Z77)
    print("special4 =",Y77)
    Y78=fuzz.WRatio(Z, Z78)
    print("special5 =",Y78)
    Y79=fuzz.WRatio(Z, Z79)
    print("special6 =",Y79)
    Y80=fuzz.WRatio(Z, Z80)
    print("special7 =",Y80)
    Y81=fuzz.WRatio(Z, Z81)
    print("special8 =",Y81)
    Y82=fuzz.WRatio(Z, Z82)
    print("natural=",Y82)
    Y83=fuzz.WRatio(Z, Z83)
    print("natural1 =",Y83)
    Y84=fuzz.WRatio(Z, Z84)
    print("natural2 =",Y84)
    Y85=fuzz.WRatio(Z, Z85)
    print("natural3 =",Y85)
    Y86=fuzz.WRatio(Z, Z86)
    print("natural4 =",Y86)
    Y87=fuzz.WRatio(Z, Z87)
    print("natural5 =",Y87)
    Y88=fuzz.WRatio(Z, Z88)
    print("doc =",Y88)
    Y89=fuzz.WRatio(Z, Z89)
    print("doc1 =",Y89)
    Y90=fuzz.WRatio(Z, Z90)
    print("doc2 =",Y90)
    Y91=fuzz.WRatio(Z, Z91)
    print("doc3 =",Y91)
    Y92=fuzz.WRatio(Z, Z92)
    print("doc4 =",Y92)
    Y93=fuzz.WRatio(Z, Z93)
    print("doc5 =",Y93)
    Y94=fuzz.WRatio(Z, Z94)
    print("doc6 =",Y94)
    Y95=fuzz.WRatio(Z, Z95)
    print("doc7 =",Y95)
    Y96=fuzz.WRatio(Z, Z96)
    print("doc8 =",Y96)
    Y97=fuzz.WRatio(Z, Z97)
    print("doc9 =",Y97)
    Y98=fuzz.WRatio(Z, Z98)
    print("doc10 =",Y98)
    Y99=fuzz.WRatio(Z, Z99)
    print("doc11 =",Y99)
    Y100=fuzz.WRatio(Z, Z100)
    print("doc12 =",Y100)
    Y101=fuzz.WRatio(Z, Z101)
    print("doc13 =",Y101)
    Y102=fuzz.WRatio(Z, Z102)
    print("connect =",Y102)
    Y103 =fuzz.WRatio(Z, Z103)
    print("connect1 =",Y103)
    Y104 =fuzz.WRatio(Z, Z104)
    print("connect2 =",Y104)
    Y105 =fuzz.WRatio(Z, Z105)
    print("connect3 =",Y105)
    Y106 =fuzz.WRatio(Z, Z106)
    print("connect4 =",Y106)
    Y107 =fuzz.WRatio(Z, Z107)
    print("resi =",Y107)
    Y108 =fuzz.WRatio(Z, Z108)
    print("resi1 =",Y108)
    Y109 =fuzz.WRatio(Z, Z109)
    print("resi2 =",Y109)
    Y110 =fuzz.WRatio(Z, Z110)
    print("resi3 =",Y110)
    Y111 =fuzz.WRatio(Z, Z111)
    print("resi4 =",Y111)
    Y112 =fuzz.WRatio(Z, Z112)
    print("resi5 =",Y112)
    Y113 =fuzz.WRatio(Z, Z113)
    print("resi6 =",Y113)
    Y114 =fuzz.WRatio(Z, Z114)
    print("lead =",Y114)
    Y115 =fuzz.WRatio(Z, Z115)
    print("lead1 =",Y115)
    Y116 =fuzz.WRatio(Z, Z116)
    print("lead2 =",Y116)
    Y117 =fuzz.WRatio(Z, Z117)
    print("lead3 =",Y117)
    Y118 =fuzz.WRatio(Z, Z118)
    print("lead4 =",Y118)
    Y119 =fuzz.WRatio(Z, Z119)
    print("lead5 =",Y119)
    Y120 =fuzz.WRatio(Z, Z120)
    print("lead6 =",Y120)
    Y121 =fuzz.WRatio(Z, Z121)
    print("lead7 =",Y121)
    Y122 =fuzz.WRatio(Z, Z122)
    print("lead8 =",Y122)
    Y123 =fuzz.WRatio(Z, Z123)
    print("lead9 =",Y123)
    Y124 =fuzz.WRatio(Z, Z124)
    print("bistro =",Y124)
    Y125 =fuzz.WRatio(Z, Z125)
    print("bistro1 =",Y125)
    Y126 =fuzz.WRatio(Z, Z126)
    print("bistro2 =",Y126)
    Y127 =fuzz.WRatio(Z, Z127)
    print("bistro3 =",Y127)
    Y128 =fuzz.WRatio(Z, Z128)
    print("voucher =",Y128)
    Y129 =fuzz.WRatio(Z, Z129)
    print("voucher1 =",Y129)
    Y130 =fuzz.WRatio(Z, Z130)
    print("voucher2 =",Y130)
    Y131 =fuzz.WRatio(Z, Z131)
    print("voucher3 =",Y131)
    Y132 =fuzz.WRatio(Z, Z132)
    print("festive =",Y132)
    Y133 =fuzz.WRatio(Z, Z133)
    print("festive1 =",Y133)
    Y134 =fuzz.WRatio(Z, Z134)
    print("festive2 =",Y134)
    Y135 =fuzz.WRatio(Z, Z135)
    print("festive3 =",Y135)
    Y136 =fuzz.WRatio(Z, Z136)
    print("festive4 =",Y136)
    Y137 =fuzz.WRatio(Z, Z137)
    print("festive5 =",Y137)
    Y138 =fuzz.WRatio(Z, Z138)
    print("festive6 =",Y138)
    Y139 =fuzz.WRatio(Z, Z139)
    print("festive7 =",Y139)
    Y140 =fuzz.WRatio(Z, Z140)
    print("promo =",Y140)
    Y141 =fuzz.WRatio(Z, Z141)
    print("promo1 =",Y141)
    Y142 =fuzz.WRatio(Z, Z142)
    print("promo2 =",Y142)
    Y143 =fuzz.WRatio(Z, Z143)
    print("promo3 =",Y143)
    Y144 =fuzz.WRatio(Z, Z144)
    print("promo4 =",Y144)
    Y145 =fuzz.WRatio(Z, Z145)
    print("promo5 =",Y145)
    Y146 =fuzz.WRatio(Z, Z146)
    print("promo6 =",Y146)
    Y147 =fuzz.WRatio(Z, Z147)
    print("promo7 =",Y147)
    Y148 =fuzz.WRatio(Z, Z148)
    print("wifi =",Y148)
    Y149 =fuzz.WRatio(Z, Z149)
    print("wifi1 =",Y149)
    Y150 =fuzz.WRatio(Z, Z150)
    print("wifi2 =",Y150)
    Y151 =fuzz.WRatio(Z, Z151)
    print("wifi3 =",Y151)
    Y152 =fuzz.WRatio(Z, Z152)
    print("wifi4 =",Y152)
    Y153 =fuzz.WRatio(Z, Z153)
    print("wifi5 =",Y153)
    Y154 =fuzz.WRatio(Z, Z154)
    print("wifi6 =",Y154)
    Y155 =fuzz.WRatio(Z, Z155)
    print("family =",Y155)
    Y156 =fuzz.WRatio(Z, Z156)
    print("family1 =",Y156)
    Y157 =fuzz.WRatio(Z, Z157)
    print("family2 =",Y157)
    Y158 =fuzz.WRatio(Z, Z158)
    print("family3 =",Y158)
    Y159 =fuzz.WRatio(Z, Z159)
    print("family4 =",Y159)
    Y160 =fuzz.WRatio(Z, Z160)
    print("check =",Y160)
    Y161 =fuzz.WRatio(Z, Z161)
    print("check1 =",Y161)
    Y162 =fuzz.WRatio(Z, Z162)
    print("check2 =",Y162)
    Y163 =fuzz.WRatio(Z, Z163)
    print("check3 =",Y163)
    Y164 =fuzz.WRatio(Z, Z164)
    print("check4 =",Y164)
    Y165 =fuzz.WRatio(Z, Z165)
    print("check5 =",Y165)
    Y166 =fuzz.WRatio(Z, Z166)
    print("hotel =",Y166)
    Y167 =fuzz.WRatio(Z, Z167)
    print("hotel1 =",Y167)
    Y168 =fuzz.WRatio(Z, Z168)
    print("hotel2 =",Y168)
    Y169 =fuzz.WRatio(Z, Z169)
    print("hotel3 =",Y169)
    Y170 =fuzz.WRatio(Z, Z170)
    print("hotel4 =",Y170)
    Y171 =fuzz.WRatio(Z, Z171)
    print("hotel5 =",Y171)
    Y172 =fuzz.WRatio(Z, Z172)
    print("hotel6 =",Y163)
    Y173 =fuzz.WRatio(Z, Z173)
    print("hotel7 =",Y173)
    Y174 =fuzz.WRatio(Z, Z174)
    print("hotel8 =",Y174)
    Y175 =fuzz.WRatio(Z, Z175)
    print("reco =",Y175)
    Y176 =fuzz.WRatio(Z, Z176)
    print("reco1 =",Y176)
    Y177 =fuzz.WRatio(Z, Z177)
    print("reco2 =",Y177)
    Y178 =fuzz.WRatio(Z, Z178)
    print("reco3 =",Y178)
    Y179 =fuzz.WRatio(Z, Z179)
    print("reco4 =",Y179)
    Y180 =fuzz.WRatio(Z, Z180)
    print("reco5 =",Y180)
    Y181 =fuzz.WRatio(Z, Z181)
    print("cart =",Y181)
    Y182 =fuzz.WRatio(Z, Z182)
    print("cart1 =",Y182)
    Y183 =fuzz.WRatio(Z, Z183)
    print("cart2 =",Y183)
    Y184 =fuzz.WRatio(Z, Z184)
    print("cart3 =",Y184)
    Y185 =fuzz.WRatio(Z, Z185)
    print("cart4 =",Y185)
    Y186 =fuzz.WRatio(Z, Z186)
    print("cart5 =",Y186)
    Y187 =fuzz.WRatio(Z, Z187)
    print("cart6 =",Y187)
    Y188 =fuzz.WRatio(Z, Z188)
    print("cart7 =",Y188)
    Y189 =fuzz.WRatio(Z, Z189)
    print("addb =",Y189)
    Y190 =fuzz.WRatio(Z, Z190)
    print("addb1 =",Y190)
    Y191 =fuzz.WRatio(Z, Z191)
    print("addb2 =",Y191)
    Y192 =fuzz.WRatio(Z, Z192)
    print("addb3 =",Y192)
    Y193 =fuzz.WRatio(Z, Z193)
    print("addb4 =",Y193)
    Y194 =fuzz.WRatio(Z, Z194)
    print("addb5 =",Y194)
    Y195 =fuzz.WRatio(Z, Z195)
    print("addb1 =",Y195)
    Y196 =fuzz.WRatio(Z, Z196)
    print("addb2 =",Y196)
    Y197 =fuzz.WRatio(Z, Z197)
    print("addb3 =",Y197)
    Y198 =fuzz.WRatio(Z, Z194)
    print("addb =",Y194)
    Y199 =fuzz.WRatio(Z, Z195)
    print("addb1 =",Y195)
    Y200 =fuzz.WRatio(Z, Z196)
    print("addb2 =",Y196)
    Y201 =fuzz.WRatio(Z, Z201)
    print("transfer =",Y201)
    Y202 =fuzz.WRatio(Z, Z202)
    print("transfer1 =",Y202)
    Y203 =fuzz.WRatio(Z, Z203)
    print("transfer2 =",Y203)
    Y204 =fuzz.WRatio(Z, Z204)
    print("transfer3 =",Y204)
    Y205 =fuzz.WRatio(Z, Z205)
    print("transfer4 =",Y205)
    Y206 =fuzz.WRatio(Z, Z206)
    print("transfer5 =",Y206)
    Y207 =fuzz.WRatio(Z, Z207)
    print("follow =",Y207)
    Y208 =fuzz.WRatio(Z, Z208)
    print("follow1 =",Y208)
    Y209 =fuzz.WRatio(Z, Z209)
    print("follow2 =",Y209)
    Y210 =fuzz.WRatio(Z, Z210)
    print("follow3 =",Y210)
    Y211 =fuzz.WRatio(Z, Z211)
    print("follow4 =",Y211)
    Y212 =fuzz.WRatio(Z, Z212)
    print("follow5 =",Y212)
    Y213 =fuzz.WRatio(Z, Z213)
    print("existing =",Y213)
    Y214 =fuzz.WRatio(Z, Z214)
    print("existing1 =",Y214)
    Y215 =fuzz.WRatio(Z, Z215)
    print("existing2 =",Y215)
    Y216 =fuzz.WRatio(Z, Z216)
    print("existing3 =",Y216)
    Y217 =fuzz.WRatio(Z, Z217)
    print("existing4 =",Y217)
    Y218 =fuzz.WRatio(Z, Z218)
    print("existing5 =",Y218)
    Y219 =fuzz.WRatio(Z, Z219)
    print("pass =",Y219)
    Y220 =fuzz.WRatio(Z, Z220)
    print("pass1 =",Y220)
    Y221 =fuzz.WRatio(Z, Z221)
    print("pass2 =",Y221)
    Y222 =fuzz.WRatio(Z, Z222)
    print("pass3 =",Y222)
    Y223 =fuzz.WRatio(Z, Z223)
    print("pass4 =",Y223)
    Y224 =fuzz.WRatio(Z, Z224)
    print("pass5 =",Y224)
    Y225 =fuzz.WRatio(Z, Z225)
    print("pass6 =",Y225)
    Y226 =fuzz.WRatio(Z, Z226)
    print("ref =",Y226)
    Y227 =fuzz.WRatio(Z, Z227)
    print("ref1 =",Y227)
    Y228 =fuzz.WRatio(Z, Z228)
    print("ref2 =",Y228)
    Y229 =fuzz.WRatio(Z, Z229)
    print("ref3 =",Y229)
    Y230 =fuzz.WRatio(Z, Z230)
    print("ref4 =",Y230)
    Y231 =fuzz.WRatio(Z, Z231)
    print("ref5 =",Y231)
    Y232 =fuzz.WRatio(Z, Z232)
    print("ref6 =",Y232)
    Y233 =fuzz.WRatio(Z, Z233)
    print("ref7 =",Y233)
    Y234 =fuzz.WRatio(Z, Z234)
    print("ref8 =",Y234)
    Y235 =fuzz.WRatio(Z, Z235)
    print("ref9 =",Y235)
    Y236 =fuzz.WRatio(Z, Z236)
    print("pet =",Y236)
    Y237 =fuzz.WRatio(Z, Z237)
    print("pet1 =",Y237)
    Y238 =fuzz.WRatio(Z, Z238)
    print("pet2 =",Y238)
    Y239 =fuzz.WRatio(Z, Z239)
    print("pet3 =",Y239)
    Y240 =fuzz.WRatio(Z, Z240)
    print("pet4 =",Y240)
    Y241 =fuzz.WRatio(Z, Z241)
    print("pet5 =",Y241)
    Y242 =fuzz.WRatio(Z, Z242)
    print("pet6 =",Y216)
    Y243 =fuzz.WRatio(Z, Z243)
    print("carry =",Y243)
    Y244 =fuzz.WRatio(Z, Z244)
    print("carry1 =",Y244)
    Y245 =fuzz.WRatio(Z, Z245)
    print("carry2 =",Y245)
    Y246 =fuzz.WRatio(Z, Z246)
    print("carry3 =",Y246)
    Y247 =fuzz.WRatio(Z, Z247)
    print("carry4 =",Y247)
    Y248 =fuzz.WRatio(Z, Z248)
    print("carry5 =",Y248)
    Y249 =fuzz.WRatio(Z, Z249)
    print("suggest =",Y249)
    Y250 =fuzz.WRatio(Z, Z250)
    print("suggest1 =",Y250)
    Y251 =fuzz.WRatio(Z, Z251)
    print("suggest2 =",Y251)
    Y252 =fuzz.WRatio(Z, Z252)
    print("suggest3 =",Y252)
    Y253 =fuzz.WRatio(Z, Z253)
    print("suggest4 =",Y253)
    Y254 =fuzz.WRatio(Z, Z254)
    print("suggest5 =",Y254)
    Y255 =fuzz.WRatio(Z, Z255)
    print("suggest6 =",Y255)
    Y256 =fuzz.WRatio(Z, Z256)
    print("suggest7 =",Y256)
    Y257 =fuzz.WRatio(Z, Z257)
    print("suggest8 =",Y257)
    Y258 =fuzz.WRatio(Z, Z258)
    print("access =",Y258)
    Y259 =fuzz.WRatio(Z, Z259)
    print("access1 =",Y259)
    Y260 =fuzz.WRatio(Z, Z260)
    print("access2 =",Y260)
    Y261 =fuzz.WRatio(Z, Z261)
    print("access3 =",Y261)
    Y262 =fuzz.WRatio(Z, Z262)
    print("access4 =",Y262)
    Y263 =fuzz.WRatio(Z, Z263)
    print("access5 =",Y263)




    if Y1 > 80 :
     M = A()
    elif Y2 > 80 :
     Z= cancelresponse()
    elif Y3 > 80 :
     Y = cancelresponse1()
    elif Y4 > 80 :
     X = cancelresponse2()
    elif Y5 > 80 :
     W = cancelresponse3()
    elif Y6 > 80 :
     V = cancelresponse4()
    elif Y7 > 80 :
     T = cancelresponse5()
    elif Y8 > 80 :
     S = lockedacc()
    elif Y9 > 80 :
     R = lockedresponse()
    elif Y10 > 80 :
     Q = lockedresponse1()
    elif Y11 > 80 :
     P = lockedresponse2()
    elif Y12 > 80 :
     O = lockedresponse3()
    elif Y13 > 80 :
     N = lockedresponse4()
    elif Y14 > 80 :
     L = lockedresponse5()
    elif Y15 > 60 :
     K = lockedresponse6()
    elif Y16 > 60 :
     J = rewardpt()
    elif Y17 > 60 :
     I = rewardpt1()
    elif Y18 > 60 :
     H = rewardpt2()
    elif Y19 > 60 :
     G = rewardpt3()
    elif Y20 > 60 :
     F = rewardpt4()
    elif Y21 > 80 :
     E = seat1()
    elif Y22 > 80 :
     D = seatoptionbasedonflightnumber()
    elif Y23 > 80 :
     C = n1()
    elif Y24 > 80 :
     B = economyoptions()
    elif Y25 > 60 :
     A = pr()
    elif Y26 > 60 :
     A1 = seatnumber()
    elif Y27 > 60 :
     A2 = s2()
    elif Y28 > 60 :
     A3 = seat3()
    elif Y29 > 60 :
     A4 = seat4()
    elif Y30 > 60 :
     A5 = new()
    elif Y31 > 60 :
     A6 = new1()
    elif Y32 > 80 :
     A7 = new3()
    elif Y33 > 80 :
     A8 = new4()
    elif Y34 > 80 :
     A9 = new5()
    elif Y35 > 80 :
     A10 = new6()
    elif Y36 > 60 :
     A11 = new7()
    elif Y37 > 60 :
     A12 = new8()
    elif Y38 > 60 :
     A13 = new9()
    elif Y39 > 60 :
     A14 = new10()
    elif Y40 > 60 :
     A15 = new11()
    elif Y41 > 80 :
     A16 = schedule()
    elif Y41 > 80 :
     A17 = schedule1()
    elif Y42 > 80 :
     A18 = schedule2()
    elif Y43 > 80 :
     A19 = schedule3()
    elif Y44 > 80 :
     A20 = schedule4()
    elif Y45 > 80 :
     A21 = schedule5()
    elif Y46 > 80 :
     A22 = schedule6()
    elif Y47 > 80 :
     A23 = schedule7()
    elif Y48 > 80 :
     A24 = forgot()
    elif Y49 > 80 :
     A25 = forgot1()
    elif Y50 > 80 :
     A26 = forgot2()
    elif Y51 > 80 :
     A27 = forgot3()
    elif Y52 > 80 :
     A28 = forgot4()
    elif Y53 > 80 :
     A29 = elite()
    elif Y54 > 80 :
     A30 = elite1()
    elif Y55 > 80 :
     A31 = elite2()
    elif Y56 > 80 :
     A32 = elite3()
    elif Y57 > 80 :
     A33 = missing()
    elif Y58 > 80 :
     A34 = missing1()
    elif Y59 > 80 :
     A35 = missing2()
    elif Y60 > 80 :
     A36 = missing3()
    elif Y61 > 80 :
     A37 = missing4()
    elif Y62 > 80 :
     A38 = missing5()
    elif Y63 > 80 :
     A39 = child()
    elif Y64 > 80 :
     A40 = child1()
    elif Y65 > 80 :
     A41 = child2()
    elif Y66 > 80 :
     A42 = child3()
    elif Y67 > 80 :
     A43 = child4()
    elif Y68 > 80 :
     A44 = child5()
    elif Y69 > 80 :
     A45 = dam()
    elif Y70 > 80 :
     A46 = dam1()
    elif Y71 > 80 :
     A47 = dam2()
    elif Y72 > 80 :
     A48 = dam3()
    elif Y73 > 80 :
     A49 = dam4()
    elif Y74 > 80 :
     A50 = special()
    elif Y75 > 80 :
     A52 = special2()
    elif Y76 > 80 :
     A53 = special3()
    elif Y77 > 80 :
     A54 = special4()
    elif Y78 > 80 :
     A55 = special5()
    elif Y79 > 80 :
     A56 = special6()
    elif Y80 > 80 :
     A57 = special7()
    elif Y81 > 80 :
     A58 = special8()
    elif Y82 > 80 :
     A59 = special3()
    elif Y83 > 80 :
     A60 = special4()
    elif Y84 > 80 :
     A61 = special5()
    elif Y85 > 80 :
     A62 = special6()
    elif Y86 > 80 :
     A63 = special7()
    elif Y87 > 80 :
     A64 = special8()
    elif Y88 > 80 :
     A65 = doc()
    elif Y89 > 80 :
     A66 = doc1()
    elif Y90 > 80 :
     A67 = doc2()
    elif Y91 > 80 :
     A68 = doc3()
    elif Y92 > 80 :
     A69 = doc4()
    elif Y93 > 80 :
     A70 = doc5()
    elif Y94 > 80 :
     A71 = doc6()
    elif Y95 > 80 :
     A72 = doc7()
    elif Y96 > 80 :
     A73 = doc8()
    elif Y97 > 80 :
     A74 = doc9()
    elif Y98 > 80 :
     A75 = doc10()
    elif Y99 > 80 :
     A76 = doc11()
    elif Y100 > 80 :
     A77 = doc12()
    elif Y101 > 80 :
     A78 = doc13()
    elif Y102 > 80 :
     A79 = connect()
    elif Y103 > 80 :
     A80 = connect1()
    elif Y104 > 80 :
     A81 = connect2()
    elif Y105 > 80 :
     A82 = connect3()
    elif Y106 > 80 :
     A83 = connect4()
    elif Y107 > 80 :
     A84 = resi()
    elif Y108 > 80 :
     A85 = resi1()
    elif Y109 > 80 :
     A86 = resi2()
    elif Y110 > 80 :
     A87 = resi3()
    elif Y111 > 80 :
     A88 = resi4()
    elif Y112 > 80 :
     A89 = resi5()
    elif Y113 > 80 :
     A90 = resi6()
    elif Y114 > 80 :
     A91 = lead()
    elif Y115 > 80 :
     A92 = lead1()
    elif Y116 > 80 :
     A93 = lead2()
    elif Y117 > 80 :
     A94 = lead3()
    elif Y118 > 80 :
     A95 = lead4()

    elif Y119 > 80 :
     A97 = lead5()
    elif Y120 > 80 :
     A98 = lead6()
    elif Y121 > 80 :
     A99 = lead7()
    elif Y122 > 80 :
     A100 = lead8()
    elif Y123 > 80 :
     A101 = lead9()
    elif Y124 > 80 :
     A102 = bistro()
    elif Y125 > 80 :
     A103 = bistro1()
    elif Y126 > 80 :
     A104 = bistro2()
    elif Y127 > 80 :
     A105 = bistro3()
    elif Y128 > 80 :
     A106 = voucher()
    elif Y129 > 80 :
     A107 = voucher1()
    elif Y130 > 80 :
     A108 = voucher2()
    elif Y131 > 80 :
     A109 = voucher3()
    elif Y132 > 80 :
     A110 = festive()
    elif Y133 > 80 :
     A111 = festive1()
    elif Y134 > 80 :
     A112 = festive2()
    elif Y135 > 80 :
     A113 = festive3()
    elif Y136 > 80 :
     A114 = festive4()
    elif Y137 > 80 :
     A115 = festive5()
    elif Y138 > 80 :
     A116 = festive6()
    elif Y139 > 80 :
     A117 = festive7()
    elif Y140 > 80 :
     A118 = promo()
    elif Y141 > 80 :
     A119 = promo1()
    elif Y142 > 80 :
     A120 = promo2()
    elif Y143 > 80 :
     A121 = promo3()
    elif Y144 > 80 :
     A122 = promo4()
    elif Y145 > 80 :
     A123 = promo5()
    elif Y146 > 80 :
     A124 = promo6()
    elif Y147 > 80 :
     A125 = promo7()
    elif Y148 > 80 :
     A126 = wifi()
    elif Y149 > 80 :
     A127 = wifi1()
    elif Y150 > 80 :
     A128 = wifi2()
    elif Y151 > 80 :
     A129 = wifi3()
    elif Y152 > 80 :
     A130 = wifi4()
    elif Y153 > 80 :
     A131 = wifi5()
    elif Y154 > 80 :
     A132 = wifi6()
    elif Y155 > 80 :
     A133 = family()
    elif Y156 > 80 :
     A134 = family1()
    elif Y157 > 80 :
     A135 = family2()
    elif Y158 > 80 :
     A136 = family3()
    elif Y159 > 80 :
     A137 = family4()
    elif Y160 > 80 :
     A138 = check()
    elif Y161 > 80 :
     A139 = check1()
    elif Y162 > 80 :
     A140 = check2()
    elif Y163 > 80 :
     A141 = check3()
    elif Y164 > 80 :
     A142 = check4()
    elif Y165 > 80 :
     A143 = check5()
    elif Y157 > 80 :
     A144 = family2()
    elif Y158 > 80 :
     A145 = family3()
    elif Y159 > 80 :
     A146 = family4()
    elif Y160 > 80 :
     A147 = check()
    elif Y161 > 80 :
     A148 = check1()
    elif Y162 > 80 :
     A149 = check2()
    elif Y163 > 80 :
     A150 = check3()
    elif Y164 > 80 :
     A151 = check4()
    elif Y165 > 80 :
     A152 = check5()
    elif Y166 > 80 :
     A153 = hotel()
    elif Y167 > 80 :
     A154 = hotel1()
    elif Y168 > 80 :
     A155 = hotel2()
    elif Y169 > 80 :
     A156 = hotel3()
    elif Y170 > 80 :
     A157 = hotel4()
    elif Y171 > 80 :
     A158 = hotel5()
    elif Y172 > 80 :
     A159 = hotel6()
    elif Y173 > 80 :
     A160 = hotel7()
    elif Y174 > 80 :
     A161 = hotel8()
    elif Y175 > 80 :
     A162 = reco()
    elif Y176 > 80 :
     A163 = reco1()
    elif Y177 > 80 :
     A164 = reco2()
    elif Y178 > 80 :
     A165 = reco3()
    elif Y179 > 80 :
     A166 = reco4()
    elif Y180 > 80 :
     A167 = reco5()
    elif Y181 > 80 :
     A168 = cart()
    elif Y182 > 80 :
     A169 = cart1()
    elif Y183 > 80 :
     A170 = cart2()
    elif Y184 > 80 :
     A171 = cart3()
    elif Y185 > 80 :
     A172 = cart4()
    elif Y186 > 80 :
     A173 = cart5()
    elif Y187 > 80 :
     A174 = cart6()
    elif Y188 > 80 :
     A175 = cart7()
    elif Y189 > 80 :
     A176 = addb()
    elif Y190 > 80 :
     A177 = addb1()
    elif Y191 > 80 :
     A178 = addb2()
    elif Y192 > 80 :
     A179 = addb3()
    elif Y193 > 80 :
     A180 = addb4()
    elif Y194 > 80 :
     A181 = addb5()
    elif Y195 > 80 :
     A182 = upgrade()
    elif Y196 > 80 :
     A183 = upgrade1()
    elif Y197 > 80 :
     A184 = upgrade2()
    elif Y198 > 80 :
     A185 = upgrade3()
    elif Y199 > 80 :
     A186 = upgrade4()
    elif Y200 > 80 :
     A187 = upgrade5()
    elif Y201 > 80 :
     A188 = transfer()
    elif Y202 > 80 :
     A189 = transfer1()
    elif Y203 > 80 :
     A190 = transfer2()
    elif Y204 > 80 :
     A191 = transfer3()
    elif Y205 > 80 :
     A192 = transfer4()
    elif Y206 > 80 :
     A193 = transfer5()
    elif Y207 > 80 :
     A194 = follow()
    elif Y208 > 80 :
     A195 = follow1()
    elif Y209 > 80 :
     A196 = follow2()
    elif Y210 > 80 :
     A197 = follow3()
    elif Y211 > 80 :
     A198 = follow4()
    elif Y212 > 80 :
     A199 = follow5()
    elif Y213 > 80 :
     A200 = existing()
    elif Y214 > 80 :
     A201 = existing1()
    elif Y215 > 80 :
     A202 = existing2()
    elif Y216 > 80 :
     A203 = existing3()
    elif Y217 > 80 :
     A204 = existing4()
    elif Y218 > 80 :
     A205 = existing5()
    elif Y219 > 80 :
     A206 = flightpass()
    elif Y220 > 80 :
     A207 = flightpass1()
    elif Y221 > 80 :
     A208 = flightpass2()
    elif Y222 > 80 :
     A209 = flightpass3()
    elif Y223 > 80 :
     A210 = flightpass4()
    elif Y224 > 80 :
     A211 = flightpass5()
    elif Y225 > 80 :
     A212 = flightpass6()
    elif Y226 > 80 :
     A213 = ref()
    elif Y227 > 80 :
     A214 = ref1()
    elif Y228 > 80 :
     A215 = ref2()
    elif Y229 > 80 :
     A216 = ref3()
    elif Y230 > 80 :
     A217 = ref4()
    elif Y231 > 80 :
     A218 = ref5()
    elif Y232 > 80 :
     A219 = ref6()
    elif Y233 > 80 :
     A220 = ref7()
    elif Y234 > 80 :
     A221 = ref8()
    elif Y235 > 80 :
     A222 = ref9()
    elif Y236 > 80 :
     A217 = pet()
    elif Y237 > 80 :
     A218 = pet1()
    elif Y238 > 80 :
     A219 = pet2()
    elif Y239 > 80 :
     A220 = pet3()
    elif Y240 > 80 :
     A221 = pet4()
    elif Y241 > 80 :
     A222 = pet5()
    elif Y242 > 80 :
     A223 = pet6()
    elif Y243 > 80 :
     A224 = carry()
    elif Y244 > 80 :
     A225 = carry1()
    elif Y245 > 80 :
     A226 = carry2()
    elif Y246 > 80 :
     A227 = carry3()
    elif Y247 > 80 :
     A228 = carry4()
    elif Y248 > 80 :
     A229 = carry5()
    elif Y249 > 80 :
     A230 = suggest()
    elif Y250 > 80 :
     A231 = suggest1()
    elif Y251 > 80 :
     A232 = suggest2()
    elif Y252 > 80 :
     A233 = suggest3()
    elif Y253 > 80 :
     A234 = suggest4()
    elif Y254 > 80 :
     A235 = suggest5()
    elif Y255 > 80 :
     A236 = suggest6()
    elif Y256 > 80 :
     A237 = suggest7()
    elif Y257 > 80 :
     A238 = suggest7()
    elif Y258 > 80 :
     A239 = access()
    elif Y259 > 80 :
     A240 = access1()
    elif Y260 > 80 :
     A241 = access2()
    elif Y261 > 80 :
     A242 = access3()
    elif Y262 > 80 :
     A243 = access4()
    elif Y263 > 80 :
     A244 = access5()
# Out:
# kindly provide me your name=YUvaraj
# welcome mr YUvaraj
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-8e76a623de1f> in <cell line: 1482>()
#    1482 for i in range(5):
#    1483
# -> 1484     key = filter()
#    1485
#    1486
#
# <ipython-input-6-8e76a623de1f> in filter()
#      16
#      17 def filter():
# ---> 18       Z = input("Hello! Welcome to Air Canada. How may I assist you today? ")
#      19       Y = Z.lower()
#      20       a1 =re.sub(r'[^A-Za-z0-9\s]+', '', Y)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...

# %%
pip install fuzzywuzzy

# %%
pip install process
# Out:
# ERROR: Could not find a version that satisfies the requirement process (from versions: none)
# ERROR: No matching distribution found for process
